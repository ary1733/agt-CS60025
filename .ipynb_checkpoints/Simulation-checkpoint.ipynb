# %% [markdown]
# # Imports for Simulation and Visualiation

# %%
from random import randint, shuffle
import time
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Class Game
# - Attributes
#     - PayoffMatrix
#         : Payoff Matrix of two player Game
# - Methods
#     - findSDSE
#         : Computes Strong Dominant Strategy Equilibrium if it exists.
#     - findMSNE
#         : Computes MSNE using indifference priciple.

# %%
class game:
    def __init__(self):
        food = (MAX_FOOD_PER_ROUND + MIN_FOOD_PER_ROUND)//2
        self.payoffMatrix = [ 
                            [[(food//2) - ENERGY_LOSS_FROM_FIGHTING, (food//2) - ENERGY_LOSS_FROM_FIGHTING],[food,0]],
                            [[0, food],[(food//2), (food//2)]]
                            ]
#     Arguments : None, Return: list of SDSE strategy
    def findSDSE(self):
        P1 = []
        P2 = []
        if self.payoffMatrix[0][0][0] > self.payoffMatrix[1][0][0] and self.payoffMatrix[0][1][0] > self.payoffMatrix[1][1][0]:
            P1.append(0)
        if self.payoffMatrix[0][0][0] < self.payoffMatrix[1][0][0] and self.payoffMatrix[0][1][0] < self.payoffMatrix[1][1][0]:
            P1.appendp(1)
        if self.payoffMatrix[0][0][1] > self.payoffMatrix[0][1][1] and self.payoffMatrix[1][0][1] > self.payoffMatrix[1][1][1]:
            P2.append(0)
        if self.payoffMatrix[0][0][1] < self.payoffMatrix[0][1][1] and self.payoffMatrix[1][0][1] < self.payoffMatrix[1][1][1]:
            P2.append(1)
        ret = [(x, y) for x in P1 for y in P2]
        return ret

#   Arguments: None, Return list of probability distribution over strategy for player 1 and player 2
    def findMSNE(self):

        SDSE = self.findSDSE()
        p = np.zeros(2)
        q = np.zeros(2)
        if(len(SDSE) > 0):
            p[SDSE[0][0]] = 1
            q[SDSE[0][1]] = 1
            return [p,q]
        
#         row player Indifference Condition
        a = np.array([[1, 1], [self.payoffMatrix[0][0][0] - self.payoffMatrix[1][0][0], self.payoffMatrix[0][1][0] - self.payoffMatrix[1][1][0]] ])
        b = np.array([1, 0])
        q = np.linalg.solve(a, b)
        
#         col player Indifference Condition
        a = np.array([[1, 1], [self.payoffMatrix[0][0][1] - self.payoffMatrix[0][1][1], self.payoffMatrix[1][0][1] - self.payoffMatrix[1][1][1]] ])
        b = np.array([1, 0])
        p = np.linalg.solve(a, b) 
        return [p,q]

# %% [markdown]
# #### Global intitial Condtion
# 1. STARTING_DOVES
#     : The number of players who are Doves in the beginning
# 2. STARTING_HAWKS
#     : The number of players who are Doves in the beginning
# 3. ROUNDS
#     : Number of Rounds in the simulation
# 4. STARTING_ENERGY
#     : The amount of energy with which each player starts the game.
# 5. MIN_FOOD_PER_ROUND
#     : Min energy available per food.
# 6. MAX_FOOD_PER_ROUND
#     : Max energy available per food.
# 7. MAX_FOOD_APPEARANCE
#     : Max number of food appearance per round
# 8. ENERGY_REQUIRED_FOR_REPRODUCTION
#     : Minimum energy required to reproduce
# 9. ENERGY_LOSS_PER_ROUND
#     : Energy spent for surviving a round
# 10. ENERGY_LOSS_FROM_FIGHTING
#     : Energy spent over fighting
# 11. ENERGY_REQUIRED_FOR_LIVING
#     : Minimum energy required to remain alive
#
# #### Model Formulation
#
# Game Starts with gameInit(), a function which initialize all the agents. These agents are the players in this game and they can be either HAWK or DOVE.

# %%
STARTING_DOVES = 1000
STARTING_HAWKS = 1000
STARTING_POPULATION = STARTING_HAWKS + STARTING_DOVES

ROUNDS = 250
STARTING_ENERGY = 100

MIN_FOOD_PER_ROUND = 25
MAX_FOOD_PER_ROUND = 70
MAX_FOOD_APPEARANCE = 2000 # this tells how much max food can be found
ENERGY_REQUIRED_FOR_REPRODUCTION = 250
ENERGY_LOSS_PER_ROUND = 4
ENERGY_LOSS_FROM_FIGHTING = 80
ENERGY_REQUIRED_FOR_LIVING = 10

STATUS_ACTIVE = "active"
STATUS_ASLEEP = "asleep"

TYPE_HAWK = "hawk"
TYPE_DOVE = "dove"

agents = []

# Graph stuff
graph_hawk_points = []
graph_dove_points = []

AGENT_ID = 1
class Agent:
    
    def __init__(self, agent_type, status, energy):
        global AGENT_ID
        self.id = AGENT_ID
        AGENT_ID += 1
        self.agent_type = agent_type
        self.status = status
        self.energy = energy
    def wake(self):
        self.status = STATUS_ACTIVE
    def sleep(self):
        self.status = STATUS_ASLEEP

def gameInit():
    global agents
    agents = []
    for x in range(0,STARTING_DOVES):
        a = Agent(TYPE_DOVE, STATUS_ASLEEP, STARTING_ENERGY)
        agents.append(a)
    for x in range(0,STARTING_HAWKS):
        a = Agent(TYPE_HAWK, STATUS_ASLEEP, STARTING_ENERGY)
        agents.append(a)

def compete(agent, nemesis, food):
# add a food fuction inside agent
    if agent.agent_type == TYPE_HAWK and nemesis.agent_type == TYPE_HAWK:
        # food distributed as food // 2 and loss from fighting subtracted
        agent.energy += (food//2)
        agent.energy -= ENERGY_LOSS_FROM_FIGHTING
        nemesis.energy += (food//2)
        nemesis.energy -= ENERGY_LOSS_FROM_FIGHTING
        
    if agent.agent_type == TYPE_HAWK and nemesis.agent_type == TYPE_DOVE:
        agent.energy += food

    if agent.agent_type == TYPE_DOVE and nemesis.agent_type == TYPE_HAWK:
        nemesis.energy += food

    if agent.agent_type == TYPE_DOVE and nemesis.agent_type == TYPE_DOVE:
        agent.energy += (food//2)
        nemesis.energy += (food//2)

    nemesis.sleep()
    agent.sleep()
def cull():

    dead_hawks = 0
    dead_doves = 0
    n = len(agents)
    for index, agent in enumerate(reversed(agents)):
        if agent.energy < ENERGY_REQUIRED_FOR_LIVING:
            if agent.agent_type == TYPE_DOVE: dead_doves += 1
            if agent.agent_type == TYPE_HAWK: dead_hawks += 1
            del agents[n - index - 1]


    return dead_hawks, dead_doves
def breed():
    """
    If agent can breed, it halves its energy and produces 
    one baby with starting energy (parent energy // 2) and
    keep parent energy // 2 for itself
    """
    hawk_babies = 0
    dove_babies = 0
    for agent in agents:
        if agent.energy > ENERGY_REQUIRED_FOR_REPRODUCTION:
            baby_agent_a = Agent(agent.agent_type, STATUS_ASLEEP, (agent.energy//2))
            agents.append(baby_agent_a)

            agent.energy //= 2

            if agent.agent_type == TYPE_DOVE: dove_babies += 1
            if agent.agent_type == TYPE_HAWK: hawk_babies += 1


    return hawk_babies, dove_babies
def getCountOfType(agents):
    local_hawk_count = 0
    local_dove_count = 0
    for agent in agents:
        if agent.agent_type == TYPE_HAWK:
            local_hawk_count += 1
        else:
            local_dove_count += 1
    return local_hawk_count, local_dove_count
def getFood():
    return randint(MIN_FOOD_PER_ROUND, MAX_FOOD_PER_ROUND)
def awakenAgents():
    for agent in agents:
        agent.wake()
def main():
    gameInit()

    current_round = 1
    death_count = 0
    dead_hawks  = 0
    dead_doves  = 0
    breed_count = 0
    main_tic = time.time()
    
    while current_round <= ROUNDS and len(agents) > 2:
        print(f"Round {current_round}")
        tic = time.time()
        awakenAgents()
        food = getFood()
# shuffling agents so that the matchmaking while be random
        shuffle(agents)
        for idx in range (0, len(agents), 2):
            if idx//2 > MAX_FOOD_APPEARANCE:
                break
            if idx + 1 >= len(agents):
                break
            agent, nemesis = agents[idx], agents[idx + 1]
            compete(agent, nemesis, food)

        # Energy cost of 'living'
        for agent in agents:
            agent.energy -= ENERGY_LOSS_PER_ROUND
        
        round_dead_hawks, round_dead_doves = cull()
        round_hawk_babies, round_dove_babies = breed()
        death_count += (round_dead_hawks + round_dead_doves)
        breed_count += (round_hawk_babies + round_dove_babies)


        toc = time.time()
        # Plot
        hawk_count, dove_count = getCountOfType(agents)
        hawk_percent = (hawk_count / (hawk_count + dove_count))*100
        dove_percent = (dove_count / (hawk_count + dove_count))*100
        graph_hawk_points.append(hawk_count)
        graph_dove_points.append(dove_count)
        print("ROUND %d" % current_round)
        print("Food produced          : %d" % food)
        print(f"Population             : Hawks-> {hawk_count}, Doves-> {dove_count}")
        print("Dead hawks             : %d" % round_dead_hawks)
        print("Dead doves             : %d" % round_dead_doves)
        print("Hawk babies            : %s" % round_hawk_babies)
        print("Dove babies            : %s" % round_dove_babies)
        print("Hawks                  : %s" % hawk_percent)
        print("Doves                  : %s" % dove_percent)
        print("----")
        print("Round Processing time  : %s" % (toc - tic))
        print("Elapsed time           : %s\n" % (time.time() - main_tic))

        

        current_round += 1


    main_toc = time.time()
    hawk_count, dove_count = getCountOfType(agents)
    hawk_percent = (hawk_count / (hawk_count + dove_count))*100
    dove_percent = (dove_count / (hawk_count + dove_count))*100
    print("=============================================================")
    print("Total dead agents      : %d" % death_count)
    print("Total breeding agents  : %d" % breed_count)
    print("Total rounds completed : %d" % (current_round - 1))
    print("Total population size  : %s" % len(agents))
    print("Hawks                  : %s" % hawk_percent)
    print("Doves                  : %s" % dove_percent)
    print("Processing time        : %s" % (main_toc - main_tic))
    print("=============================================================")
main()
# Out:
# Round 1
# ROUND 1
# Food produced          : 68
# Population             : Hawks-> 1000, Doves-> 1000
# Dead hawks             : 0
# Dead doves             : 0
# Hawk babies            : 0
# Dove babies            : 0
# Hawks                  : 50.0
# Doves                  : 50.0
# ----
# Round Processing time  : 0.00694584846496582
# Elapsed time           : 0.007943391799926758
#
# Round 2
# ROUND 2
# Food produced          : 34
# Population             : Hawks-> 752, Doves-> 1000
# Dead hawks             : 248
# Dead doves             : 0
# Hawk babies            : 0
# Dove babies            : 0
# Hawks                  : 42.922374429223744
# Doves                  : 57.077625570776256
# ----
# Round Processing time  : 0.00498652458190918
# Elapsed time           : 0.013928890228271484
#
# Round 3
# ROUND 3
# Food produced          : 45
# Population             : Hawks-> 752, Doves-> 1000
# Dead hawks             : 0
# Dead doves             : 0
# Hawk babies            : 0
# Dove babies            : 0
# Hawks                  : 42.922374429223744
# Doves                  : 57.077625570776256
# ----
# Round Processing time  : 0.0040225982666015625
# Elapsed time           : 0.018955469131469727
#
# Round 4
# ROUND 4
# Food produced          : 40
# Population             : Hawks-> 745, Doves-> 1000
# Dead hawks             : 88
# Dead doves             : 0
# Hawk babies            : 81
# Dove babies            : 0
# Hawks                  : 42.693409742120345
# Doves                  : 57.306590257879655
# ----
# Round Processing time  : 0.0039823055267333984
# Elapsed time           : 0.023935794830322266
#
# Round 5
# ROUND 5
# Food produced          : 48
# Population             : Hawks-> 679, Doves-> 1000
# Dead hawks             : 66
# Dead doves             : 0
# Hawk babies            : 0
# Dove babies            : 0
# Hawks                  : 40.44073853484217
# Doves                  : 59.55926146515783
# ----
# Round Processing time  : 0.003988504409790039
# Elapsed time           : 0.027924299240112305
#
# Round 6
# ROUND 6
# Food produced          : 69
# Population             : Hawks-> 779, Doves-> 1000
# Dead hawks             : 14
# Dead doves             : 0
# Hawk babies            : 114
# Dove babies            : 0
# Hawks                  : 43.78864530635188
# Doves                  : 56.21135469364812
# ----
# Round Processing time  : 0.003988981246948242
# Elapsed time           : 0.03391551971435547
#
# Round 7
# ROUND 7
# Food produced          : 29
# Population             : Hawks-> 750, Doves-> 1000
# Dead hawks             : 67
# Dead doves             : 0
# Hawk babies            : 38
# Dove babies            : 0
# Hawks                  : 42.857142857142854
# Doves                  : 57.14285714285714
# ----
# Round Processing time  : 0.0039823055267333984
# Elapsed time           : 0.0448458194732666
#
# Round 8
# ROUND 8
# Food produced          : 56
# Population             : Hawks-> 764, Doves-> 1004
# Dead hawks             : 29
# Dead doves             : 0
# Hawk babies            : 43
# Dove babies            : 4
# Hawks                  : 43.21266968325792
# Doves                  : 56.78733031674208
# ----
# Round Processing time  : 0.004022836685180664
# Elapsed time           : 0.048868656158447266
#
# Round 9
# ROUND 9
# Food produced          : 54
# Population             : Hawks-> 806, Doves-> 1034
# Dead hawks             : 54
# Dead doves             : 0
# Hawk babies            : 96
# Dove babies            : 30
# Hawks                  : 43.80434782608696
# Doves                  : 56.19565217391305
# ----
# Round Processing time  : 0.003985166549682617
# Elapsed time           : 0.054853200912475586
#
# Round 10
# ROUND 10
# Food produced          : 35
# Population             : Hawks-> 762, Doves-> 1066
# Dead hawks             : 60
# Dead doves             : 0
# Hawk babies            : 16
# Dove babies            : 32
# Hawks                  : 41.68490153172866
# Doves                  : 58.31509846827133
# ----
# Round Processing time  : 0.003989219665527344
# Elapsed time           : 0.05983901023864746
#
# Round 11
# ROUND 11
# Food produced          : 66
# Population             : Hawks-> 825, Doves-> 1151
# Dead hawks             : 17
# Dead doves             : 0
# Hawk babies            : 80
# Dove babies            : 85
# Hawks                  : 41.75101214574899
# Doves                  : 58.24898785425101
# ----
# Round Processing time  : 0.10173726081848145
# Elapsed time           : 0.16257214546203613
#
# Round 12
# ROUND 12
# Food produced          : 36
# Population             : Hawks-> 826, Doves-> 1196
# Dead hawks             : 56
# Dead doves             : 0
# Hawk babies            : 57
# Dove babies            : 45
# Hawks                  : 40.85064292779426
# Doves                  : 59.14935707220573
# ----
# Round Processing time  : 0.0049860477447509766
# Elapsed time           : 0.1675581932067871
#
# Round 13
# ROUND 13
# Food produced          : 50
# Population             : Hawks-> 808, Doves-> 1284
# Dead hawks             : 58
# Dead doves             : 0
# Hawk babies            : 40
# Dove babies            : 88
# Hawks                  : 38.623326959847034
# Doves                  : 61.376673040152966
# ----
# Round Processing time  : 0.004987239837646484
# Elapsed time           : 0.1725454330444336
#
# Round 14
# ROUND 14
# Food produced          : 34
# Population             : Hawks-> 793, Doves-> 1324
# Dead hawks             : 50
# Dead doves             : 0
# Hawk babies            : 35
# Dove babies            : 40
# Hawks                  : 37.45866792631082
# Doves                  : 62.54133207368918
# ----
# Round Processing time  : 0.004987955093383789
# Elapsed time           : 0.17852234840393066
#
# Round 15
# ROUND 15
# Food produced          : 41
# Population             : Hawks-> 805, Doves-> 1401
# Dead hawks             : 49
# Dead doves             : 0
# Hawk babies            : 61
# Dove babies            : 77
# Hawks                  : 36.491387126019944
# Doves                  : 63.508612873980056
# ----
# Round Processing time  : 0.0049932003021240234
# Elapsed time           : 0.18450570106506348
#
# Round 16
# ROUND 16
# Food produced          : 26
# Population             : Hawks-> 785, Doves-> 1440
# Dead hawks             : 47
# Dead doves             : 0
# Hawk babies            : 27
# Dove babies            : 39
# Hawks                  : 35.28089887640449
# Doves                  : 64.71910112359551
# ----
# Round Processing time  : 0.004993438720703125
# Elapsed time           : 0.19049906730651855
#
# Round 17
# ROUND 17
# Food produced          : 68
# Population             : Hawks-> 860, Doves-> 1569
# Dead hawks             : 24
# Dead doves             : 0
# Hawk babies            : 99
# Dove babies            : 129
# Hawks                  : 35.405516673528204
# Doves                  : 64.5944833264718
# ----
# Round Processing time  : 0.005982160568237305
# Elapsed time           : 0.19747185707092285
#
# Round 18
# ROUND 18
# Food produced          : 43
# Population             : Hawks-> 918, Doves-> 1656
# Dead hawks             : 29
# Dead doves             : 0
# Hawk babies            : 87
# Dove babies            : 87
# Hawks                  : 35.66433566433567
# Doves                  : 64.33566433566433
# ----
# Round Processing time  : 0.005989551544189453
# Elapsed time           : 0.20445513725280762
#
# Round 19
# ROUND 19
# Food produced          : 55
# Population             : Hawks-> 964, Doves-> 1767
# Dead hawks             : 29
# Dead doves             : 0
# Hawk babies            : 75
# Dove babies            : 111
# Hawks                  : 35.29842548517026
# Doves                  : 64.70157451482973
# ----
# Round Processing time  : 0.005988121032714844
# Elapsed time           : 0.21144843101501465
#
# Round 20
# ROUND 20
# Food produced          : 32
# Population             : Hawks-> 982, Doves-> 1833
# Dead hawks             : 51
# Dead doves             : 0
# Hawk babies            : 69
# Dove babies            : 66
# Hawks                  : 34.88454706927176
# Doves                  : 65.11545293072825
# ----
# Round Processing time  : 0.0069735050201416016
# Elapsed time           : 0.21842193603515625
#
# Round 21
# ROUND 21
# Food produced          : 52
# Population             : Hawks-> 1055, Doves-> 1977
# Dead hawks             : 42
# Dead doves             : 0
# Hawk babies            : 115
# Dove babies            : 144
# Hawks                  : 34.79551451187335
# Doves                  : 65.20448548812665
# ----
# Round Processing time  : 0.006983280181884766
# Elapsed time           : 0.22639989852905273
#
# Round 22
# ROUND 22
# Food produced          : 51
# Population             : Hawks-> 1109, Doves-> 2094
# Dead hawks             : 40
# Dead doves             : 0
# Hawk babies            : 94
# Dove babies            : 117
# Hawks                  : 34.6237901966906
# Doves                  : 65.3762098033094
# ----
# Round Processing time  : 0.00698542594909668
# Elapsed time           : 0.23437929153442383
#
# Round 23
# ROUND 23
# Food produced          : 61
# Population             : Hawks-> 1229, Doves-> 2304
# Dead hawks             : 29
# Dead doves             : 0
# Hawk babies            : 149
# Dove babies            : 210
# Hawks                  : 34.7863005943957
# Doves                  : 65.2136994056043
# ----
# Round Processing time  : 0.007972240447998047
# Elapsed time           : 0.24331450462341309
#
# Round 24
# ROUND 24
# Food produced          : 56
# Population             : Hawks-> 1346, Doves-> 2477
# Dead hawks             : 27
# Dead doves             : 0
# Hawk babies            : 144
# Dove babies            : 173
# Hawks                  : 35.20795187025896
# Doves                  : 64.79204812974105
# ----
# Round Processing time  : 0.010008096694946289
# Elapsed time           : 0.2543191909790039
#
# Round 25
# ROUND 25
# Food produced          : 42
# Population             : Hawks-> 1406, Doves-> 2606
# Dead hawks             : 45
# Dead doves             : 0
# Hawk babies            : 105
# Dove babies            : 129
# Hawks                  : 35.044865403788634
# Doves                  : 64.95513459621137
# ----
# Round Processing time  : 0.009965896606445312
# Elapsed time           : 0.2652578353881836
#
# Round 26
# ROUND 26
# Food produced          : 45
# Population             : Hawks-> 1493, Doves-> 2750
# Dead hawks             : 63
# Dead doves             : 0
# Hawk babies            : 150
# Dove babies            : 144
# Hawks                  : 35.187367428706104
# Doves                  : 64.81263257129389
# ----
# Round Processing time  : 0.010004997253417969
# Elapsed time           : 0.2762289047241211
#
# Round 27
# ROUND 27
# Food produced          : 49
# Population             : Hawks-> 1562, Doves-> 2938
# Dead hawks             : 66
# Dead doves             : 0
# Hawk babies            : 135
# Dove babies            : 188
# Hawks                  : 34.71111111111111
# Doves                  : 65.28888888888889
# ----
# Round Processing time  : 0.011002779006958008
# Elapsed time           : 0.28822851181030273
#
# Round 28
# ROUND 28
# Food produced          : 30
# Population             : Hawks-> 1543, Doves-> 3005
# Dead hawks             : 59
# Dead doves             : 0
# Hawk babies            : 40
# Dove babies            : 67
# Hawks                  : 33.927000879507474
# Doves                  : 66.07299912049253
# ----
# Round Processing time  : 0.010970592498779297
# Elapsed time           : 0.300199031829834
#
# Round 29
# ROUND 29
# Food produced          : 62
# Population             : Hawks-> 1678, Doves-> 3250
# Dead hawks             : 45
# Dead doves             : 0
# Hawk babies            : 180
# Dove babies            : 245
# Hawks                  : 34.05032467532468
# Doves                  : 65.94967532467533
# ----
# Round Processing time  : 0.013960123062133789
# Elapsed time           : 0.3151562213897705
#
# Round 30
# ROUND 30
# Food produced          : 45
# Population             : Hawks-> 1739, Doves-> 3424
# Dead hawks             : 55
# Dead doves             : 0
# Hawk babies            : 116
# Dove babies            : 174
# Hawks                  : 33.6819678481503
# Doves                  : 66.3180321518497
# ----
# Round Processing time  : 0.0109710693359375
# Elapsed time           : 0.32712507247924805
#
# Round 31
# ROUND 31
# Food produced          : 58
# Population             : Hawks-> 1806, Doves-> 3635
# Dead hawks             : 35
# Dead doves             : 0
# Hawk babies            : 102
# Dove babies            : 211
# Hawks                  : 33.19242786252527
# Doves                  : 66.80757213747472
# ----
# Round Processing time  : 0.011980056762695312
# Elapsed time           : 0.3400919437408447
#
# Round 32
# ROUND 32
# Food produced          : 68
# Population             : Hawks-> 2045, Doves-> 3921
# Dead hawks             : 23
# Dead doves             : 0
# Hawk babies            : 262
# Dove babies            : 286
# Hawks                  : 34.27757291317466
# Doves                  : 65.72242708682535
# ----
# Round Processing time  : 0.013967037200927734
# Elapsed time           : 0.35504937171936035
#
# Round 33
# ROUND 33
# Food produced          : 67
# Population             : Hawks-> 2250, Doves-> 4172
# Dead hawks             : 27
# Dead doves             : 0
# Hawk babies            : 232
# Dove babies            : 251
# Hawks                  : 35.03581438804111
# Doves                  : 64.9641856119589
# ----
# Round Processing time  : 0.012965679168701172
# Elapsed time           : 0.3700106143951416
#
# Round 34
# ROUND 34
# Food produced          : 49
# Population             : Hawks-> 2356, Doves-> 4317
# Dead hawks             : 29
# Dead doves             : 0
# Hawk babies            : 135
# Dove babies            : 145
# Hawks                  : 35.306458864079126
# Doves                  : 64.69354113592087
# ----
# Round Processing time  : 0.013961553573608398
# Elapsed time           : 0.385967493057251
#
# Round 35
# ROUND 35
# Food produced          : 32
# Population             : Hawks-> 2383, Doves-> 4382
# Dead hawks             : 62
# Dead doves             : 0
# Hawk babies            : 89
# Dove babies            : 65
# Hawks                  : 35.22542498152254
# Doves                  : 64.77457501847745
# ----
# Round Processing time  : 0.013962268829345703
# Elapsed time           : 0.4009273052215576
#
# Round 36
# ROUND 36
# Food produced          : 37
# Population             : Hawks-> 2384, Doves-> 4459
# Dead hawks             : 85
# Dead doves             : 0
# Hawk babies            : 86
# Dove babies            : 77
# Hawks                  : 34.83852111646939
# Doves                  : 65.1614788835306
# ----
# Round Processing time  : 0.01595783233642578
# Elapsed time           : 0.41887927055358887
#
# Round 37
# ROUND 37
# Food produced          : 34
# Population             : Hawks-> 2364, Doves-> 4531
# Dead hawks             : 72
# Dead doves             : 0
# Hawk babies            : 52
# Dove babies            : 72
# Hawks                  : 34.285714285714285
# Doves                  : 65.71428571428571
# ----
# Round Processing time  : 0.015957355499267578
# Elapsed time           : 0.43683624267578125
#
# Round 38
# ROUND 38
# Food produced          : 64
# Population             : Hawks-> 2458, Doves-> 4741
# Dead hawks             : 67
# Dead doves             : 0
# Hawk babies            : 161
# Dove babies            : 210
# Hawks                  : 34.14363105986943
# Doves                  : 65.85636894013057
# ----
# Round Processing time  : 0.014957666397094727
# Elapsed time           : 0.4527890682220459
#
# Round 39
# ROUND 39
# Food produced          : 62
# Population             : Hawks-> 2564, Doves-> 4928
# Dead hawks             : 67
# Dead doves             : 0
# Hawk babies            : 173
# Dove babies            : 187
# Hawks                  : 34.223171382808324
# Doves                  : 65.77682861719167
# ----
# Round Processing time  : 0.015956878662109375
# Elapsed time           : 0.4707460403442383
#
# Round 40
# ROUND 40
# Food produced          : 58
# Population             : Hawks-> 2698, Doves-> 5125
# Dead hawks             : 44
# Dead doves             : 0
# Hawk babies            : 178
# Dove babies            : 197
# Hawks                  : 34.488048063402786
# Doves                  : 65.51195193659721
# ----
# Round Processing time  : 0.015952348709106445
# Elapsed time           : 0.48769474029541016
#
# Round 41
# ROUND 41
# Food produced          : 67
# Population             : Hawks-> 2858, Doves-> 5366
# Dead hawks             : 38
# Dead doves             : 0
# Hawk babies            : 198
# Dove babies            : 241
# Hawks                  : 34.75194552529183
# Doves                  : 65.24805447470817
# ----
# Round Processing time  : 0.015957355499267578
# Elapsed time           : 0.5086393356323242
#
# Round 42
# ROUND 42
# Food produced          : 33
# Population             : Hawks-> 2874, Doves-> 5432
# Dead hawks             : 52
# Dead doves             : 0
# Hawk babies            : 68
# Dove babies            : 66
# Hawks                  : 34.60149289670118
# Doves                  : 65.39850710329883
# ----
# Round Processing time  : 0.01695418357849121
# Elapsed time           : 0.527590274810791
#
# Round 43
# ROUND 43
# Food produced          : 37
# Population             : Hawks-> 2874, Doves-> 5506
# Dead hawks             : 79
# Dead doves             : 0
# Hawk babies            : 79
# Dove babies            : 74
# Hawks                  : 34.29594272076372
# Doves                  : 65.70405727923627
# ----
# Round Processing time  : 0.030881881713867188
# Elapsed time           : 0.5614640712738037
#
# Round 44
# ROUND 44
# Food produced          : 27
# Population             : Hawks-> 2828, Doves-> 5542
# Dead hawks             : 93
# Dead doves             : 0
# Hawk babies            : 47
# Dove babies            : 36
# Hawks                  : 33.78733572281959
# Doves                  : 66.21266427718041
# ----
# Round Processing time  : 0.016988039016723633
# Elapsed time           : 0.5804471969604492
#
# Round 45
# ROUND 45
# Food produced          : 41
# Population             : Hawks-> 2818, Doves-> 5620
# Dead hawks             : 79
# Dead doves             : 0
# Hawk babies            : 69
# Dove babies            : 78
# Hawks                  : 33.39653946432804
# Doves                  : 66.60346053567197
# ----
# Round Processing time  : 0.016955137252807617
# Elapsed time           : 0.5993967056274414
#
# Round 46
# ROUND 46
# Food produced          : 60
# Population             : Hawks-> 2899, Doves-> 5802
# Dead hawks             : 58
# Dead doves             : 0
# Hawk babies            : 139
# Dove babies            : 182
# Hawks                  : 33.318009424204114
# Doves                  : 66.6819905757959
# ----
# Round Processing time  : 0.01695418357849121
# Elapsed time           : 0.6183454990386963
#
# Round 47
# ROUND 47
# Food produced          : 54
# Population             : Hawks-> 2962, Doves-> 5949
# Dead hawks             : 59
# Dead doves             : 0
# Hawk babies            : 122
# Dove babies            : 147
# Hawks                  : 33.23981595780496
# Doves                  : 66.76018404219504
# ----
# Round Processing time  : 0.017959117889404297
# Elapsed time           : 0.6382927894592285
#
# Round 48
# ROUND 48
# Food produced          : 59
# Population             : Hawks-> 3046, Doves-> 6121
# Dead hawks             : 54
# Dead doves             : 0
# Hawk babies            : 138
# Dove babies            : 172
# Hawks                  : 33.227882622450096
# Doves                  : 66.7721173775499
# ----
# Round Processing time  : 0.018949508666992188
# Elapsed time           : 0.6592388153076172
#
# Round 49
# ROUND 49
# Food produced          : 27
# Population             : Hawks-> 3015, Doves-> 6156
# Dead hawks             : 79
# Dead doves             : 0
# Hawk babies            : 48
# Dove babies            : 35
# Hawks                  : 32.87536800785084
# Doves                  : 67.12463199214916
# ----
# Round Processing time  : 0.017949581146240234
# Elapsed time           : 0.679182767868042
#
# Round 50
# ROUND 50
# Food produced          : 63
# Population             : Hawks-> 3097, Doves-> 6312
# Dead hawks             : 58
# Dead doves             : 0
# Hawk babies            : 140
# Dove babies            : 156
# Hawks                  : 32.915293867573595
# Doves                  : 67.08470613242639
# ----
# Round Processing time  : 0.018949270248413086
# Elapsed time           : 0.6991293430328369
#
# Round 51
# ROUND 51
# Food produced          : 61
# Population             : Hawks-> 3200, Doves-> 6482
# Dead hawks             : 53
# Dead doves             : 0
# Hawk babies            : 156
# Dove babies            : 170
# Hawks                  : 33.051022516009084
# Doves                  : 66.94897748399092
# ----
# Round Processing time  : 0.019946813583374023
# Elapsed time           : 0.7210376262664795
#
# Round 52
# ROUND 52
# Food produced          : 38
# Population             : Hawks-> 3216, Doves-> 6558
# Dead hawks             : 68
# Dead doves             : 0
# Hawk babies            : 84
# Dove babies            : 76
# Hawks                  : 32.903621853898095
# Doves                  : 67.0963781461019
# ----
# Round Processing time  : 0.018984079360961914
# Elapsed time           : 0.7420156002044678
#
# Round 53
# ROUND 53
# Food produced          : 67
# Population             : Hawks-> 3332, Doves-> 6757
# Dead hawks             : 56
# Dead doves             : 0
# Hawk babies            : 172
# Dove babies            : 199
# Hawks                  : 33.02606799484587
# Doves                  : 66.97393200515413
# ----
# Round Processing time  : 0.01994609832763672
# Elapsed time           : 0.7639591693878174
#
# Round 54
# ROUND 54
# Food produced          : 69
# Population             : Hawks-> 3499, Doves-> 6968
# Dead hawks             : 39
# Dead doves             : 0
# Hawk babies            : 206
# Dove babies            : 211
# Hawks                  : 33.42887169198433
# Doves                  : 66.57112830801567
# ----
# Round Processing time  : 0.019944429397583008
# Elapsed time           : 0.7858984470367432
#
# Round 55
# ROUND 55
# Food produced          : 40
# Population             : Hawks-> 3536, Doves-> 7059
# Dead hawks             : 49
# Dead doves             : 0
# Hawk babies            : 86
# Dove babies            : 91
# Hawks                  : 33.374233128834355
# Doves                  : 66.62576687116565
# ----
# Round Processing time  : 0.02094268798828125
# Elapsed time           : 0.8088364601135254
#
# Round 56
# ROUND 56
# Food produced          : 32
# Population             : Hawks-> 3507, Doves-> 7099
# Dead hawks             : 87
# Dead doves             : 0
# Hawk babies            : 58
# Dove babies            : 40
# Hawks                  : 33.06618894965114
# Doves                  : 66.93381105034885
# ----
# Round Processing time  : 0.019947528839111328
# Elapsed time           : 0.8327722549438477
#
# Round 57
# ROUND 57
# Food produced          : 38
# Population             : Hawks-> 3500, Doves-> 7151
# Dead hawks             : 67
# Dead doves             : 0
# Hawk babies            : 60
# Dove babies            : 52
# Hawks                  : 32.8607642474885
# Doves                  : 67.13923575251151
# ----
# Round Processing time  : 0.020944595336914062
# Elapsed time           : 0.8557116985321045
#
# Round 58
# ROUND 58
# Food produced          : 27
# Population             : Hawks-> 3455, Doves-> 7170
# Dead hawks             : 81
# Dead doves             : 0
# Hawk babies            : 36
# Dove babies            : 19
# Hawks                  : 32.51764705882353
# Doves                  : 67.48235294117647
# ----
# Round Processing time  : 0.019949913024902344
# Elapsed time           : 0.8776521682739258
#
# Round 59
# ROUND 59
# Food produced          : 67
# Population             : Hawks-> 3568, Doves-> 7329
# Dead hawks             : 57
# Dead doves             : 0
# Hawk babies            : 170
# Dove babies            : 159
# Hawks                  : 32.74295677709461
# Doves                  : 67.2570432229054
# ----
# Round Processing time  : 0.021941184997558594
# Elapsed time           : 0.9025869369506836
#
# Round 60
# ROUND 60
# Food produced          : 50
# Population             : Hawks-> 3600, Doves-> 7430
# Dead hawks             : 68
# Dead doves             : 0
# Hawk babies            : 100
# Dove babies            : 101
# Hawks                  : 32.638259292837716
# Doves                  : 67.36174070716228
# ----
# Round Processing time  : 0.020943164825439453
# Elapsed time           : 0.9265215396881104
#
# Round 61
# ROUND 61
# Food produced          : 41
# Population             : Hawks-> 3624, Doves-> 7500
# Dead hawks             : 72
# Dead doves             : 0
# Hawk babies            : 96
# Dove babies            : 70
# Hawks                  : 32.5782092772384
# Doves                  : 67.4217907227616
# ----
# Round Processing time  : 0.021941423416137695
# Elapsed time           : 0.9514584541320801
#
# Round 62
# ROUND 62
# Food produced          : 30
# Population             : Hawks-> 3597, Doves-> 7538
# Dead hawks             : 85
# Dead doves             : 0
# Hawk babies            : 58
# Dove babies            : 38
# Hawks                  : 32.30354737314774
# Doves                  : 67.69645262685226
# ----
# Round Processing time  : 0.022935152053833008
# Elapsed time           : 0.976388692855835
#
# Round 63
# ROUND 63
# Food produced          : 35
# Population             : Hawks-> 3549, Doves-> 7584
# Dead hawks             : 98
# Dead doves             : 0
# Hawk babies            : 50
# Dove babies            : 46
# Hawks                  : 31.87819994610617
# Doves                  : 68.12180005389384
# ----
# Round Processing time  : 0.022944927215576172
# Elapsed time           : 1.0013282299041748
#
# Round 64
# ROUND 64
# Food produced          : 45
# Population             : Hawks-> 3536, Doves-> 7649
# Dead hawks             : 84
# Dead doves             : 0
# Hawk babies            : 71
# Dove babies            : 65
# Hawks                  : 31.613768439874836
# Doves                  : 68.38623156012517
# ----
# Round Processing time  : 0.027925729751586914
# Elapsed time           : 1.0322389602661133
#
# Round 65
# ROUND 65
# Food produced          : 68
# Population             : Hawks-> 3649, Doves-> 7809
# Dead hawks             : 48
# Dead doves             : 0
# Hawk babies            : 161
# Dove babies            : 160
# Hawks                  : 31.846744632571127
# Doves                  : 68.15325536742887
# ----
# Round Processing time  : 0.021949052810668945
# Elapsed time           : 1.0661509037017822
#
# Round 66
# ROUND 66
# Food produced          : 26
# Population             : Hawks-> 3600, Doves-> 7828
# Dead hawks             : 82
# Dead doves             : 0
# Hawk babies            : 33
# Dove babies            : 19
# Hawks                  : 31.501575078753934
# Doves                  : 68.49842492124606
# ----
# Round Processing time  : 0.022942066192626953
# Elapsed time           : 1.0910921096801758
#
# Round 67
# ROUND 67
# Food produced          : 70
# Population             : Hawks-> 3712, Doves-> 7983
# Dead hawks             : 48
# Dead doves             : 0
# Hawk babies            : 160
# Dove babies            : 155
# Hawks                  : 31.740059854638737
# Doves                  : 68.25994014536127
# ----
# Round Processing time  : 0.025925874710083008
# Elapsed time           : 1.1189727783203125
#
# Round 68
# ROUND 68
# Food produced          : 50
# Population             : Hawks-> 3763, Doves-> 8080
# Dead hawks             : 50
# Dead doves             : 0
# Hawk babies            : 101
# Dove babies            : 97
# Hawks                  : 31.774043738917506
# Doves                  : 68.2259562610825
# ----
# Round Processing time  : 0.020955801010131836
# Elapsed time           : 1.1439406871795654
#
# Round 69
# ROUND 69
# Food produced          : 53
# Population             : Hawks-> 3794, Doves-> 8173
# Dead hawks             : 71
# Dead doves             : 0
# Hawk babies            : 102
# Dove babies            : 93
# Hawks                  : 31.70385226038272
# Doves                  : 68.29614773961728
# ----
# Round Processing time  : 0.022947072982788086
# Elapsed time           : 1.1698834896087646
#
# Round 70
# ROUND 70
# Food produced          : 35
# Population             : Hawks-> 3781, Doves-> 8217
# Dead hawks             : 70
# Dead doves             : 1
# Hawk babies            : 57
# Dove babies            : 45
# Hawks                  : 31.5135855975996
# Doves                  : 68.4864144024004
# ----
# Round Processing time  : 0.023940563201904297
# Elapsed time           : 1.196765661239624
#
# Round 71
# ROUND 71
# Food produced          : 44
# Population             : Hawks-> 3829, Doves-> 8287
# Dead hawks             : 58
# Dead doves             : 0
# Hawk babies            : 106
# Dove babies            : 70
# Hawks                  : 31.60283922086497
# Doves                  : 68.39716077913502
# ----
# Round Processing time  : 0.021981477737426758
# Elapsed time           : 1.221745252609253
#
# Round 72
# ROUND 72
# Food produced          : 69
# Population             : Hawks-> 3944, Doves-> 8458
# Dead hawks             : 42
# Dead doves             : 0
# Hawk babies            : 157
# Dove babies            : 171
# Hawks                  : 31.8013223673601
# Doves                  : 68.19867763263989
# ----
# Round Processing time  : 0.022932767868041992
# Elapsed time           : 1.246656894683838
#
# Round 73
# ROUND 73
# Food produced          : 44
# Population             : Hawks-> 3972, Doves-> 8530
# Dead hawks             : 57
# Dead doves             : 0
# Hawk babies            : 85
# Dove babies            : 72
# Hawks                  : 31.77091665333547
# Doves                  : 68.22908334666454
# ----
# Round Processing time  : 0.02395343780517578
# Elapsed time           : 1.2726027965545654
#
# Round 74
# ROUND 74
# Food produced          : 44
# Population             : Hawks-> 3976, Doves-> 8603
# Dead hawks             : 74
# Dead doves             : 0
# Hawk babies            : 78
# Dove babies            : 73
# Hawks                  : 31.60823594880356
# Doves                  : 68.39176405119643
# ----
# Round Processing time  : 0.023936748504638672
# Elapsed time           : 1.2995243072509766
#
# Round 75
# ROUND 75
# Food produced          : 62
# Population             : Hawks-> 4078, Doves-> 8724
# Dead hawks             : 66
# Dead doves             : 0
# Hawk babies            : 168
# Dove babies            : 121
# Hawks                  : 31.85439775035151
# Doves                  : 68.14560224964849
# ----
# Round Processing time  : 0.022944927215576172
# Elapsed time           : 1.3254613876342773
#
# Round 76
# ROUND 76
# Food produced          : 39
# Population             : Hawks-> 4079, Doves-> 8772
# Dead hawks             : 71
# Dead doves             : 0
# Hawk babies            : 72
# Dove babies            : 48
# Hawks                  : 31.74072056649288
# Doves                  : 68.25927943350713
# ----
# Round Processing time  : 0.022939205169677734
# Elapsed time           : 1.3513522148132324
#
# Round 77
# ROUND 77
# Food produced          : 38
# Population             : Hawks-> 4066, Doves-> 8819
# Dead hawks             : 82
# Dead doves             : 0
# Hawk babies            : 69
# Dove babies            : 47
# Hawks                  : 31.556072953046176
# Doves                  : 68.44392704695382
# ----
# Round Processing time  : 0.024971723556518555
# Elapsed time           : 1.3793113231658936
#
# Round 78
# ROUND 78
# Food produced          : 50
# Population             : Hawks-> 4113, Doves-> 8896
# Dead hawks             : 57
# Dead doves             : 1
# Hawk babies            : 104
# Dove babies            : 78
# Hawks                  : 31.61657314167115
# Doves                  : 68.38342685832885
# ----
# Round Processing time  : 0.02394413948059082
# Elapsed time           : 1.4052515029907227
#
# Round 79
# ROUND 79
# Food produced          : 49
# Population             : Hawks-> 4137, Doves-> 8961
# Dead hawks             : 71
# Dead doves             : 0
# Hawk babies            : 95
# Dove babies            : 65
# Hawks                  : 31.584974805313788
# Doves                  : 68.41502519468621
# ----
# Round Processing time  : 0.023944854736328125
# Elapsed time           : 1.432176113128662
#
# Round 80
# ROUND 80
# Food produced          : 57
# Population             : Hawks-> 4209, Doves-> 9067
# Dead hawks             : 47
# Dead doves             : 0
# Hawk babies            : 119
# Dove babies            : 106
# Hawks                  : 31.703826453751127
# Doves                  : 68.29617354624887
# ----
# Round Processing time  : 0.02593064308166504
# Elapsed time           : 1.4611003398895264
#
# Round 81
# ROUND 81
# Food produced          : 65
# Population             : Hawks-> 4295, Doves-> 9198
# Dead hawks             : 64
# Dead doves             : 0
# Hawk babies            : 150
# Dove babies            : 131
# Hawks                  : 31.831319943674497
# Doves                  : 68.1686800563255
# ----
# Round Processing time  : 0.024934053421020508
# Elapsed time           : 1.4880270957946777
#
# Round 82
# ROUND 82
# Food produced          : 33
# Population             : Hawks-> 4287, Doves-> 9236
# Dead hawks             : 70
# Dead doves             : 0
# Hawk babies            : 62
# Dove babies            : 38
# Hawks                  : 31.701545515048434
# Doves                  : 68.29845448495156
# ----
# Round Processing time  : 0.0359044075012207
# Elapsed time           : 1.5269169807434082
#
# Round 83
# ROUND 83
# Food produced          : 60
# Population             : Hawks-> 4365, Doves-> 9351
# Dead hawks             : 66
# Dead doves             : 2
# Hawk babies            : 144
# Dove babies            : 117
# Hawks                  : 31.8241469816273
# Doves                  : 68.1758530183727
# ----
# Round Processing time  : 0.02493906021118164
# Elapsed time           : 1.5548477172851562
#
# Round 84
# ROUND 84
# Food produced          : 29
# Population             : Hawks-> 4344, Doves-> 9370
# Dead hawks             : 73
# Dead doves             : 1
# Hawk babies            : 52
# Dove babies            : 20
# Hawks                  : 31.675659909581448
# Doves                  : 68.32434009041854
# ----
# Round Processing time  : 0.02489304542541504
# Elapsed time           : 1.5827319622039795
#
# Round 85
# ROUND 85
# Food produced          : 41
# Population             : Hawks-> 4333, Doves-> 9415
# Dead hawks             : 69
# Dead doves             : 0
# Hawk babies            : 58
# Dove babies            : 45
# Hawks                  : 31.5173116089613
# Doves                  : 68.48268839103869
# ----
# Round Processing time  : 0.0279691219329834
# Elapsed time           : 1.6136927604675293
#
# Round 86
# ROUND 86
# Food produced          : 64
# Population             : Hawks-> 4395, Doves-> 9533
# Dead hawks             : 64
# Dead doves             : 0
# Hawk babies            : 126
# Dove babies            : 118
# Hawks                  : 31.555140723721998
# Doves                  : 68.44485927627801
# ----
# Round Processing time  : 0.027923107147216797
# Elapsed time           : 1.6446077823638916
#
# Round 87
# ROUND 87
# Food produced          : 30
# Population             : Hawks-> 4358, Doves-> 9558
# Dead hawks             : 86
# Dead doves             : 0
# Hawk babies            : 49
# Dove babies            : 25
# Hawks                  : 31.31647025007186
# Doves                  : 68.68352974992814
# ----
# Round Processing time  : 0.024933338165283203
# Elapsed time           : 1.6715354919433594
#
# Round 88
# ROUND 88
# Food produced          : 54
# Population             : Hawks-> 4380, Doves-> 9629
# Dead hawks             : 69
# Dead doves             : 1
# Hawk babies            : 91
# Dove babies            : 72
# Hawks                  : 31.265614961810268
# Doves                  : 68.73438503818974
# ----
# Round Processing time  : 0.025931119918823242
# Elapsed time           : 1.700458288192749
#
# Round 89
# ROUND 89
# Food produced          : 48
# Population             : Hawks-> 4407, Doves-> 9683
# Dead hawks             : 66
# Dead doves             : 2
# Hawk babies            : 93
# Dove babies            : 56
# Hawks                  : 31.27750177430802
# Doves                  : 68.72249822569198
# ----
# Round Processing time  : 0.0269315242767334
# Elapsed time           : 1.7303812503814697
#
# Round 90
# ROUND 90
# Food produced          : 39
# Population             : Hawks-> 4420, Doves-> 9714
# Dead hawks             : 72
# Dead doves             : 1
# Hawk babies            : 85
# Dove babies            : 32
# Hawks                  : 31.27210980614122
# Doves                  : 68.72789019385877
# ----
# Round Processing time  : 0.02991795539855957
# Elapsed time           : 1.7622957229614258
#
# Round 91
# ROUND 91
# Food produced          : 61
# Population             : Hawks-> 4464, Doves-> 9825
# Dead hawks             : 84
# Dead doves             : 2
# Hawk babies            : 128
# Dove babies            : 113
# Hawks                  : 31.240814612639095
# Doves                  : 68.75918538736092
# ----
# Round Processing time  : 0.026933908462524414
# Elapsed time           : 1.7922134399414062
#
# Round 92
# ROUND 92
# Food produced          : 64
# Population             : Hawks-> 4543, Doves-> 9942
# Dead hawks             : 55
# Dead doves             : 1
# Hawk babies            : 134
# Dove babies            : 118
# Hawks                  : 31.363479461511908
# Doves                  : 68.63652053848809
# ----
# Round Processing time  : 0.02593255043029785
# Elapsed time           : 1.8211383819580078
#
# Round 93
# ROUND 93
# Food produced          : 47
# Population             : Hawks-> 4579, Doves-> 9996
# Dead hawks             : 60
# Dead doves             : 1
# Hawk babies            : 96
# Dove babies            : 55
# Hawks                  : 31.41680960548885
# Doves                  : 68.58319039451115
# ----
# Round Processing time  : 0.027926206588745117
# Elapsed time           : 1.852052927017212
#
# Round 94
# ROUND 94
# Food produced          : 27
# Population             : Hawks-> 4533, Doves-> 10013
# Dead hawks             : 88
# Dead doves             : 0
# Hawk babies            : 42
# Dove babies            : 17
# Hawks                  : 31.163206379760762
# Doves                  : 68.83679362023925
# ----
# Round Processing time  : 0.02692866325378418
# Elapsed time           : 1.8849589824676514
#
# Round 95
# ROUND 95
# Food produced          : 41
# Population             : Hawks-> 4524, Doves-> 10042
# Dead hawks             : 86
# Dead doves             : 0
# Hawk babies            : 77
# Dove babies            : 29
# Hawks                  : 31.058629685569134
# Doves                  : 68.94137031443086
# ----
# Round Processing time  : 0.02693486213684082
# Elapsed time           : 1.914879322052002
#
# Round 96
# ROUND 96
# Food produced          : 54
# Population             : Hawks-> 4557, Doves-> 10110
# Dead hawks             : 66
# Dead doves             : 1
# Hawk babies            : 99
# Dove babies            : 69
# Hawks                  : 31.069748414808757
# Doves                  : 68.93025158519124
# ----
# Round Processing time  : 0.02594280242919922
# Elapsed time           : 1.94380784034729
#
# Round 97
# ROUND 97
# Food produced          : 26
# Population             : Hawks-> 4501, Doves-> 10119
# Dead hawks             : 81
# Dead doves             : 2
# Hawk babies            : 25
# Dove babies            : 11
# Hawks                  : 30.786593707250343
# Doves                  : 69.21340629274965
# ----
# Round Processing time  : 0.029920339584350586
# Elapsed time           : 1.975722312927246
#
# Round 98
# ROUND 98
# Food produced          : 38
# Population             : Hawks-> 4466, Doves-> 10139
# Dead hawks             : 90
# Dead doves             : 2
# Hawk babies            : 55
# Dove babies            : 22
# Hawks                  : 30.578568983224923
# Doves                  : 69.42143101677509
# ----
# Round Processing time  : 0.027925491333007812
# Elapsed time           : 2.006633758544922
#
# Round 99
# ROUND 99
# Food produced          : 66
# Population             : Hawks-> 4522, Doves-> 10235
# Dead hawks             : 79
# Dead doves             : 4
# Hawk babies            : 135
# Dove babies            : 100
# Hawks                  : 30.643084637799014
# Doves                  : 69.356915362201
# ----
# Round Processing time  : 0.02693486213684082
# Elapsed time           : 2.036561965942383
#
# Round 100
# ROUND 100
# Food produced          : 31
# Population             : Hawks-> 4486, Doves-> 10247
# Dead hawks             : 78
# Dead doves             : 5
# Hawk babies            : 42
# Dove babies            : 17
# Hawks                  : 30.448652684449872
# Doves                  : 69.55134731555013
# ----
# Round Processing time  : 0.026926517486572266
# Elapsed time           : 2.066473960876465
#
# Round 101
# ROUND 101
# Food produced          : 30
# Population             : Hawks-> 4426, Doves-> 10264
# Dead hawks             : 105
# Dead doves             : 1
# Hawk babies            : 45
# Dove babies            : 18
# Hawks                  : 30.12933968686181
# Doves                  : 69.87066031313819
# ----
# Round Processing time  : 0.02892923355102539
# Elapsed time           : 2.0973572731018066
#
# Round 102
# ROUND 102
# Food produced          : 70
# Population             : Hawks-> 4492, Doves-> 10375
# Dead hawks             : 64
# Dead doves             : 1
# Hawk babies            : 130
# Dove babies            : 112
# Hawks                  : 30.21456918006323
# Doves                  : 69.78543081993678
# ----
# Round Processing time  : 0.027966737747192383
# Elapsed time           : 2.1282901763916016
#
# Round 103
# ROUND 103
# Food produced          : 44
# Population             : Hawks-> 4479, Doves-> 10415
# Dead hawks             : 84
# Dead doves             : 4
# Hawk babies            : 71
# Dove babies            : 44
# Hawks                  : 30.07251242110917
# Doves                  : 69.92748757889082
# ----
# Round Processing time  : 0.027951955795288086
# Elapsed time           : 2.1602344512939453
#
# Round 104
# ROUND 104
# Food produced          : 62
# Population             : Hawks-> 4545, Doves-> 10517
# Dead hawks             : 58
# Dead doves             : 2
# Hawk babies            : 124
# Dove babies            : 104
# Hawks                  : 30.17527552781835
# Doves                  : 69.82472447218166
# ----
# Round Processing time  : 0.02692270278930664
# Elapsed time           : 2.190157175064087
#
# Round 105
# ROUND 105
# Food produced          : 50
# Population             : Hawks-> 4557, Doves-> 10571
# Dead hawks             : 70
# Dead doves             : 0
# Hawk babies            : 82
# Dove babies            : 54
# Hawks                  : 30.122950819672127
# Doves                  : 69.87704918032787
# ----
# Round Processing time  : 0.028914213180541992
# Elapsed time           : 2.2220640182495117
#
# Round 106
# ROUND 106
# Food produced          : 41
# Population             : Hawks-> 4536, Doves-> 10601
# Dead hawks             : 76
# Dead doves             : 4
# Hawk babies            : 55
# Dove babies            : 34
# Hawks                  : 29.96630772279844
# Doves                  : 70.03369227720155
# ----
# Round Processing time  : 0.02792501449584961
# Elapsed time           : 2.252981185913086
#
# Round 107
# ROUND 107
# Food produced          : 57
# Population             : Hawks-> 4557, Doves-> 10675
# Dead hawks             : 59
# Dead doves             : 1
# Hawk babies            : 80
# Dove babies            : 75
# Hawks                  : 29.917279411764707
# Doves                  : 70.08272058823529
# ----
# Round Processing time  : 0.027927160263061523
# Elapsed time           : 2.2829010486602783
#
# Round 108
# ROUND 108
# Food produced          : 39
# Population             : Hawks-> 4558, Doves-> 10702
# Dead hawks             : 78
# Dead doves             : 4
# Hawk babies            : 79
# Dove babies            : 31
# Hawks                  : 29.868938401048496
# Doves                  : 70.1310615989515
# ----
# Round Processing time  : 0.027925729751586914
# Elapsed time           : 2.31381893157959
#
# Round 109
# ROUND 109
# Food produced          : 30
# Population             : Hawks-> 4509, Doves-> 10715
# Dead hawks             : 84
# Dead doves             : 8
# Hawk babies            : 35
# Dove babies            : 21
# Hawks                  : 29.61770888071466
# Doves                  : 70.38229111928533
# ----
# Round Processing time  : 0.02991962432861328
# Elapsed time           : 2.3467307090759277
#
# Round 110
# ROUND 110
# Food produced          : 53
# Population             : Hawks-> 4552, Doves-> 10759
# Dead hawks             : 68
# Dead doves             : 7
# Hawk babies            : 111
# Dove babies            : 51
# Hawks                  : 29.73025929070603
# Doves                  : 70.26974070929397
# ----
# Round Processing time  : 0.03490900993347168
# Elapsed time           : 2.3846287727355957
#
# Round 111
# ROUND 111
# Food produced          : 51
# Population             : Hawks-> 4577, Doves-> 10803
# Dead hawks             : 63
# Dead doves             : 11
# Hawk babies            : 88
# Dove babies            : 55
# Hawks                  : 29.759427828348507
# Doves                  : 70.2405721716515
# ----
# Round Processing time  : 0.026930570602416992
# Elapsed time           : 2.4155406951904297
#
# Round 112
# ROUND 112
# Food produced          : 62
# Population             : Hawks-> 4666, Doves-> 10876
# Dead hawks             : 46
# Dead doves             : 6
# Hawk babies            : 135
# Dove babies            : 79
# Hawks                  : 30.021876206408443
# Doves                  : 69.97812379359156
# ----
# Round Processing time  : 0.027933120727539062
# Elapsed time           : 2.4464645385742188
#
# Round 113
# ROUND 113
# Food produced          : 70
# Population             : Hawks-> 4798, Doves-> 10959
# Dead hawks             : 56
# Dead doves             : 11
# Hawk babies            : 188
# Dove babies            : 94
# Hawks                  : 30.449958748492733
# Doves                  : 69.55004125150727
# ----
# Round Processing time  : 0.028923988342285156
# Elapsed time           : 2.478379011154175
#
# Round 114
# ROUND 114
# Food produced          : 60
# Population             : Hawks-> 4885, Doves-> 11050
# Dead hawks             : 65
# Dead doves             : 8
# Hawk babies            : 152
# Dove babies            : 99
# Hawks                  : 30.65578914339504
# Doves                  : 69.34421085660496
# ----
# Round Processing time  : 0.028924226760864258
# Elapsed time           : 2.510294198989868
#
# Round 115
# ROUND 115
# Food produced          : 35
# Population             : Hawks-> 4870, Doves-> 11058
# Dead hawks             : 75
# Dead doves             : 12
# Hawk babies            : 60
# Dove babies            : 20
# Hawks                  : 30.575087895529883
# Doves                  : 69.42491210447011
# ----
# Round Processing time  : 0.028923511505126953
# Elapsed time           : 2.542208194732666
#
# Round 116
# ROUND 116
# Food produced          : 61
# Population             : Hawks-> 4972, Doves-> 11137
# Dead hawks             : 45
# Dead doves             : 1
# Hawk babies            : 147
# Dove babies            : 80
# Hawks                  : 30.864733999627536
# Doves                  : 69.13526600037247
# ----
# Round Processing time  : 0.030917882919311523
# Elapsed time           : 2.5761168003082275
#
# Round 117
# ROUND 117
# Food produced          : 43
# Population             : Hawks-> 4953, Doves-> 11165
# Dead hawks             : 91
# Dead doves             : 16
# Hawk babies            : 72
# Dove babies            : 44
# Hawks                  : 30.72961905943665
# Doves                  : 69.27038094056334
# ----
# Round Processing time  : 0.02992081642150879
# Elapsed time           : 2.6099853515625
#
# Round 118
# ROUND 118
# Food produced          : 68
# Population             : Hawks-> 5057, Doves-> 11280
# Dead hawks             : 51
# Dead doves             : 10
# Hawk babies            : 155
# Dove babies            : 125
# Hawks                  : 30.95427557079023
# Doves                  : 69.04572442920977
# ----
# Round Processing time  : 0.029954195022583008
# Elapsed time           : 2.642944097518921
#
# Round 119
# ROUND 119
# Food produced          : 34
# Population             : Hawks-> 5043, Doves-> 11298
# Dead hawks             : 68
# Dead doves             : 2
# Hawk babies            : 54
# Dove babies            : 20
# Hawks                  : 30.86102441711034
# Doves                  : 69.13897558288966
# ----
# Round Processing time  : 0.029907941818237305
# Elapsed time           : 2.6758437156677246
#
# Round 120
# ROUND 120
# Food produced          : 52
# Population             : Hawks-> 5080, Doves-> 11341
# Dead hawks             : 65
# Dead doves             : 4
# Hawk babies            : 102
# Dove babies            : 47
# Hawks                  : 30.93599658973266
# Doves                  : 69.06400341026733
# ----
# Round Processing time  : 0.030916929244995117
# Elapsed time           : 2.709768295288086
#
# Round 121
# ROUND 121
# Food produced          : 37
# Population             : Hawks-> 5047, Doves-> 11360
# Dead hawks             : 81
# Dead doves             : 6
# Hawk babies            : 48
# Dove babies            : 25
# Hawks                  : 30.761260437618088
# Doves                  : 69.23873956238191
# ----
# Round Processing time  : 0.02891087532043457
# Elapsed time           : 2.7416677474975586
#
# Round 122
# ROUND 122
# Food produced          : 65
# Population             : Hawks-> 5112, Doves-> 11446
# Dead hawks             : 78
# Dead doves             : 7
# Hawk babies            : 143
# Dove babies            : 93
# Hawks                  : 30.87329387607199
# Doves                  : 69.126706123928
# ----
# Round Processing time  : 0.02892756462097168
# Elapsed time           : 2.7735488414764404
#
# Round 123
# ROUND 123
# Food produced          : 34
# Population             : Hawks-> 5083, Doves-> 11452
# Dead hawks             : 78
# Dead doves             : 13
# Hawk babies            : 49
# ...
# Hawk babies            : 23
# Dove babies            : 8
# Hawks                  : 29.18817171655838
# Doves                  : 70.81182828344161
# ----
# Round Processing time  : 0.041886091232299805
# Elapsed time           : 6.559513807296753
#
# Round 212
# ROUND 212
# Food produced          : 51
# Population             : Hawks-> 4817, Doves-> 11661
# Dead hawks             : 72
# Dead doves             : 29
# Hawk babies            : 82
# Dove babies            : 28
# Hawks                  : 29.232916616094183
# Doves                  : 70.76708338390581
# ----
# Round Processing time  : 0.04093313217163086
# Elapsed time           : 6.606427431106567
#
# Round 213
# ROUND 213
# Food produced          : 27
# Population             : Hawks-> 4753, Doves-> 11643
# Dead hawks             : 91
# Dead doves             : 25
# Hawk babies            : 27
# Dove babies            : 7
# Hawks                  : 28.988777750670895
# Doves                  : 71.01122224932911
# ----
# Round Processing time  : 0.043843984603881836
# Elapsed time           : 6.656256675720215
#
# Round 214
# ROUND 214
# Food produced          : 68
# Population             : Hawks-> 4799, Doves-> 11650
# Dead hawks             : 76
# Dead doves             : 34
# Hawk babies            : 122
# Dove babies            : 41
# Hawks                  : 29.175025837436923
# Doves                  : 70.82497416256307
# ----
# Round Processing time  : 0.04288458824157715
# Elapsed time           : 6.704128742218018
#
# Round 215
# ROUND 215
# Food produced          : 58
# Population             : Hawks-> 4848, Doves-> 11655
# Dead hawks             : 63
# Dead doves             : 37
# Hawk babies            : 112
# Dove babies            : 42
# Hawks                  : 29.376477004181055
# Doves                  : 70.62352299581894
# ----
# Round Processing time  : 0.042885541915893555
# Elapsed time           : 6.753032922744751
#
# Round 216
# ROUND 216
# Food produced          : 31
# Population             : Hawks-> 4802, Doves-> 11626
# Dead hawks             : 82
# Dead doves             : 44
# Hawk babies            : 36
# Dove babies            : 15
# Hawks                  : 29.23058193328464
# Doves                  : 70.76941806671536
# ----
# Round Processing time  : 0.041893959045410156
# Elapsed time           : 6.800869941711426
#
# Round 217
# ROUND 217
# Food produced          : 54
# Population             : Hawks-> 4811, Doves-> 11625
# Dead hawks             : 74
# Dead doves             : 42
# Hawk babies            : 83
# Dove babies            : 41
# Hawks                  : 29.27111219274763
# Doves                  : 70.72888780725238
# ----
# Round Processing time  : 0.04291892051696777
# Elapsed time           : 6.849812984466553
#
# Round 218
# ROUND 218
# Food produced          : 29
# Population             : Hawks-> 4768, Doves-> 11592
# Dead hawks             : 81
# Dead doves             : 38
# Hawk babies            : 38
# Dove babies            : 5
# Hawks                  : 29.144254278728603
# Doves                  : 70.85574572127139
# ----
# Round Processing time  : 0.04285025596618652
# Elapsed time           : 6.898608446121216
#
# Round 219
# ROUND 219
# Food produced          : 41
# Population             : Hawks-> 4757, Doves-> 11573
# Dead hawks             : 85
# Dead doves             : 33
# Hawk babies            : 74
# Dove babies            : 14
# Hawks                  : 29.130434782608695
# Doves                  : 70.86956521739131
# ----
# Round Processing time  : 0.042885780334472656
# Elapsed time           : 6.947518825531006
#
# Round 220
# ROUND 220
# Food produced          : 44
# Population             : Hawks-> 4746, Doves-> 11554
# Dead hawks             : 85
# Dead doves             : 31
# Hawk babies            : 74
# Dove babies            : 12
# Hawks                  : 29.116564417177916
# Doves                  : 70.88343558282209
# ----
# Round Processing time  : 0.04886341094970703
# Elapsed time           : 7.00233006477356
#
# Round 221
# ROUND 221
# Food produced          : 59
# Population             : Hawks-> 4781, Doves-> 11554
# Dead hawks             : 55
# Dead doves             : 37
# Hawk babies            : 90
# Dove babies            : 37
# Hawks                  : 29.268441995714724
# Doves                  : 70.73155800428528
# ----
# Round Processing time  : 0.041931867599487305
# Elapsed time           : 7.050215482711792
#
# Round 222
# ROUND 222
# Food produced          : 38
# Population             : Hawks-> 4765, Doves-> 11525
# Dead hawks             : 77
# Dead doves             : 46
# Hawk babies            : 61
# Dove babies            : 17
# Hawks                  : 29.251074278698585
# Doves                  : 70.74892572130142
# ----
# Round Processing time  : 0.04291391372680664
# Elapsed time           : 7.099107503890991
#
# Round 223
# ROUND 223
# Food produced          : 70
# Population             : Hawks-> 4844, Doves-> 11550
# Dead hawks             : 51
# Dead doves             : 32
# Hawk babies            : 130
# Dove babies            : 57
# Hawks                  : 29.54739538855679
# Doves                  : 70.45260461144322
# ----
# Round Processing time  : 0.041893959045410156
# Elapsed time           : 7.146979331970215
#
# Round 224
# ROUND 224
# Food produced          : 36
# Population             : Hawks-> 4813, Doves-> 11526
# Dead hawks             : 80
# Dead doves             : 42
# Hawk babies            : 49
# Dove babies            : 18
# Hawks                  : 29.45712711916274
# Doves                  : 70.54287288083727
# ----
# Round Processing time  : 0.04189491271972656
# Elapsed time           : 7.1928551197052
#
# Round 225
# ROUND 225
# Food produced          : 66
# Population             : Hawks-> 4886, Doves-> 11538
# Dead hawks             : 70
# Dead doves             : 36
# Hawk babies            : 143
# Dove babies            : 48
# Hawks                  : 29.749147588894303
# Doves                  : 70.2508524111057
# ----
# Round Processing time  : 0.045874595642089844
# Elapsed time           : 7.244708299636841
#
# Round 226
# ROUND 226
# Food produced          : 67
# Population             : Hawks-> 4979, Doves-> 11580
# Dead hawks             : 68
# Dead doves             : 29
# Hawk babies            : 161
# Dove babies            : 71
# Hawks                  : 30.068240835799266
# Doves                  : 69.93175916420074
# ----
# Round Processing time  : 0.04385638236999512
# Elapsed time           : 7.29459285736084
#
# Round 227
# ROUND 227
# Food produced          : 41
# Population             : Hawks-> 4978, Doves-> 11564
# Dead hawks             : 68
# Dead doves             : 39
# Hawk babies            : 67
# Dove babies            : 23
# Hawks                  : 30.093096360778627
# Doves                  : 69.90690363922137
# ----
# Round Processing time  : 0.04387974739074707
# Elapsed time           : 7.343459844589233
#
# Round 228
# ROUND 228
# Food produced          : 38
# Population             : Hawks-> 4945, Doves-> 11549
# Dead hawks             : 92
# Dead doves             : 37
# Hawk babies            : 59
# Dove babies            : 22
# Hawks                  : 29.980599005699045
# Doves                  : 70.01940099430097
# ----
# Round Processing time  : 0.04188799858093262
# Elapsed time           : 7.390331029891968
#
# Round 229
# ROUND 229
# Food produced          : 63
# Population             : Hawks-> 4970, Doves-> 11563
# Dead hawks             : 81
# Dead doves             : 24
# Hawk babies            : 106
# Dove babies            : 38
# Hawks                  : 30.06108994132946
# Doves                  : 69.93891005867053
# ----
# Round Processing time  : 0.04288911819458008
# Elapsed time           : 7.439161539077759
#
# Round 230
# ROUND 230
# Food produced          : 26
# Population             : Hawks-> 4909, Doves-> 11541
# Dead hawks             : 83
# Dead doves             : 27
# Hawk babies            : 22
# Dove babies            : 5
# Hawks                  : 29.841945288753802
# Doves                  : 70.1580547112462
# ----
# Round Processing time  : 0.042926788330078125
# Elapsed time           : 7.49002742767334
#
# Round 231
# ROUND 231
# Food produced          : 52
# Population             : Hawks-> 4938, Doves-> 11549
# Dead hawks             : 73
# Dead doves             : 24
# Hawk babies            : 102
# Dove babies            : 32
# Hawks                  : 29.950870382725785
# Doves                  : 70.04912961727422
# ----
# Round Processing time  : 0.044913530349731445
# Elapsed time           : 7.540925741195679
#
# Round 232
# ROUND 232
# Food produced          : 66
# Population             : Hawks-> 5009, Doves-> 11552
# Dead hawks             : 61
# Dead doves             : 39
# Hawk babies            : 132
# Dove babies            : 42
# Hawks                  : 30.245758106394543
# Doves                  : 69.75424189360547
# ----
# Round Processing time  : 0.04085493087768555
# Elapsed time           : 7.587766885757446
#
# Round 233
# ROUND 233
# Food produced          : 33
# Population             : Hawks-> 4966, Doves-> 11531
# Dead hawks             : 82
# Dead doves             : 41
# Hawk babies            : 39
# Dove babies            : 20
# Hawks                  : 30.102442868400313
# Doves                  : 69.89755713159968
# ----
# Round Processing time  : 0.04288291931152344
# Elapsed time           : 7.635673761367798
#
# Round 234
# ROUND 234
# Food produced          : 40
# Population             : Hawks-> 4940, Doves-> 11521
# Dead hawks             : 86
# Dead doves             : 34
# Hawk babies            : 60
# Dove babies            : 24
# Hawks                  : 30.010327440617218
# Doves                  : 69.98967255938278
# ----
# Round Processing time  : 0.04486370086669922
# Elapsed time           : 7.687499046325684
#
# Round 235
# ROUND 235
# Food produced          : 66
# Population             : Hawks-> 5034, Doves-> 11543
# Dead hawks             : 61
# Dead doves             : 23
# Hawk babies            : 155
# Dove babies            : 45
# Hawks                  : 30.36737648549195
# Doves                  : 69.63262351450805
# ----
# Round Processing time  : 0.04392075538635254
# Elapsed time           : 7.73640251159668
#
# Round 236
# ROUND 236
# Food produced          : 39
# Population             : Hawks-> 5015, Doves-> 11539
# Dead hawks             : 76
# Dead doves             : 19
# Hawk babies            : 57
# Dove babies            : 15
# Hawks                  : 30.294792799323428
# Doves                  : 69.70520720067658
# ----
# Round Processing time  : 0.04487943649291992
# Elapsed time           : 7.787232160568237
#
# Round 237
# ROUND 237
# Food produced          : 68
# Population             : Hawks-> 5099, Doves-> 11573
# Dead hawks             : 54
# Dead doves             : 35
# Hawk babies            : 138
# Dove babies            : 69
# Hawks                  : 30.58421305182342
# Doves                  : 69.41578694817659
# ----
# Round Processing time  : 0.03693580627441406
# Elapsed time           : 7.827159643173218
#
# Round 238
# ROUND 238
# Food produced          : 33
# Population             : Hawks-> 5066, Doves-> 11559
# Dead hawks             : 83
# Dead doves             : 30
# Hawk babies            : 50
# Dove babies            : 16
# Hawks                  : 30.472180451127816
# Doves                  : 69.52781954887219
# ----
# Round Processing time  : 0.030009984970092773
# Elapsed time           : 7.860162258148193
#
# Round 239
# ROUND 239
# Food produced          : 49
# Population             : Hawks-> 5069, Doves-> 11537
# Dead hawks             : 71
# Dead doves             : 47
# Hawk babies            : 74
# Dove babies            : 25
# Hawks                  : 30.525111405516082
# Doves                  : 69.47488859448391
# ----
# Round Processing time  : 0.03591036796569824
# Elapsed time           : 7.8990583419799805
#
# Round 240
# ROUND 240
# Food produced          : 53
# Population             : Hawks-> 5104, Doves-> 11540
# Dead hawks             : 64
# Dead doves             : 30
# Hawk babies            : 99
# Dove babies            : 33
# Hawks                  : 30.66570535928863
# Doves                  : 69.33429464071136
# ----
# Round Processing time  : 0.030924081802368164
# Elapsed time           : 7.932932615280151
#
# Round 241
# ROUND 241
# Food produced          : 49
# Population             : Hawks-> 5111, Doves-> 11525
# Dead hawks             : 70
# Dead doves             : 39
# Hawk babies            : 77
# Dove babies            : 24
# Hawks                  : 30.72252945419572
# Doves                  : 69.27747054580428
# ----
# Round Processing time  : 0.030951976776123047
# Elapsed time           : 7.966885566711426
#
# Round 242
# ROUND 242
# Food produced          : 60
# Population             : Hawks-> 5156, Doves-> 11524
# Dead hawks             : 69
# Dead doves             : 38
# Hawk babies            : 114
# Dove babies            : 37
# Hawks                  : 30.91127098321343
# Doves                  : 69.08872901678656
# ----
# Round Processing time  : 0.032921791076660156
# Elapsed time           : 8.003746509552002
#
# Round 243
# ROUND 243
# Food produced          : 47
# Population             : Hawks-> 5179, Doves-> 11524
# Dead hawks             : 76
# Dead doves             : 37
# Hawk babies            : 99
# Dove babies            : 37
# Hawks                  : 31.00640603484404
# Doves                  : 68.99359396515597
# ----
# Round Processing time  : 0.03095412254333496
# Elapsed time           : 8.037695169448853
#
# Round 244
# ROUND 244
# Food produced          : 70
# Population             : Hawks-> 5269, Doves-> 11568
# Dead hawks             : 77
# Dead doves             : 17
# Hawk babies            : 167
# Dove babies            : 61
# Hawks                  : 31.29417354635624
# Doves                  : 68.70582645364377
# ----
# Round Processing time  : 0.030916213989257812
# Elapsed time           : 8.071562051773071
#
# Round 245
# ROUND 245
# Food produced          : 29
# Population             : Hawks-> 5200, Doves-> 11544
# Dead hawks             : 107
# Dead doves             : 37
# Hawk babies            : 38
# Dove babies            : 13
# Hawks                  : 31.05590062111801
# Doves                  : 68.94409937888199
# ----
# Round Processing time  : 0.03005671501159668
# Elapsed time           : 8.104617357254028
#
# Round 246
# ROUND 246
# Food produced          : 27
# Population             : Hawks-> 5150, Doves-> 11519
# Dead hawks             : 88
# Dead doves             : 32
# Hawk babies            : 38
# Dove babies            : 7
# Hawks                  : 30.89567460555522
# Doves                  : 69.10432539444477
# ----
# Round Processing time  : 0.034906625747680664
# Elapsed time           : 8.14251160621643
#
# Round 247
# ROUND 247
# Food produced          : 56
# Population             : Hawks-> 5176, Doves-> 11510
# Dead hawks             : 84
# Dead doves             : 39
# Hawk babies            : 110
# Dove babies            : 30
# Hawks                  : 31.020016780534583
# Doves                  : 68.97998321946542
# ----
# Round Processing time  : 0.031919002532958984
# Elapsed time           : 8.177382469177246
#
# Round 248
# ROUND 248
# Food produced          : 63
# Population             : Hawks-> 5218, Doves-> 11519
# Dead hawks             : 67
# Dead doves             : 42
# Hawk babies            : 109
# Dove babies            : 51
# Hawks                  : 31.176435442432933
# Doves                  : 68.82356455756707
# ----
# Round Processing time  : 0.03195476531982422
# Elapsed time           : 8.212341070175171
#
# Round 249
# ROUND 249
# Food produced          : 28
# Population             : Hawks-> 5171, Doves-> 11503
# Dead hawks             : 85
# Dead doves             : 26
# Hawk babies            : 38
# Dove babies            : 10
# Hawks                  : 31.012354563991845
# Doves                  : 68.98764543600817
# ----
# Round Processing time  : 0.0319056510925293
# Elapsed time           : 8.247241258621216
#
# Round 250
# ROUND 250
# Food produced          : 26
# Population             : Hawks-> 5111, Doves-> 11470
# Dead hawks             : 85
# Dead doves             : 38
# Hawk babies            : 25
# Dove babies            : 5
# Hawks                  : 30.82443760931186
# Doves                  : 69.17556239068814
# ----
# Round Processing time  : 0.02991628646850586
# Elapsed time           : 8.280142307281494
#
# =============================================================
# Total dead agents      : 21243
# Total breeding agents  : 35824
# Total rounds completed : 250
# Total population size  : 16581
# Hawks                  : 30.82443760931186
# Doves                  : 69.17556239068814
# Processing time        : 8.280142307281494
# =============================================================

# %%
npdove = np.array(graph_dove_points)
nphawk = np.array(graph_hawk_points)
npdovePer = npdove / (npdove + nphawk)
nphawkPer = nphawk / (npdove + nphawk)
nppopulation = nphawk + npdove
nppopulation = nppopulation/np.max(nppopulation)

# %%
plt.clf()
plt.plot(npdovePer, color = "purple", label = "Dove fraction")
plt.plot(nphawkPer, color = "coral", label = "Hawk fraction")
plt.plot(nppopulation, label = "Population")
MSNE = game().findMSNE()
plt.axhline(y=MSNE[0][0],color = 'red', linestyle='--', label = "Hawk in MSNE")
plt.axhline(y=MSNE[0][1],color = 'purple', linestyle='--', label = "Dove in MSNE")
plt.legend()



plt.show()

# %%
print(MSNE)
# Out:
# [array([0.2962963, 0.7037037]), array([0.2962963, 0.7037037])]

# %%
a = [1, 2, 3]
for x in reversed(a):
    print(( x))
    a.remove(x)
# Out:
# 3
# 2
# 1

# %%
a
# Out:
# []
