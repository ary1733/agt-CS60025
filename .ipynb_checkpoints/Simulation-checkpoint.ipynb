# %% [markdown]
# # Imports for Simulation and Visualization

# %%
from random import randint, shuffle
import time
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Class Game
# - Attributes
#     - PayoffMatrix
#         : Payoff Matrix of two player Game
# - Methods
#     - findSDSE
#         : Computes Strong Dominant Strategy Equilibrium if it exists.
#     - findMSNE
#         : Computes MSNE using indifference priciple.

# %%
class game:
    def __init__(self):
        food = (MAX_FOOD_PER_ROUND + MIN_FOOD_PER_ROUND)//2
        self.payoffMatrix = [ 
                            [[(food//2) - ENERGY_LOSS_FROM_FIGHTING, (food//2) - ENERGY_LOSS_FROM_FIGHTING],[food,0]],
                            [[0, food],[(food//2), (food//2)]]
                            ]
#     Arguments : None, Return: list of SDSE strategy
    def findSDSE(self):
        P1 = []
        P2 = []
        if self.payoffMatrix[0][0][0] > self.payoffMatrix[1][0][0] and self.payoffMatrix[0][1][0] > self.payoffMatrix[1][1][0]:
            P1.append(0)
        if self.payoffMatrix[0][0][0] < self.payoffMatrix[1][0][0] and self.payoffMatrix[0][1][0] < self.payoffMatrix[1][1][0]:
            P1.appendp(1)
        if self.payoffMatrix[0][0][1] > self.payoffMatrix[0][1][1] and self.payoffMatrix[1][0][1] > self.payoffMatrix[1][1][1]:
            P2.append(0)
        if self.payoffMatrix[0][0][1] < self.payoffMatrix[0][1][1] and self.payoffMatrix[1][0][1] < self.payoffMatrix[1][1][1]:
            P2.append(1)
        ret = [(x, y) for x in P1 for y in P2]
        return ret

#   Arguments: None, Return list of probability distribution over strategy for player 1 and player 2
    def findMSNE(self):

        SDSE = self.findSDSE()
        p = np.zeros(2)
        q = np.zeros(2)
        if(len(SDSE) > 0):
            p[SDSE[0][0]] = 1
            q[SDSE[0][1]] = 1
            return [p,q]
        
#         row player Indifference Condition
        a = np.array([[1, 1], [self.payoffMatrix[0][0][0] - self.payoffMatrix[1][0][0], self.payoffMatrix[0][1][0] - self.payoffMatrix[1][1][0]] ])
        b = np.array([1, 0])
        q = np.linalg.solve(a, b)
        
#         col player Indifference Condition
        a = np.array([[1, 1], [self.payoffMatrix[0][0][1] - self.payoffMatrix[0][1][1], self.payoffMatrix[1][0][1] - self.payoffMatrix[1][1][1]] ])
        b = np.array([1, 0])
        p = np.linalg.solve(a, b) 
        return [p,q]

# %% [markdown]
# #### Global intitial Condtion
# 1. STARTING_DOVES
#     : The number of players who are Doves in the beginning
# 2. STARTING_HAWKS
#     : The number of players who are Hawks in the beginning
# 3. ROUNDS
#     : Number of Rounds in the simulation
# 4. STARTING_ENERGY
#     : The amount of energy with which each player starts the game.
# 5. MIN_FOOD_PER_ROUND
#     : Min energy available per food.
# 6. MAX_FOOD_PER_ROUND
#     : Max energy available per food.
# 7. MAX_FOOD_APPEARANCE
#     : Max number of food appearance per round
# 8. ENERGY_REQUIRED_FOR_REPRODUCTION
#     : Minimum energy required to reproduce
# 9. ENERGY_LOSS_PER_ROUND
#     : Energy spent for surviving a round
# 10. ENERGY_LOSS_FROM_FIGHTING
#     : Energy spent over fighting
# 11. ENERGY_REQUIRED_FOR_LIVING
#     : Minimum energy required to remain alive
#
# #### Model Formulation
#
# 1. Game Starts with gameInit(), a function which initialize all the agents. These agents are the players in this game and they can be either HAWK or DOVE.
# 2. Then rounds start, while rounds <= ROUNDS **and** Agents Remaining >=2:
#     1. Call AwakenAgents(), set the state of agent to **Awake State**.
#     2. Generate the random food for the current round.
#     3. Shuffle the agents for random pairing.
#     4. Then pair the agents and let them compete over the food, However the max number of food appearance is limited by MAX_FOOD_APPEARANCE.
#     5. Then the agents pay the cost of living a round.
#     6. Cull() is called and every agent with energy less than ENERGY_REQUIRED_FOR_LIVING is deleted from the simulation.
#     7. The remaing of the agents then reproduce if they have energy greater than ENERGY_REQUIRED_FOR_REPRODUCTION.
#     8. Data is collected stored for further analysis.
#     9. Agents Sent to sleet State.
# 3. After the simulation ends we analyze and compare the data collected with the  theoretically calculated MSNE.

# %%
STARTING_DOVES = 1000
STARTING_HAWKS = 1000
STARTING_POPULATION = STARTING_HAWKS + STARTING_DOVES

ROUNDS = 500
STARTING_ENERGY = 100

MIN_FOOD_PER_ROUND = 40
MAX_FOOD_PER_ROUND = 40
MAX_FOOD_APPEARANCE = 1000 # this tells how much max food can be found
ENERGY_REQUIRED_FOR_REPRODUCTION = 250
ENERGY_LOSS_PER_ROUND = 4
ENERGY_LOSS_FROM_FIGHTING = 60
ENERGY_REQUIRED_FOR_LIVING = 10

STATUS_ACTIVE = "active"
STATUS_ASLEEP = "asleep"

TYPE_HAWK = "hawk"
TYPE_DOVE = "dove"

agents = []

# Graph stuff
graph_hawk_points = []
graph_dove_points = []

AGENT_ID = 1
class Agent:
    
    def __init__(self, agent_type, status, energy):
        global AGENT_ID
        self.id = AGENT_ID
        AGENT_ID += 1
        self.agent_type = agent_type
        self.status = status
        self.energy = energy
    def wake(self):
        self.status = STATUS_ACTIVE
    def sleep(self):
        self.status = STATUS_ASLEEP

def gameInit():
    global agents
    agents = []
    for x in range(0,STARTING_DOVES):
        a = Agent(TYPE_DOVE, STATUS_ASLEEP, STARTING_ENERGY)
        agents.append(a)
    for x in range(0,STARTING_HAWKS):
        a = Agent(TYPE_HAWK, STATUS_ASLEEP, STARTING_ENERGY)
        agents.append(a)

def compete(agent, nemesis, food):
# add a food fuction inside agent
    if agent.agent_type == TYPE_HAWK and nemesis.agent_type == TYPE_HAWK:
        # food distributed as food // 2 and loss from fighting subtracted
        agent.energy += (food//2)
        agent.energy -= ENERGY_LOSS_FROM_FIGHTING
        nemesis.energy += (food//2)
        nemesis.energy -= ENERGY_LOSS_FROM_FIGHTING
        
    if agent.agent_type == TYPE_HAWK and nemesis.agent_type == TYPE_DOVE:
        agent.energy += food

    if agent.agent_type == TYPE_DOVE and nemesis.agent_type == TYPE_HAWK:
        nemesis.energy += food

    if agent.agent_type == TYPE_DOVE and nemesis.agent_type == TYPE_DOVE:
        agent.energy += (food//2)
        nemesis.energy += (food//2)

    nemesis.sleep()
    agent.sleep()
def cull():

    dead_hawks = 0
    dead_doves = 0
    n = len(agents)
    for index, agent in enumerate(reversed(agents)):
        if agent.energy < ENERGY_REQUIRED_FOR_LIVING:
            if agent.agent_type == TYPE_DOVE: dead_doves += 1
            if agent.agent_type == TYPE_HAWK: dead_hawks += 1
            del agents[n - index - 1]


    return dead_hawks, dead_doves
def breed():
    """
    If agent can breed, it halves its energy and produces 
    one baby with starting energy (parent energy // 2) and
    keep parent energy // 2 for itself
    """
    hawk_babies = 0
    dove_babies = 0
    for agent in agents:
        if agent.energy > ENERGY_REQUIRED_FOR_REPRODUCTION:
            baby_agent_a = Agent(agent.agent_type, STATUS_ASLEEP, (agent.energy//2))
            agents.append(baby_agent_a)

            agent.energy //= 2

            if agent.agent_type == TYPE_DOVE: dove_babies += 1
            if agent.agent_type == TYPE_HAWK: hawk_babies += 1


    return hawk_babies, dove_babies
def getCountOfType(agents):
    local_hawk_count = 0
    local_dove_count = 0
    for agent in agents:
        if agent.agent_type == TYPE_HAWK:
            local_hawk_count += 1
        else:
            local_dove_count += 1
    return local_hawk_count, local_dove_count
def getFood():
    return randint(MIN_FOOD_PER_ROUND, MAX_FOOD_PER_ROUND)
def awakenAgents():
    for agent in agents:
        agent.wake()
def SendToSleep():
    for agent in agents:
        agent.sleep()
def main():
    gameInit()

    current_round = 1
    death_count = 0
    dead_hawks  = 0
    dead_doves  = 0
    breed_count = 0
    main_tic = time.time()
    
    while current_round <= ROUNDS and len(agents) > 2:
        print(f"Round {current_round}")
        tic = time.time()
        awakenAgents()
        food = getFood()
# shuffling agents so that the matchmaking while be random
        shuffle(agents)
        for idx in range (0, len(agents), 2):
            if idx//2 > MAX_FOOD_APPEARANCE:
                break
            if idx + 1 >= len(agents):
                break
            agent, nemesis = agents[idx], agents[idx + 1]
            compete(agent, nemesis, food)

        # Energy cost of 'living'
        for agent in agents:
            agent.energy -= ENERGY_LOSS_PER_ROUND
        
        round_dead_hawks, round_dead_doves = cull()
        round_hawk_babies, round_dove_babies = breed()
        death_count += (round_dead_hawks + round_dead_doves)
        breed_count += (round_hawk_babies + round_dove_babies)
        SendToSleep()

        toc = time.time()
        # Plot
        hawk_count, dove_count = getCountOfType(agents)
        hawk_percent = (hawk_count / (hawk_count + dove_count))*100
        dove_percent = (dove_count / (hawk_count + dove_count))*100
        graph_hawk_points.append(hawk_count)
        graph_dove_points.append(dove_count)
        print("ROUND %d" % current_round)
        print("Food produced          : %d" % food)
        print(f"Population             : Hawks-> {hawk_count}, Doves-> {dove_count}")
        print("Dead hawks             : %d" % round_dead_hawks)
        print("Dead doves             : %d" % round_dead_doves)
        print("Hawk babies            : %s" % round_hawk_babies)
        print("Dove babies            : %s" % round_dove_babies)
        print("Hawks                  : %s" % hawk_percent)
        print("Doves                  : %s" % dove_percent)
        print("----")
        print("Round Processing time  : %s" % (toc - tic))
        print("Elapsed time           : %s\n" % (time.time() - main_tic))

        

        current_round += 1


    main_toc = time.time()
    hawk_count, dove_count = getCountOfType(agents)
    hawk_percent = (hawk_count / (hawk_count + dove_count))*100
    dove_percent = (dove_count / (hawk_count + dove_count))*100
    print("=============================================================")
    print("Total dead agents      : %d" % death_count)
    print("Total breeding agents  : %d" % breed_count)
    print("Total rounds completed : %d" % (current_round - 1))
    print("Total population size  : %s" % len(agents))
    print("Hawks                  : %s" % hawk_percent)
    print("Doves                  : %s" % dove_percent)
    print("Processing time        : %s" % (main_toc - main_tic))
    print("=============================================================")
main()
# Out:
# Round 1
# ROUND 1
# Food produced          : 40
# Population             : Hawks-> 1000, Doves-> 1000
# Dead hawks             : 0
# Dead doves             : 0
# Hawk babies            : 0
# Dove babies            : 0
# Hawks                  : 50.0
# Doves                  : 50.0
# ----
# Round Processing time  : 0.011025190353393555
# Elapsed time           : 0.01496434211730957
#
# Round 2
# ROUND 2
# Food produced          : 40
# Population             : Hawks-> 1000, Doves-> 1000
# Dead hawks             : 0
# Dead doves             : 0
# Hawk babies            : 0
# Dove babies            : 0
# Hawks                  : 50.0
# Doves                  : 50.0
# ----
# Round Processing time  : 0.008997917175292969
# Elapsed time           : 0.026012182235717773
#
# Round 3
# ROUND 3
# Food produced          : 40
# Population             : Hawks-> 884, Doves-> 1000
# Dead hawks             : 116
# Dead doves             : 0
# Hawk babies            : 0
# Dove babies            : 0
# Hawks                  : 46.92144373673036
# Doves                  : 53.07855626326964
# ----
# Round Processing time  : 0.008038997650146484
# Elapsed time           : 0.03648805618286133
#
# Round 4
# ROUND 4
# Food produced          : 40
# Population             : Hawks-> 689, Doves-> 1000
# Dead hawks             : 195
# Dead doves             : 0
# Hawk babies            : 0
# Dove babies            : 0
# Hawks                  : 40.79336885731202
# Doves                  : 59.20663114268798
# ----
# Round Processing time  : 0.008460283279418945
# Elapsed time           : 0.04695773124694824
#
# Round 5
# ROUND 5
# Food produced          : 40
# Population             : Hawks-> 730, Doves-> 1000
# Dead hawks             : 0
# Dead doves             : 0
# Hawk babies            : 41
# Dove babies            : 0
# Hawks                  : 42.19653179190752
# Doves                  : 57.80346820809249
# ----
# Round Processing time  : 0.007975101470947266
# Elapsed time           : 0.05694770812988281
#
# Round 6
# ROUND 6
# Food produced          : 40
# Population             : Hawks-> 668, Doves-> 1000
# Dead hawks             : 62
# Dead doves             : 0
# Hawk babies            : 0
# Dove babies            : 0
# Hawks                  : 40.04796163069545
# Doves                  : 59.95203836930456
# ----
# Round Processing time  : 0.009979963302612305
# Elapsed time           : 0.07088589668273926
#
# Round 7
# ROUND 7
# Food produced          : 40
# Population             : Hawks-> 741, Doves-> 1000
# Dead hawks             : 0
# Dead doves             : 0
# Hawk babies            : 73
# Dove babies            : 0
# Hawks                  : 42.56174612291787
# Doves                  : 57.43825387708213
# ----
# Round Processing time  : 0.01004934310913086
# Elapsed time           : 0.08281445503234863
#
# Round 8
# ROUND 8
# Food produced          : 40
# Population             : Hawks-> 691, Doves-> 1000
# Dead hawks             : 50
# Dead doves             : 0
# Hawk babies            : 0
# Dove babies            : 0
# Hawks                  : 40.86339444115908
# Doves                  : 59.13660555884093
# ----
# Round Processing time  : 0.00991511344909668
# Elapsed time           : 0.09582805633544922
#
# Round 9
# ROUND 9
# Food produced          : 40
# Population             : Hawks-> 753, Doves-> 1000
# Dead hawks             : 0
# Dead doves             : 0
# Hawk babies            : 62
# Dove babies            : 0
# Hawks                  : 42.95493439817456
# Doves                  : 57.04506560182544
# ----
# Round Processing time  : 0.010976314544677734
# Elapsed time           : 0.108795166015625
#
# Round 10
# ROUND 10
# Food produced          : 40
# Population             : Hawks-> 719, Doves-> 1002
# Dead hawks             : 36
# Dead doves             : 0
# Hawk babies            : 2
# Dove babies            : 2
# Hawks                  : 41.77803602556653
# Doves                  : 58.221963974433464
# ----
# Round Processing time  : 0.008974552154541016
# Elapsed time           : 0.12076306343078613
#
# Round 11
# ROUND 11
# Food produced          : 40
# Population             : Hawks-> 793, Doves-> 1022
# Dead hawks             : 0
# Dead doves             : 0
# Hawk babies            : 74
# Dove babies            : 20
# Hawks                  : 43.69146005509642
# Doves                  : 56.30853994490358
# ----
# Round Processing time  : 0.01063680648803711
# Elapsed time           : 0.1343836784362793
#
# Round 12
# ROUND 12
# Food produced          : 40
# Population             : Hawks-> 754, Doves-> 1052
# Dead hawks             : 40
# Dead doves             : 0
# Hawk babies            : 1
# Dove babies            : 30
# Hawks                  : 41.74972314507198
# Doves                  : 58.25027685492802
# ----
# Round Processing time  : 0.01097726821899414
# Elapsed time           : 0.14735007286071777
#
# Round 13
# ROUND 13
# Food produced          : 40
# Population             : Hawks-> 764, Doves-> 1052
# Dead hawks             : 40
# Dead doves             : 0
# Hawk babies            : 50
# Dove babies            : 0
# Hawks                  : 42.070484581497794
# Doves                  : 57.9295154185022
# ----
# Round Processing time  : 0.010956048965454102
# Elapsed time           : 0.1614234447479248
#
# Round 14
# ROUND 14
# Food produced          : 40
# Population             : Hawks-> 755, Doves-> 1088
# Dead hawks             : 30
# Dead doves             : 0
# Hawk babies            : 21
# Dove babies            : 36
# Hawks                  : 40.96581660336408
# Doves                  : 59.03418339663592
# ----
# Round Processing time  : 0.010867834091186523
# Elapsed time           : 0.1752772331237793
#
# Round 15
# ROUND 15
# Food produced          : 40
# Population             : Hawks-> 779, Doves-> 1154
# Dead hawks             : 24
# Dead doves             : 0
# Hawk babies            : 48
# Dove babies            : 66
# Hawks                  : 40.30005173305742
# Doves                  : 59.699948266942584
# ----
# Round Processing time  : 0.009926080703735352
# Elapsed time           : 0.1891951560974121
#
# Round 16
# ROUND 16
# Food produced          : 40
# Population             : Hawks-> 789, Doves-> 1245
# Dead hawks             : 25
# Dead doves             : 0
# Hawk babies            : 35
# Dove babies            : 91
# Hawks                  : 38.7905604719764
# Doves                  : 61.2094395280236
# ----
# Round Processing time  : 0.01595902442932129
# Elapsed time           : 0.2141261100769043
#
# Round 17
# ROUND 17
# Food produced          : 40
# Population             : Hawks-> 835, Doves-> 1361
# Dead hawks             : 9
# Dead doves             : 0
# Hawk babies            : 55
# Dove babies            : 116
# Hawks                  : 38.02367941712204
# Doves                  : 61.97632058287796
# ----
# Round Processing time  : 0.028653621673583984
# Elapsed time           : 0.2566707134246826
#
# Round 18
# ROUND 18
# Food produced          : 40
# Population             : Hawks-> 851, Doves-> 1361
# Dead hawks             : 23
# Dead doves             : 0
# Hawk babies            : 39
# Dove babies            : 0
# Hawks                  : 38.47197106690777
# Doves                  : 61.52802893309223
# ----
# Round Processing time  : 0.019948244094848633
# Elapsed time           : 0.28060364723205566
#
# Round 19
# ROUND 19
# Food produced          : 40
# Population             : Hawks-> 873, Doves-> 1402
# Dead hawks             : 20
# Dead doves             : 0
# Hawk babies            : 42
# Dove babies            : 41
# Hawks                  : 38.37362637362637
# Doves                  : 61.626373626373635
# ----
# Round Processing time  : 0.01491689682006836
# Elapsed time           : 0.2985553741455078
#
# Round 20
# ROUND 20
# Food produced          : 40
# Population             : Hawks-> 899, Doves-> 1494
# Dead hawks             : 17
# Dead doves             : 0
# Hawk babies            : 43
# Dove babies            : 92
# Hawks                  : 37.567906393648144
# Doves                  : 62.432093606351856
# ----
# Round Processing time  : 0.014103889465332031
# Elapsed time           : 0.3145127296447754
#
# Round 21
# ROUND 21
# Food produced          : 40
# Population             : Hawks-> 913, Doves-> 1581
# Dead hawks             : 28
# Dead doves             : 0
# Hawk babies            : 42
# Dove babies            : 87
# Hawks                  : 36.60785886126704
# Doves                  : 63.39214113873296
# ----
# Round Processing time  : 0.010617256164550781
# Elapsed time           : 0.32889842987060547
#
# Round 22
# ROUND 22
# Food produced          : 40
# Population             : Hawks-> 953, Doves-> 1656
# Dead hawks             : 14
# Dead doves             : 0
# Hawk babies            : 54
# Dove babies            : 75
# Hawks                  : 36.52740513606746
# Doves                  : 63.47259486393254
# ----
# Round Processing time  : 0.013063669204711914
# Elapsed time           : 0.34392690658569336
#
# Round 23
# ROUND 23
# Food produced          : 40
# Population             : Hawks-> 974, Doves-> 1660
# Dead hawks             : 16
# Dead doves             : 0
# Hawk babies            : 37
# Dove babies            : 4
# Hawks                  : 36.97798025816249
# Doves                  : 63.02201974183751
# ----
# Round Processing time  : 0.010941505432128906
# Elapsed time           : 0.35794758796691895
#
# Round 24
# ROUND 24
# Food produced          : 40
# Population             : Hawks-> 997, Doves-> 1698
# Dead hawks             : 20
# Dead doves             : 0
# Hawk babies            : 43
# Dove babies            : 38
# Hawks                  : 36.99443413729128
# Doves                  : 63.00556586270872
# ----
# Round Processing time  : 0.010883569717407227
# Elapsed time           : 0.37177371978759766
#
# Round 25
# ROUND 25
# Food produced          : 40
# Population             : Hawks-> 1016, Doves-> 1756
# Dead hawks             : 17
# Dead doves             : 0
# Hawk babies            : 36
# Dove babies            : 58
# Hawks                  : 36.65223665223665
# Doves                  : 63.347763347763355
# ----
# Round Processing time  : 0.011010169982910156
# Elapsed time           : 0.3847794532775879
#
# Round 26
# ROUND 26
# Food produced          : 40
# Population             : Hawks-> 1046, Doves-> 1801
# Dead hawks             : 15
# Dead doves             : 0
# Hawk babies            : 45
# Dove babies            : 45
# Hawks                  : 36.74042852125044
# Doves                  : 63.259571478749564
# ----
# Round Processing time  : 0.010968685150146484
# Elapsed time           : 0.4009523391723633
#
# Round 27
# ROUND 27
# Food produced          : 40
# Population             : Hawks-> 1064, Doves-> 1857
# Dead hawks             : 12
# Dead doves             : 0
# Hawk babies            : 30
# Dove babies            : 56
# Hawks                  : 36.425881547415266
# Doves                  : 63.57411845258473
# ----
# Round Processing time  : 0.01894688606262207
# Elapsed time           : 0.42583680152893066
#
# Round 28
# ROUND 28
# Food produced          : 40
# Population             : Hawks-> 1105, Doves-> 1887
# Dead hawks             : 17
# Dead doves             : 0
# Hawk babies            : 58
# Dove babies            : 30
# Hawks                  : 36.93181818181818
# Doves                  : 63.06818181818182
# ----
# Round Processing time  : 0.016963481903076172
# Elapsed time           : 0.4458279609680176
#
# Round 29
# ROUND 29
# Food produced          : 40
# Population             : Hawks-> 1128, Doves-> 1954
# Dead hawks             : 17
# Dead doves             : 0
# Hawk babies            : 40
# Dove babies            : 67
# Hawks                  : 36.59961064243997
# Doves                  : 63.40038935756003
# ----
# Round Processing time  : 0.015956401824951172
# Elapsed time           : 0.46477699279785156
#
# Round 30
# ROUND 30
# Food produced          : 40
# Population             : Hawks-> 1148, Doves-> 2006
# Dead hawks             : 12
# Dead doves             : 0
# Hawk babies            : 32
# Dove babies            : 52
# Hawks                  : 36.39822447685479
# Doves                  : 63.60177552314521
# ----
# Round Processing time  : 0.015923500061035156
# Elapsed time           : 0.4836902618408203
#
# Round 31
# ROUND 31
# Food produced          : 40
# Population             : Hawks-> 1165, Doves-> 2044
# Dead hawks             : 22
# Dead doves             : 0
# Hawk babies            : 39
# Dove babies            : 38
# Hawks                  : 36.30414459333126
# Doves                  : 63.69585540666874
# ----
# Round Processing time  : 0.014997243881225586
# Elapsed time           : 0.5006880760192871
#
# Round 32
# ROUND 32
# Food produced          : 40
# Population             : Hawks-> 1188, Doves-> 2095
# Dead hawks             : 18
# Dead doves             : 0
# Hawk babies            : 41
# Dove babies            : 51
# Hawks                  : 36.18641486445324
# Doves                  : 63.81358513554676
# ----
# Round Processing time  : 0.017066478729248047
# Elapsed time           : 0.5195915699005127
#
# Round 33
# ROUND 33
# Food produced          : 40
# Population             : Hawks-> 1197, Doves-> 2134
# Dead hawks             : 28
# Dead doves             : 0
# Hawk babies            : 37
# Dove babies            : 39
# Hawks                  : 35.93515460822576
# Doves                  : 64.06484539177424
# ----
# Round Processing time  : 0.017161846160888672
# Elapsed time           : 0.5405631065368652
#
# Round 34
# ROUND 34
# Food produced          : 40
# Population             : Hawks-> 1228, Doves-> 2193
# Dead hawks             : 23
# Dead doves             : 0
# Hawk babies            : 54
# Dove babies            : 59
# Hawks                  : 35.89593686056708
# Doves                  : 64.10406313943291
# ----
# Round Processing time  : 0.015954256057739258
# Elapsed time           : 0.5605080127716064
#
# Round 35
# ROUND 35
# Food produced          : 40
# Population             : Hawks-> 1256, Doves-> 2242
# Dead hawks             : 17
# Dead doves             : 0
# Hawk babies            : 45
# Dove babies            : 49
# Hawks                  : 35.906232132647226
# Doves                  : 64.09376786735277
# ----
# Round Processing time  : 0.0139617919921875
# Elapsed time           : 0.5754680633544922
#
# Round 36
# ROUND 36
# Food produced          : 40
# Population             : Hawks-> 1289, Doves-> 2267
# Dead hawks             : 15
# Dead doves             : 0
# Hawk babies            : 48
# Dove babies            : 25
# Hawks                  : 36.24859392575928
# Doves                  : 63.75140607424073
# ----
# Round Processing time  : 0.01653575897216797
# Elapsed time           : 0.5967569351196289
#
# Round 37
# ROUND 37
# Food produced          : 40
# Population             : Hawks-> 1315, Doves-> 2313
# Dead hawks             : 11
# Dead doves             : 0
# Hawk babies            : 37
# Dove babies            : 46
# Hawks                  : 36.24586549062844
# Doves                  : 63.75413450937155
# ----
# Round Processing time  : 0.02163529396057129
# Elapsed time           : 0.6283273696899414
#
# Round 38
# ROUND 38
# Food produced          : 40
# Population             : Hawks-> 1339, Doves-> 2370
# Dead hawks             : 19
# Dead doves             : 0
# Hawk babies            : 43
# Dove babies            : 57
# Hawks                  : 36.10137503370181
# Doves                  : 63.898624966298186
# ----
# Round Processing time  : 0.016956806182861328
# Elapsed time           : 0.6492831707000732
#
# Round 39
# ROUND 39
# Food produced          : 40
# Population             : Hawks-> 1363, Doves-> 2424
# Dead hawks             : 13
# Dead doves             : 0
# Hawk babies            : 37
# Dove babies            : 54
# Hawks                  : 35.99155003960919
# Doves                  : 64.0084499603908
# ----
# Round Processing time  : 0.01894211769104004
# Elapsed time           : 0.6722142696380615
#
# Round 40
# ROUND 40
# Food produced          : 40
# Population             : Hawks-> 1394, Doves-> 2471
# Dead hawks             : 14
# Dead doves             : 0
# Hawk babies            : 45
# Dove babies            : 47
# Hawks                  : 36.06727037516171
# Doves                  : 63.93272962483829
# ----
# Round Processing time  : 0.031015634536743164
# Elapsed time           : 0.7101094722747803
#
# Round 41
# ROUND 41
# Food produced          : 40
# Population             : Hawks-> 1415, Doves-> 2493
# Dead hawks             : 18
# Dead doves             : 0
# Hawk babies            : 39
# Dove babies            : 22
# Hawks                  : 36.207778915046056
# Doves                  : 63.79222108495394
# ----
# Round Processing time  : 0.038971662521362305
# Elapsed time           : 0.7520265579223633
#
# Round 42
# ROUND 42
# Food produced          : 40
# Population             : Hawks-> 1446, Doves-> 2538
# Dead hawks             : 14
# Dead doves             : 0
# Hawk babies            : 45
# Dove babies            : 45
# Hawks                  : 36.295180722891565
# Doves                  : 63.704819277108435
# ----
# Round Processing time  : 0.014983654022216797
# Elapsed time           : 0.7690012454986572
#
# Round 43
# ROUND 43
# Food produced          : 40
# Population             : Hawks-> 1463, Doves-> 2582
# Dead hawks             : 17
# Dead doves             : 0
# Hawk babies            : 34
# Dove babies            : 44
# Hawks                  : 36.16810877626699
# Doves                  : 63.83189122373301
# ----
# Round Processing time  : 0.014962196350097656
# Elapsed time           : 0.7869553565979004
#
# Round 44
# ROUND 44
# Food produced          : 40
# Population             : Hawks-> 1492, Doves-> 2637
# Dead hawks             : 14
# Dead doves             : 0
# Hawk babies            : 43
# Dove babies            : 55
# Hawks                  : 36.13465730201017
# Doves                  : 63.865342697989824
# ----
# Round Processing time  : 0.015970706939697266
# Elapsed time           : 0.8069026470184326
#
# Round 45
# ROUND 45
# Food produced          : 40
# Population             : Hawks-> 1519, Doves-> 2681
# Dead hawks             : 15
# Dead doves             : 0
# Hawk babies            : 42
# Dove babies            : 44
# Hawks                  : 36.16666666666667
# Doves                  : 63.83333333333333
# ----
# Round Processing time  : 0.01994776725769043
# Elapsed time           : 0.8297884464263916
#
# Round 46
# ROUND 46
# Food produced          : 40
# Population             : Hawks-> 1556, Doves-> 2701
# Dead hawks             : 11
# Dead doves             : 0
# Hawk babies            : 48
# Dove babies            : 20
# Hawks                  : 36.551562132957486
# Doves                  : 63.448437867042514
# ----
# Round Processing time  : 0.023158788681030273
# Elapsed time           : 0.8559279441833496
#
# Round 47
# ROUND 47
# Food produced          : 40
# Population             : Hawks-> 1571, Doves-> 2741
# Dead hawks             : 34
# Dead doves             : 0
# Hawk babies            : 49
# Dove babies            : 40
# Hawks                  : 36.43320964749536
# Doves                  : 63.56679035250464
# ----
# Round Processing time  : 0.014904975891113281
# Elapsed time           : 0.8747086524963379
#
# Round 48
# ROUND 48
# Food produced          : 40
# Population             : Hawks-> 1593, Doves-> 2779
# Dead hawks             : 21
# Dead doves             : 0
# Hawk babies            : 43
# Dove babies            : 38
# Hawks                  : 36.43641354071363
# Doves                  : 63.56358645928637
# ----
# Round Processing time  : 0.014972448348999023
# Elapsed time           : 0.8926734924316406
#
# Round 49
# ROUND 49
# Food produced          : 40
# Population             : Hawks-> 1606, Doves-> 2821
# Dead hawks             : 24
# Dead doves             : 0
# Hawk babies            : 37
# Dove babies            : 42
# Hawks                  : 36.277388750847074
# Doves                  : 63.722611249152926
# ----
# Round Processing time  : 0.015956640243530273
# Elapsed time           : 0.9126169681549072
#
# Round 50
# ROUND 50
# Food produced          : 40
# Population             : Hawks-> 1633, Doves-> 2856
# Dead hawks             : 18
# Dead doves             : 0
# Hawk babies            : 45
# Dove babies            : 35
# Hawks                  : 36.37781243038539
# Doves                  : 63.62218756961462
# ----
# Round Processing time  : 0.01513814926147461
# Elapsed time           : 0.931556224822998
#
# Round 51
# ROUND 51
# Food produced          : 40
# Population             : Hawks-> 1650, Doves-> 2873
# Dead hawks             : 21
# Dead doves             : 0
# Hawk babies            : 38
# Dove babies            : 17
# Hawks                  : 36.48021224850763
# Doves                  : 63.51978775149237
# ----
# Round Processing time  : 0.016965866088867188
# Elapsed time           : 0.9516596794128418
#
# Round 52
# ROUND 52
# Food produced          : 40
# Population             : Hawks-> 1664, Doves-> 2909
# Dead hawks             : 20
# Dead doves             : 0
# Hawk babies            : 34
# Dove babies            : 36
# Hawks                  : 36.387491799693855
# Doves                  : 63.61250820030614
# ----
# Round Processing time  : 0.01594686508178711
# Elapsed time           : 0.9764397144317627
#
# Round 53
# ROUND 53
# Food produced          : 40
# Population             : Hawks-> 1686, Doves-> 2950
# Dead hawks             : 21
# Dead doves             : 0
# Hawk babies            : 43
# Dove babies            : 41
# Hawks                  : 36.36755823986195
# Doves                  : 63.63244176013805
# ----
# Round Processing time  : 0.018001556396484375
# Elapsed time           : 0.998384952545166
#
# Round 54
# ROUND 54
# Food produced          : 40
# Population             : Hawks-> 1714, Doves-> 2986
# Dead hawks             : 18
# Dead doves             : 0
# Hawk babies            : 46
# Dove babies            : 36
# Hawks                  : 36.46808510638298
# Doves                  : 63.53191489361703
# ----
# Round Processing time  : 0.016961336135864258
# Elapsed time           : 1.0173273086547852
#
# Round 55
# ROUND 55
# Food produced          : 40
# Population             : Hawks-> 1721, Doves-> 3012
# Dead hawks             : 27
# Dead doves             : 0
# Hawk babies            : 34
# Dove babies            : 26
# Hawks                  : 36.36171561377562
# Doves                  : 63.638284386224385
# ----
# Round Processing time  : 0.017673254013061523
# Elapsed time           : 1.0379970073699951
#
# Round 56
# ROUND 56
# Food produced          : 40
# Population             : Hawks-> 1728, Doves-> 3028
# Dead hawks             : 24
# Dead doves             : 0
# Hawk babies            : 31
# Dove babies            : 16
# Hawks                  : 36.33305298570227
# Doves                  : 63.666947014297726
# ----
# Round Processing time  : 0.021971940994262695
# Elapsed time           : 1.0688042640686035
#
# Round 57
# ROUND 57
# Food produced          : 40
# Population             : Hawks-> 1746, Doves-> 3053
# Dead hawks             : 30
# Dead doves             : 0
# Hawk babies            : 48
# Dove babies            : 25
# Hawks                  : 36.38257970410502
# Doves                  : 63.61742029589498
# ----
# Round Processing time  : 0.03500699996948242
# Elapsed time           : 1.1116437911987305
#
# Round 58
# ROUND 58
# Food produced          : 40
# Population             : Hawks-> 1744, Doves-> 3091
# Dead hawks             : 29
# Dead doves             : 0
# Hawk babies            : 27
# Dove babies            : 38
# Hawks                  : 36.07032057911066
# Doves                  : 63.92967942088935
# ----
# Round Processing time  : 0.07774829864501953
# Elapsed time           : 1.2034375667572021
#
# Round 59
# ROUND 59
# Food produced          : 40
# Population             : Hawks-> 1747, Doves-> 3139
# Dead hawks             : 29
# Dead doves             : 0
# Hawk babies            : 32
# Dove babies            : 48
# Hawks                  : 35.755218993041346
# Doves                  : 64.24478100695866
# ----
# Round Processing time  : 0.028979063034057617
# Elapsed time           : 1.2393972873687744
#
# Round 60
# ROUND 60
# Food produced          : 40
# Population             : Hawks-> 1754, Doves-> 3181
# Dead hawks             : 23
# Dead doves             : 0
# Hawk babies            : 30
# Dove babies            : 42
# Hawks                  : 35.54204660587639
# Doves                  : 64.4579533941236
# ----
# Round Processing time  : 0.02597188949584961
# Elapsed time           : 1.2695581912994385
#
# Round 61
# ROUND 61
# Food produced          : 40
# Population             : Hawks-> 1759, Doves-> 3203
# Dead hawks             : 29
# Dead doves             : 0
# Hawk babies            : 34
# Dove babies            : 22
# Hawks                  : 35.44941555824264
# Doves                  : 64.55058444175735
# ----
# Round Processing time  : 0.017918825149536133
# Elapsed time           : 1.290313482284546
#
# Round 62
# ROUND 62
# Food produced          : 40
# Population             : Hawks-> 1764, Doves-> 3234
# Dead hawks             : 27
# Dead doves             : 0
# Hawk babies            : 32
# Dove babies            : 31
# Hawks                  : 35.294117647058826
# Doves                  : 64.70588235294117
# ----
# Round Processing time  : 0.0219271183013916
# Elapsed time           : 1.3142478466033936
#
# Round 63
# ROUND 63
# Food produced          : 40
# Population             : Hawks-> 1777, Doves-> 3260
# Dead hawks             : 25
# Dead doves             : 0
# Hawk babies            : 38
# Dove babies            : 26
# Hawks                  : 35.278935874528486
# Doves                  : 64.7210641254715
# ----
# Round Processing time  : 0.02189159393310547
# Elapsed time           : 1.3381381034851074
#
# Round 64
# ROUND 64
# Food produced          : 40
# Population             : Hawks-> 1794, Doves-> 3297
# Dead hawks             : 20
# Dead doves             : 0
# Hawk babies            : 37
# Dove babies            : 37
# Hawks                  : 35.23865645256335
# Doves                  : 64.76134354743665
# ----
# Round Processing time  : 0.02099323272705078
# Elapsed time           : 1.3643949031829834
#
# Round 65
# ROUND 65
# Food produced          : 40
# Population             : Hawks-> 1815, Doves-> 3321
# Dead hawks             : 19
# Dead doves             : 0
# Hawk babies            : 40
# Dove babies            : 24
# Hawks                  : 35.33878504672897
# Doves                  : 64.66121495327103
# ----
# Round Processing time  : 0.02763843536376953
# Elapsed time           : 1.3969776630401611
#
# Round 66
# ROUND 66
# Food produced          : 40
# Population             : Hawks-> 1828, Doves-> 3339
# Dead hawks             : 26
# Dead doves             : 0
# Hawk babies            : 39
# Dove babies            : 18
# Hawks                  : 35.3783626862783
# Doves                  : 64.62163731372169
# ----
# Round Processing time  : 0.04342460632324219
# Elapsed time           : 1.4463863372802734
#
# Round 67
# ROUND 67
# Food produced          : 40
# Population             : Hawks-> 1841, Doves-> 3378
# Dead hawks             : 22
# Dead doves             : 0
# Hawk babies            : 35
# Dove babies            : 39
# Hawks                  : 35.27495688829278
# Doves                  : 64.72504311170722
# ----
# Round Processing time  : 0.041931867599487305
# Elapsed time           : 1.4932599067687988
#
# Round 68
# ROUND 68
# Food produced          : 40
# Population             : Hawks-> 1845, Doves-> 3418
# Dead hawks             : 34
# Dead doves             : 0
# Hawk babies            : 38
# Dove babies            : 40
# Hawks                  : 35.05605168155045
# Doves                  : 64.94394831844956
# ----
# Round Processing time  : 0.03690457344055176
# Elapsed time           : 1.53519606590271
#
# Round 69
# ROUND 69
# Food produced          : 40
# Population             : Hawks-> 1856, Doves-> 3456
# Dead hawks             : 21
# Dead doves             : 0
# Hawk babies            : 32
# Dove babies            : 38
# Hawks                  : 34.93975903614458
# Doves                  : 65.06024096385542
# ----
# Round Processing time  : 0.039846181869506836
# Elapsed time           : 1.5800302028656006
#
# Round 70
# ROUND 70
# Food produced          : 40
# Population             : Hawks-> 1879, Doves-> 3478
# Dead hawks             : 17
# Dead doves             : 0
# Hawk babies            : 40
# Dove babies            : 22
# Hawks                  : 35.075602016053764
# Doves                  : 64.92439798394624
# ----
# Round Processing time  : 0.03709888458251953
# Elapsed time           : 1.6259069442749023
#
# Round 71
# ROUND 71
# Food produced          : 40
# Population             : Hawks-> 1886, Doves-> 3491
# Dead hawks             : 22
# Dead doves             : 0
# Hawk babies            : 29
# Dove babies            : 13
# Hawks                  : 35.07532081086108
# Doves                  : 64.92467918913893
# ----
# Round Processing time  : 0.04491615295410156
# Elapsed time           : 1.674809217453003
#
# Round 72
# ROUND 72
# Food produced          : 40
# Population             : Hawks-> 1898, Doves-> 3524
# Dead hawks             : 22
# Dead doves             : 0
# Hawk babies            : 34
# Dove babies            : 33
# Hawks                  : 35.0055330136481
# Doves                  : 64.9944669863519
# ----
# Round Processing time  : 0.027046680450439453
# Elapsed time           : 1.705725908279419
#
# Round 73
# ROUND 73
# Food produced          : 40
# Population             : Hawks-> 1912, Doves-> 3558
# Dead hawks             : 21
# Dead doves             : 0
# Hawk babies            : 35
# Dove babies            : 34
# Hawks                  : 34.95429616087751
# Doves                  : 65.04570383912248
# ----
# Round Processing time  : 0.0434267520904541
# Elapsed time           : 1.7556493282318115
#
# Round 74
# ROUND 74
# Food produced          : 40
# Population             : Hawks-> 1899, Doves-> 3583
# Dead hawks             : 33
# Dead doves             : 0
# Hawk babies            : 20
# Dove babies            : 25
# Hawks                  : 34.640642101422834
# Doves                  : 65.35935789857716
# ----
# Round Processing time  : 0.021936893463134766
# Elapsed time           : 1.7815661430358887
#
# Round 75
# ROUND 75
# Food produced          : 40
# Population             : Hawks-> 1907, Doves-> 3609
# Dead hawks             : 29
# Dead doves             : 0
# Hawk babies            : 37
# Dove babies            : 26
# Hawks                  : 34.57215373459028
# Doves                  : 65.42784626540971
# ----
# Round Processing time  : 0.023893117904663086
# Elapsed time           : 1.8084909915924072
#
# Round 76
# ROUND 76
# Food produced          : 40
# Population             : Hawks-> 1906, Doves-> 3630
# Dead hawks             : 30
# Dead doves             : 0
# Hawk babies            : 29
# Dove babies            : 21
# Hawks                  : 34.42919075144509
# Doves                  : 65.57080924855492
# ----
# Round Processing time  : 0.022942781448364258
# Elapsed time           : 1.8345961570739746
#
# Round 77
# ROUND 77
# Food produced          : 40
# Population             : Hawks-> 1910, Doves-> 3660
# Dead hawks             : 26
# Dead doves             : 0
# Hawk babies            : 30
# Dove babies            : 30
# Hawks                  : 34.29084380610413
# Doves                  : 65.70915619389586
# ----
# Round Processing time  : 0.025934219360351562
# Elapsed time           : 1.8643724918365479
#
# Round 78
# ROUND 78
# Food produced          : 40
# Population             : Hawks-> 1908, Doves-> 3691
# Dead hawks             : 25
# Dead doves             : 0
# Hawk babies            : 23
# Dove babies            : 31
# Hawks                  : 34.07751384175746
# Doves                  : 65.92248615824255
# ----
# Round Processing time  : 0.023972272872924805
# Elapsed time           : 1.8914482593536377
#
# Round 79
# ROUND 79
# Food produced          : 40
# Population             : Hawks-> 1908, Doves-> 3717
# Dead hawks             : 27
# Dead doves             : 0
# Hawk babies            : 27
# Dove babies            : 26
# Hawks                  : 33.92
# Doves                  : 66.08000000000001
# ----
# Round Processing time  : 0.023986339569091797
# Elapsed time           : 1.9203829765319824
#
# Round 80
# ROUND 80
# Food produced          : 40
# Population             : Hawks-> 1923, Doves-> 3741
# Dead hawks             : 25
# Dead doves             : 0
# Hawk babies            : 40
# Dove babies            : 24
# Hawks                  : 33.95127118644068
# Doves                  : 66.04872881355932
# ----
# Round Processing time  : 0.024930477142333984
# Elapsed time           : 1.9495913982391357
#
# Round 81
# ROUND 81
# Food produced          : 40
# Population             : Hawks-> 1918, Doves-> 3768
# Dead hawks             : 28
# Dead doves             : 0
# Hawk babies            : 23
# Dove babies            : 27
# Hawks                  : 33.731973267674995
# Doves                  : 66.26802673232501
# ----
# Round Processing time  : 0.026641845703125
# Elapsed time           : 1.981217861175537
#
# Round 82
# ROUND 82
# Food produced          : 40
# Population             : Hawks-> 1920, Doves-> 3797
# Dead hawks             : 27
# Dead doves             : 0
# Hawk babies            : 29
# Dove babies            : 29
# Hawks                  : 33.58404757740073
# Doves                  : 66.41595242259926
# ----
# Round Processing time  : 0.027927398681640625
# Elapsed time           : 2.013132333755493
#
# Round 83
# ROUND 83
# Food produced          : 40
# Population             : Hawks-> 1922, Doves-> 3820
# Dead hawks             : 29
# Dead doves             : 0
# Hawk babies            : 31
# Dove babies            : 23
# Hawks                  : 33.47265761058865
# Doves                  : 66.52734238941136
# ----
# Round Processing time  : 0.027233123779296875
# Elapsed time           : 2.0443429946899414
#
# Round 84
# ROUND 84
# Food produced          : 40
# Population             : Hawks-> 1924, Doves-> 3836
# Dead hawks             : 29
# Dead doves             : 1
# Hawk babies            : 31
# Dove babies            : 17
# Hawks                  : 33.40277777777778
# Doves                  : 66.59722222222221
# ----
# Round Processing time  : 0.028797388076782227
# Elapsed time           : 2.082254409790039
#
# Round 85
# ROUND 85
# Food produced          : 40
# Population             : Hawks-> 1929, Doves-> 3854
# Dead hawks             : 22
# Dead doves             : 1
# Hawk babies            : 27
# Dove babies            : 19
# Hawks                  : 33.35638941725748
# Doves                  : 66.64361058274253
# ----
# Round Processing time  : 0.029919147491455078
# Elapsed time           : 2.117161750793457
#
# Round 86
# ROUND 86
# Food produced          : 40
# Population             : Hawks-> 1941, Doves-> 3879
# Dead hawks             : 23
# Dead doves             : 0
# Hawk babies            : 35
# Dove babies            : 25
# Hawks                  : 33.350515463917525
# Doves                  : 66.64948453608247
# ----
# Round Processing time  : 0.025926828384399414
# Elapsed time           : 2.1580348014831543
#
# Round 87
# ROUND 87
# Food produced          : 40
# Population             : Hawks-> 1948, Doves-> 3901
# Dead hawks             : 30
# Dead doves             : 0
# Hawk babies            : 37
# Dove babies            : 22
# Hawks                  : 33.30483843392033
# Doves                  : 66.69516156607968
# ----
# Round Processing time  : 0.03386878967285156
# Elapsed time           : 2.1998867988586426
#
# Round 88
# ROUND 88
# Food produced          : 40
# Population             : Hawks-> 1961, Doves-> 3920
# Dead hawks             : 25
# Dead doves             : 0
# Hawk babies            : 38
# Dove babies            : 19
# Hawks                  : 33.344669273933
# Doves                  : 66.65533072606699
# ----
# Round Processing time  : 0.029915332794189453
# Elapsed time           : 2.2317965030670166
#
# Round 89
# ROUND 89
# Food produced          : 40
# Population             : Hawks-> 1962, Doves-> 3934
# Dead hawks             : 27
# Dead doves             : 0
# Hawk babies            : 28
# Dove babies            : 14
# Hawks                  : 33.27679782903664
# Doves                  : 66.72320217096338
# ----
# Round Processing time  : 0.04647064208984375
# Elapsed time           : 2.2852439880371094
#
# Round 90
# ROUND 90
# Food produced          : 40
# Population             : Hawks-> 1968, Doves-> 3952
# Dead hawks             : 29
# Dead doves             : 0
# Hawk babies            : 35
# Dove babies            : 18
# Hawks                  : 33.24324324324324
# Doves                  : 66.75675675675676
# ----
# Round Processing time  : 0.05120682716369629
# Elapsed time           : 2.3443164825439453
#
# Round 91
# ROUND 91
# Food produced          : 40
# Population             : Hawks-> 1976, Doves-> 3968
# Dead hawks             : 21
# Dead doves             : 1
# Hawk babies            : 29
# Dove babies            : 17
# Hawks                  : 33.24360699865411
# Doves                  : 66.7563930013459
# ----
# Round Processing time  : 0.019942522048950195
# Elapsed time           : 2.3722286224365234
#
# Round 92
# ROUND 92
# Food produced          : 40
# Population             : Hawks-> 1981, Doves-> 3998
# Dead hawks             : 33
# Dead doves             : 0
# Hawk babies            : 38
# Dove babies            : 30
# Hawks                  : 33.132630874728214
# Doves                  : 66.86736912527178
# ----
# Round Processing time  : 0.019950151443481445
# Elapsed time           : 2.3951683044433594
#
# Round 93
# ROUND 93
# Food produced          : 40
# Population             : Hawks-> 1979, Doves-> 4021
# Dead hawks             : 24
# Dead doves             : 0
# Hawk babies            : 22
# Dove babies            : 23
# Hawks                  : 32.983333333333334
# Doves                  : 67.01666666666667
# ----
# Round Processing time  : 0.02692127227783203
# Elapsed time           : 2.4260849952697754
#
# Round 94
# ROUND 94
# Food produced          : 40
# Population             : Hawks-> 1993, Doves-> 4036
# Dead hawks             : 26
# Dead doves             : 1
# Hawk babies            : 40
# Dove babies            : 16
# Hawks                  : 33.05689169016421
# Doves                  : 66.9431083098358
# ----
# Round Processing time  : 0.03505063056945801
# Elapsed time           : 2.4640352725982666
#
# Round 95
# ROUND 95
# Food produced          : 40
# Population             : Hawks-> 1991, Doves-> 4054
# Dead hawks             : 31
# Dead doves             : 0
# Hawk babies            : 29
# Dove babies            : 18
# Hawks                  : 32.93631100082713
# Doves                  : 67.06368899917287
# ----
# Round Processing time  : 0.026839733123779297
# Elapsed time           : 2.4938666820526123
#
# Round 96
# ROUND 96
# Food produced          : 40
# Population             : Hawks-> 1990, Doves-> 4071
# Dead hawks             : 28
# Dead doves             : 2
# Hawk babies            : 27
# Dove babies            : 19
# Hawks                  : 32.83286586371886
# Doves                  : 67.16713413628113
# ----
# Round Processing time  : 0.02799534797668457
# Elapsed time           : 2.525778293609619
#
# Round 97
# ROUND 97
# Food produced          : 40
# Population             : Hawks-> 1997, Doves-> 4106
# Dead hawks             : 25
# Dead doves             : 1
# Hawk babies            : 32
# Dove babies            : 36
# Hawks                  : 32.72161232180895
# Doves                  : 67.27838767819105
# ----
# Round Processing time  : 0.027133941650390625
# Elapsed time           : 2.5579328536987305
#
# Round 98
# ROUND 98
# Food produced          : 40
# Population             : Hawks-> 1993, Doves-> 4120
# Dead hawks             : 31
# Dead doves             : 0
# Hawk babies            : 27
# Dove babies            : 14
# Hawks                  : 32.602650089972194
# Doves                  : 67.39734991002781
# ----
# Round Processing time  : 0.026892423629760742
# Elapsed time           : 2.587817668914795
#
# Round 99
# ROUND 99
# Food produced          : 40
# Population             : Hawks-> 2002, Doves-> 4133
# Dead hawks             : 21
# Dead doves             : 0
# Hawk babies            : 30
# Dove babies            : 13
# Hawks                  : 32.63243683781581
# Doves                  : 67.36756316218418
# ----
# Round Processing time  : 0.030918121337890625
# Elapsed time           : 2.6227223873138428
#
# Round 100
# ROUND 100
# Food produced          : 40
# Population             : Hawks-> 2003, Doves-> 4149
# Dead hawks             : 25
# Dead doves             : 0
# Hawk babies            : 26
# Dove babies            : 16
# Hawks                  : 32.55851755526658
# Doves                  : 67.44148244473342
# ----
# Round Processing time  : 0.03444957733154297
# Elapsed time           : 2.665196418762207
#
# Round 101
# ROUND 101
# Food produced          : 40
# Population             : Hawks-> 2015, Doves-> 4164
# Dead hawks             : 24
# Dead doves             : 0
# Hawk babies            : 36
# Dove babies            : 15
# Hawks                  : 32.610454766143384
# Doves                  : 67.38954523385661
# ----
# Round Processing time  : 0.021053552627563477
# Elapsed time           : 2.6912591457366943
#
# Round 102
# ROUND 102
# Food produced          : 40
# Population             : Hawks-> 2031, Doves-> 4184
# Dead hawks             : 30
# Dead doves             : 1
# Hawk babies            : 46
# Dove babies            : 21
# Hawks                  : 32.67900241351569
# Doves                  : 67.32099758648431
# ----
# Round Processing time  : 0.020812034606933594
# Elapsed time           : 2.715064525604248
#
# Round 103
# ROUND 103
# Food produced          : 40
# Population             : Hawks-> 2043, Doves-> 4201
# Dead hawks             : 22
# Dead doves             : 0
# Hawk babies            : 34
# Dove babies            : 17
# Hawks                  : 32.71941063420884
# Doves                  : 67.28058936579116
# ----
# Round Processing time  : 0.03535890579223633
# Elapsed time           : 2.758401870727539
#
# Round 104
# ROUND 104
# Food produced          : 40
# Population             : Hawks-> 2047, Doves-> 4214
# Dead hawks             : 18
# Dead doves             : 1
# Hawk babies            : 22
# Dove babies            : 14
# Hawks                  : 32.69445775435234
# Doves                  : 67.30554224564767
# ----
# Round Processing time  : 0.06491732597351074
# Elapsed time           : 2.831206798553467
#
# Round 105
# ROUND 105
# Food produced          : 40
# Population             : Hawks-> 2055, Doves-> 4229
# Dead hawks             : 26
# Dead doves             : 2
# Hawk babies            : 34
# Dove babies            : 17
# Hawks                  : 32.702100572883516
# Doves                  : 67.29789942711648
# ----
# Round Processing time  : 0.03101968765258789
# Elapsed time           : 2.8652122020721436
#
# Round 106
# ROUND 106
# Food produced          : 40
# Population             : Hawks-> 2055, Doves-> 4249
# Dead hawks             : 25
# Dead doves             : 2
# Hawk babies            : 25
# Dove babies            : 22
# Hawks                  : 32.598350253807105
# Doves                  : 67.40164974619289
# ----
# Round Processing time  : 0.029919862747192383
# Elapsed time           : 2.899120330810547
#
# Round 107
# ROUND 107
# Food produced          : 40
# Population             : Hawks-> 2068, Doves-> 4277
# Dead hawks             : 13
# Dead doves             : 1
# Hawk babies            : 26
# Dove babies            : 29
# Hawks                  : 32.592592592592595
# Doves                  : 67.4074074074074
# ----
# Round Processing time  : 0.024988651275634766
# Elapsed time           : 2.926098108291626
#
# Round 108
# ROUND 108
# Food produced          : 40
# Population             : Hawks-> 2084, Doves-> 4298
# Dead hawks             : 20
# Dead doves             : 0
# Hawk babies            : 36
# Dove babies            : 21
# Hawks                  : 32.65434033218427
# Doves                  : 67.34565966781572
# ----
# Round Processing time  : 0.0199434757232666
# Elapsed time           : 2.9500339031219482
#
# Round 109
# ROUND 109
# Food produced          : 40
# Population             : Hawks-> 2097, Doves-> 4310
# Dead hawks             : 25
# Dead doves             : 1
# Hawk babies            : 38
# Dove babies            : 13
# Hawks                  : 32.72982675199001
# Doves                  : 67.27017324801
# ----
# Round Processing time  : 0.02693009376525879
# Elapsed time           : 2.9799530506134033
#
# Round 110
# ROUND 110
# Food produced          : 40
# Population             : Hawks-> 2102, Doves-> 4325
# Dead hawks             : 23
# Dead doves             : 0
# Hawk babies            : 28
# Dove babies            : 15
# Hawks                  : 32.70577252217209
# Doves                  : 67.29422747782792
# ----
# Round Processing time  : 0.022931575775146484
# Elapsed time           : 3.0068821907043457
#
# Round 111
# ROUND 111
# Food produced          : 40
# Population             : Hawks-> 2114, Doves-> 4336
# Dead hawks             : 21
# Dead doves             : 2
# Hawk babies            : 33
# Dove babies            : 13
# Hawks                  : 32.775193798449614
# Doves                  : 67.2248062015504
# ----
# Round Processing time  : 0.028929948806762695
# Elapsed time           : 3.0417776107788086
#
# Round 112
# ROUND 112
# Food produced          : 40
# Population             : Hawks-> 2107, Doves-> 4356
# Dead hawks             : 26
# Dead doves             : 1
# Hawk babies            : 19
# Dove babies            : 21
# Hawks                  : 32.600959306823455
# Doves                  : 67.39904069317654
# ----
# Round Processing time  : 0.029933929443359375
# Elapsed time           : 3.076700448989868
#
# Round 113
# ROUND 113
# Food produced          : 40
# Population             : Hawks-> 2118, Doves-> 4381
# Dead hawks             : 26
# Dead doves             : 6
# Hawk babies            : 37
# Dove babies            : 31
# Hawks                  : 32.58962917371903
# Doves                  : 67.41037082628097
# ----
# Round Processing time  : 0.02992391586303711
# Elapsed time           : 3.111595630645752
#
# Round 114
# ROUND 114
# Food produced          : 40
# Population             : Hawks-> 2134, Doves-> 4392
# Dead hawks             : 19
# Dead doves             : 1
# Hawk babies            : 35
# Dove babies            : 12
# Hawks                  : 32.699969353355804
# Doves                  : 67.30003064664419
# ----
# Round Processing time  : 0.030482053756713867
# Elapsed time           : 3.145657777786255
#
# Round 115
# ROUND 115
# Food produced          : 40
# Population             : Hawks-> 2148, Doves-> 4404
# Dead hawks             : 26
# Dead doves             : 2
# Hawk babies            : 40
# Dove babies            : 14
# Hawks                  : 32.78388278388278
# Doves                  : 67.21611721611723
# ----
# Round Processing time  : 0.028912067413330078
# Elapsed time           : 3.1785659790039062
#
# Round 116
# ROUND 116
# Food produced          : 40
# Population             : Hawks-> 2149, Doves-> 4422
# Dead hawks             : 28
# Dead doves             : 0
# Hawk babies            : 29
# Dove babies            : 18
# Hawks                  : 32.70430680261756
# Doves                  : 67.29569319738243
# ----
# Round Processing time  : 0.040886640548706055
# Elapsed time           : 3.225430965423584
#
# Round 117
# ROUND 117
# Food produced          : 40
# Population             : Hawks-> 2145, Doves-> 4438
# Dead hawks             : 34
# Dead doves             : 3
# Hawk babies            : 30
# Dove babies            : 19
# Hawks                  : 32.583928300167095
# Doves                  : 67.4160716998329
# ----
# Round Processing time  : 0.031906843185424805
# Elapsed time           : 3.266312837600708
#
# Round 118
# ROUND 118
# Food produced          : 40
# Population             : Hawks-> 2158, Doves-> 4454
# Dead hawks             : 19
# Dead doves             : 3
# Hawk babies            : 32
# Dove babies            : 19
# Hawks                  : 32.63762855414398
# Doves                  : 67.36237144585601
# ----
# Round Processing time  : 0.03093409538269043
# Elapsed time           : 3.3011860847473145
#
# Round 119
# ROUND 119
# Food produced          : 40
# Population             : Hawks-> 2165, Doves-> 4472
# Dead hawks             : 22
# Dead doves             : 3
# Hawk babies            : 29
# Dove babies            : 21
# Hawks                  : 32.62015971071267
# Doves                  : 67.37984028928733
# ----
# Round Processing time  : 0.03296685218811035
# Elapsed time           : 3.342133045196533
#
# Round 120
# ROUND 120
# Food produced          : 40
# Population             : Hawks-> 2170, Doves-> 4480
# Dead hawks             : 32
# Dead doves             : 4
# Hawk babies            : 37
# Dove babies            : 12
# Hawks                  : 32.631578947368425
# Doves                  : 67.36842105263158
# ----
# Round Processing time  : 0.03290987014770508
# Elapsed time           : 3.3789846897125244
#
# Round 121
# ROUND 121
# Food produced          : 40
# Population             : Hawks-> 2169, Doves-> 4492
# Dead hawks             : 28
# Dead doves             : 2
# Hawk babies            : 27
# Dove babies            : 14
# Hawks                  : 32.56267827653506
# Doves                  : 67.43732172346495
# ----
# Round Processing time  : 0.07251262664794922
# Elapsed time           : 3.4565253257751465
#
# Round 122
# ROUND 122
# Food produced          : 40
# Population             : Hawks-> 2179, Doves-> 4508
# Dead hawks             : 28
# Dead doves             : 0
# Hawk babies            : 38
# Dove babies            : 16
# Hawks                  : 32.5856138776731
# Doves                  : 67.4143861223269
# ----
# Round Processing time  : 0.055858612060546875
# Elapsed time           : 3.52136492729187
#
# Round 123
# ROUND 123
# Food produced          : 40
# Population             : Hawks-> 2184, Doves-> 4513
# Dead hawks             : 22
# Dead doves             : 6
# Hawk babies            : 27
# Dove babies            : 11
# Hawks                  : 32.61161714200389
# Doves                  : 67.38838285799612
# ----
# Round Processing time  : 0.03343391418457031
# Elapsed time           : 3.5617287158966064
#
# Round 124
# ROUND 124
# ...
# Population             : Hawks-> 2234, Doves-> 4451
# Dead hawks             : 29
# Dead doves             : 11
# Hawk babies            : 30
# Dove babies            : 6
# Hawks                  : 33.41810022438295
# Doves                  : 66.58189977561705
# ----
# Round Processing time  : 0.04950237274169922
# Elapsed time           : 16.108092784881592
#
# Round 462
# ROUND 462
# Food produced          : 40
# Population             : Hawks-> 2225, Doves-> 4453
# Dead hawks             : 37
# Dead doves             : 6
# Hawk babies            : 28
# Dove babies            : 8
# Hawks                  : 33.3183587900569
# Doves                  : 66.6816412099431
# ----
# Round Processing time  : 0.02099132537841797
# Elapsed time           : 16.1340491771698
#
# Round 463
# ROUND 463
# Food produced          : 40
# Population             : Hawks-> 2227, Doves-> 4455
# Dead hawks             : 33
# Dead doves             : 9
# Hawk babies            : 35
# Dove babies            : 11
# Hawks                  : 33.328344806944024
# Doves                  : 66.67165519305597
# ----
# Round Processing time  : 0.02594757080078125
# Elapsed time           : 16.164994955062866
#
# Round 464
# ROUND 464
# Food produced          : 40
# Population             : Hawks-> 2227, Doves-> 4450
# Dead hawks             : 27
# Dead doves             : 8
# Hawk babies            : 27
# Dove babies            : 3
# Hawks                  : 33.35330238130897
# Doves                  : 66.64669761869104
# ----
# Round Processing time  : 0.03345298767089844
# Elapsed time           : 16.20360779762268
#
# Round 465
# ROUND 465
# Food produced          : 40
# Population             : Hawks-> 2225, Doves-> 4447
# Dead hawks             : 23
# Dead doves             : 8
# Hawk babies            : 21
# Dove babies            : 5
# Hawks                  : 33.34832134292566
# Doves                  : 66.65167865707434
# ----
# Round Processing time  : 0.04515695571899414
# Elapsed time           : 16.25829815864563
#
# Round 466
# ROUND 466
# Food produced          : 40
# Population             : Hawks-> 2214, Doves-> 4455
# Dead hawks             : 30
# Dead doves             : 5
# Hawk babies            : 19
# Dove babies            : 13
# Hawks                  : 33.198380566801625
# Doves                  : 66.80161943319838
# ----
# Round Processing time  : 0.044870615005493164
# Elapsed time           : 16.308157205581665
#
# Round 467
# ROUND 467
# Food produced          : 40
# Population             : Hawks-> 2215, Doves-> 4461
# Dead hawks             : 34
# Dead doves             : 4
# Hawk babies            : 35
# Dove babies            : 10
# Hawks                  : 33.17855002995806
# Doves                  : 66.82144997004194
# ----
# Round Processing time  : 0.03699207305908203
# Elapsed time           : 16.35011386871338
#
# Round 468
# ROUND 468
# Food produced          : 40
# Population             : Hawks-> 2215, Doves-> 4462
# Dead hawks             : 26
# Dead doves             : 8
# Hawk babies            : 26
# Dove babies            : 9
# Hawks                  : 33.17358094952823
# Doves                  : 66.82641905047177
# ----
# Round Processing time  : 0.033941030502319336
# Elapsed time           : 16.386959314346313
#
# Round 469
# ROUND 469
# Food produced          : 40
# Population             : Hawks-> 2217, Doves-> 4466
# Dead hawks             : 30
# Dead doves             : 5
# Hawk babies            : 32
# Dove babies            : 9
# Hawks                  : 33.173724375280564
# Doves                  : 66.82627562471943
# ----
# Round Processing time  : 0.03330588340759277
# Elapsed time           : 16.427206993103027
#
# Round 470
# ROUND 470
# Food produced          : 40
# Population             : Hawks-> 2226, Doves-> 4457
# Dead hawks             : 25
# Dead doves             : 14
# Hawk babies            : 34
# Dove babies            : 5
# Hawks                  : 33.30839443363759
# Doves                  : 66.69160556636241
# ----
# Round Processing time  : 0.024974346160888672
# Elapsed time           : 16.457128763198853
#
# Round 471
# ROUND 471
# Food produced          : 40
# Population             : Hawks-> 2233, Doves-> 4458
# Dead hawks             : 22
# Dead doves             : 11
# Hawk babies            : 29
# Dove babies            : 12
# Hawks                  : 33.373187864295325
# Doves                  : 66.62681213570468
# ----
# Round Processing time  : 0.028017759323120117
# Elapsed time           : 16.49004292488098
#
# Round 472
# ROUND 472
# Food produced          : 40
# Population             : Hawks-> 2235, Doves-> 4456
# Dead hawks             : 28
# Dead doves             : 13
# Hawk babies            : 30
# Dove babies            : 11
# Hawks                  : 33.40307876251681
# Doves                  : 66.59692123748319
# ----
# Round Processing time  : 0.029916048049926758
# Elapsed time           : 16.522950649261475
#
# Round 473
# ROUND 473
# Food produced          : 40
# Population             : Hawks-> 2236, Doves-> 4448
# Dead hawks             : 23
# Dead doves             : 13
# Hawk babies            : 24
# Dove babies            : 5
# Hawks                  : 33.45302214242968
# Doves                  : 66.54697785757033
# ----
# Round Processing time  : 0.033210039138793945
# Elapsed time           : 16.559895753860474
#
# Round 474
# ROUND 474
# Food produced          : 40
# Population             : Hawks-> 2240, Doves-> 4450
# Dead hawks             : 20
# Dead doves             : 14
# Hawk babies            : 24
# Dove babies            : 16
# Hawks                  : 33.482810164424514
# Doves                  : 66.51718983557548
# ----
# Round Processing time  : 0.0483546257019043
# Elapsed time           : 16.61423420906067
#
# Round 475
# ROUND 475
# Food produced          : 40
# Population             : Hawks-> 2250, Doves-> 4446
# Dead hawks             : 26
# Dead doves             : 8
# Hawk babies            : 36
# Dove babies            : 4
# Hawks                  : 33.60215053763441
# Doves                  : 66.39784946236558
# ----
# Round Processing time  : 0.03993368148803711
# Elapsed time           : 16.658157110214233
#
# Round 476
# ROUND 476
# Food produced          : 40
# Population             : Hawks-> 2253, Doves-> 4449
# Dead hawks             : 32
# Dead doves             : 9
# Hawk babies            : 35
# Dove babies            : 12
# Hawks                  : 33.61683079677708
# Doves                  : 66.38316920322292
# ----
# Round Processing time  : 0.02593088150024414
# Elapsed time           : 16.69003987312317
#
# Round 477
# ROUND 477
# Food produced          : 40
# Population             : Hawks-> 2257, Doves-> 4448
# Dead hawks             : 26
# Dead doves             : 11
# Hawk babies            : 30
# Dove babies            : 10
# Hawks                  : 33.66144668158091
# Doves                  : 66.33855331841909
# ----
# Round Processing time  : 0.02608036994934082
# Elapsed time           : 16.72120976448059
#
# Round 478
# ROUND 478
# Food produced          : 40
# Population             : Hawks-> 2263, Doves-> 4449
# Dead hawks             : 19
# Dead doves             : 4
# Hawk babies            : 25
# Dove babies            : 5
# Hawks                  : 33.715733015494635
# Doves                  : 66.28426698450536
# ----
# Round Processing time  : 0.025859594345092773
# Elapsed time           : 16.750442504882812
#
# Round 479
# ROUND 479
# Food produced          : 40
# Population             : Hawks-> 2261, Doves-> 4445
# Dead hawks             : 26
# Dead doves             : 11
# Hawk babies            : 24
# Dove babies            : 7
# Hawks                  : 33.7160751565762
# Doves                  : 66.2839248434238
# ----
# Round Processing time  : 0.02567434310913086
# Elapsed time           : 16.779971837997437
#
# Round 480
# ROUND 480
# Food produced          : 40
# Population             : Hawks-> 2256, Doves-> 4446
# Dead hawks             : 31
# Dead doves             : 11
# Hawk babies            : 26
# Dove babies            : 12
# Hawks                  : 33.66159355416294
# Doves                  : 66.33840644583707
# ----
# Round Processing time  : 0.02993178367614746
# Elapsed time           : 16.81389355659485
#
# Round 481
# ROUND 481
# Food produced          : 40
# Population             : Hawks-> 2243, Doves-> 4447
# Dead hawks             : 28
# Dead doves             : 6
# Hawk babies            : 15
# Dove babies            : 7
# Hawks                  : 33.52765321375187
# Doves                  : 66.47234678624812
# ----
# Round Processing time  : 0.02792525291442871
# Elapsed time           : 16.849782943725586
#
# Round 482
# ROUND 482
# Food produced          : 40
# Population             : Hawks-> 2243, Doves-> 4450
# Dead hawks             : 28
# Dead doves             : 7
# Hawk babies            : 28
# Dove babies            : 10
# Hawks                  : 33.5126251307336
# Doves                  : 66.4873748692664
# ----
# Round Processing time  : 0.027890920639038086
# Elapsed time           : 16.88211178779602
#
# Round 483
# ROUND 483
# Food produced          : 40
# Population             : Hawks-> 2242, Doves-> 4446
# Dead hawks             : 24
# Dead doves             : 13
# Hawk babies            : 23
# Dove babies            : 9
# Hawks                  : 33.52272727272727
# Doves                  : 66.47727272727273
# ----
# Round Processing time  : 0.027159690856933594
# Elapsed time           : 16.91227436065674
#
# Round 484
# ROUND 484
# Food produced          : 40
# Population             : Hawks-> 2220, Doves-> 4451
# Dead hawks             : 46
# Dead doves             : 7
# Hawk babies            : 24
# Dove babies            : 12
# Hawks                  : 33.27836906011093
# Doves                  : 66.72163093988908
# ----
# Round Processing time  : 0.0249326229095459
# Elapsed time           : 16.942182064056396
#
# Round 485
# ROUND 485
# Food produced          : 40
# Population             : Hawks-> 2221, Doves-> 4452
# Dead hawks             : 26
# Dead doves             : 7
# Hawk babies            : 27
# Dove babies            : 8
# Hawks                  : 33.28338078825116
# Doves                  : 66.71661921174884
# ----
# Round Processing time  : 0.0289309024810791
# Elapsed time           : 16.9761061668396
#
# Round 486
# ROUND 486
# Food produced          : 40
# Population             : Hawks-> 2237, Doves-> 4451
# Dead hawks             : 18
# Dead doves             : 10
# Hawk babies            : 34
# Dove babies            : 9
# Hawks                  : 33.447966507177036
# Doves                  : 66.55203349282297
# ----
# Round Processing time  : 0.02857184410095215
# Elapsed time           : 17.01164674758911
#
# Round 487
# ROUND 487
# Food produced          : 40
# Population             : Hawks-> 2222, Doves-> 4452
# Dead hawks             : 35
# Dead doves             : 5
# Hawk babies            : 20
# Dove babies            : 6
# Hawks                  : 33.29337728498651
# Doves                  : 66.70662271501348
# ----
# Round Processing time  : 0.02917623519897461
# Elapsed time           : 17.051538467407227
#
# Round 488
# ROUND 488
# Food produced          : 40
# Population             : Hawks-> 2219, Doves-> 4450
# Dead hawks             : 30
# Dead doves             : 9
# Hawk babies            : 27
# Dove babies            : 7
# Hawks                  : 33.273354325985906
# Doves                  : 66.7266456740141
# ----
# Round Processing time  : 0.02892279624938965
# Elapsed time           : 17.091558933258057
#
# Round 489
# ROUND 489
# Food produced          : 40
# Population             : Hawks-> 2226, Doves-> 4448
# Dead hawks             : 20
# Dead doves             : 9
# Hawk babies            : 27
# Dove babies            : 7
# Hawks                  : 33.35331135750674
# Doves                  : 66.64668864249326
# ----
# Round Processing time  : 0.026916027069091797
# Elapsed time           : 17.126348733901978
#
# Round 490
# ROUND 490
# Food produced          : 40
# Population             : Hawks-> 2221, Doves-> 4451
# Dead hawks             : 36
# Dead doves             : 8
# Hawk babies            : 31
# Dove babies            : 11
# Hawks                  : 33.288369304556355
# Doves                  : 66.71163069544365
# ----
# Round Processing time  : 0.022884845733642578
# Elapsed time           : 17.150230884552002
#
# Round 491
# ROUND 491
# Food produced          : 40
# Population             : Hawks-> 2227, Doves-> 4445
# Dead hawks             : 17
# Dead doves             : 14
# Hawk babies            : 23
# Dove babies            : 8
# Hawks                  : 33.37829736211031
# Doves                  : 66.62170263788968
# ----
# Round Processing time  : 0.018004179000854492
# Elapsed time           : 17.173274517059326
#
# Round 492
# ROUND 492
# Food produced          : 40
# Population             : Hawks-> 2221, Doves-> 4443
# Dead hawks             : 31
# Dead doves             : 11
# Hawk babies            : 25
# Dove babies            : 9
# Hawks                  : 33.32833133253301
# Doves                  : 66.67166866746699
# ----
# Round Processing time  : 0.028872966766357422
# Elapsed time           : 17.20813226699829
#
# Round 493
# ROUND 493
# Food produced          : 40
# Population             : Hawks-> 2215, Doves-> 4446
# Dead hawks             : 29
# Dead doves             : 8
# Hawk babies            : 23
# Dove babies            : 11
# Hawks                  : 33.25326527548416
# Doves                  : 66.74673472451585
# ----
# Round Processing time  : 0.02791142463684082
# Elapsed time           : 17.24503183364868
#
# Round 494
# ROUND 494
# Food produced          : 40
# Population             : Hawks-> 2222, Doves-> 4450
# Dead hawks             : 34
# Dead doves             : 7
# Hawk babies            : 41
# Dove babies            : 11
# Hawks                  : 33.30335731414868
# Doves                  : 66.69664268585132
# ----
# Round Processing time  : 0.029574871063232422
# Elapsed time           : 17.27892780303955
#
# Round 495
# ROUND 495
# Food produced          : 40
# Population             : Hawks-> 2216, Doves-> 4446
# Dead hawks             : 30
# Dead doves             : 11
# Hawk babies            : 24
# Dove babies            : 7
# Hawks                  : 33.26328429900931
# Doves                  : 66.73671570099069
# ----
# Round Processing time  : 0.03130292892456055
# Elapsed time           : 17.315216541290283
#
# Round 496
# ROUND 496
# Food produced          : 40
# Population             : Hawks-> 2203, Doves-> 4449
# Dead hawks             : 30
# Dead doves             : 9
# Hawk babies            : 17
# Dove babies            : 12
# Hawks                  : 33.117859290438965
# Doves                  : 66.88214070956103
# ----
# Round Processing time  : 0.02293086051940918
# Elapsed time           : 17.341136693954468
#
# Round 497
# ROUND 497
# Food produced          : 40
# Population             : Hawks-> 2197, Doves-> 4444
# Dead hawks             : 37
# Dead doves             : 9
# Hawk babies            : 31
# Dove babies            : 4
# Hawks                  : 33.08236711338654
# Doves                  : 66.91763288661346
# ----
# Round Processing time  : 0.027884960174560547
# Elapsed time           : 17.372068166732788
#
# Round 498
# ROUND 498
# Food produced          : 40
# Population             : Hawks-> 2185, Doves-> 4441
# Dead hawks             : 29
# Dead doves             : 10
# Hawk babies            : 17
# Dove babies            : 7
# Hawks                  : 32.97615454271053
# Doves                  : 67.02384545728947
# ----
# Round Processing time  : 0.03200840950012207
# Elapsed time           : 17.415536165237427
#
# Round 499
# ROUND 499
# Food produced          : 40
# Population             : Hawks-> 2180, Doves-> 4444
# Dead hawks             : 33
# Dead doves             : 5
# Hawk babies            : 28
# Dove babies            : 8
# Hawks                  : 32.910628019323674
# Doves                  : 67.08937198067633
# ----
# Round Processing time  : 0.038407325744628906
# Elapsed time           : 17.456970930099487
#
# Round 500
# ROUND 500
# Food produced          : 40
# Population             : Hawks-> 2184, Doves-> 4443
# Dead hawks             : 35
# Dead doves             : 11
# Hawk babies            : 39
# Dove babies            : 10
# Hawks                  : 32.956088727931196
# Doves                  : 67.04391127206881
# ----
# Round Processing time  : 0.021945476531982422
# Elapsed time           : 17.48090696334839
#
# =============================================================
# Total dead agents      : 17181
# Total breeding agents  : 21808
# Total rounds completed : 500
# Total population size  : 6627
# Hawks                  : 32.956088727931196
# Doves                  : 67.04391127206881
# Processing time        : 17.48090696334839
# =============================================================

# %%
npdove = np.array(graph_dove_points)
nphawk = np.array(graph_hawk_points)
npdovePer = npdove / (npdove + nphawk)
nphawkPer = nphawk / (npdove + nphawk)
nppopulation = nphawk + npdove
nppopulation = nppopulation/np.max(nppopulation)

# %%
plt.clf()
plt.plot(npdovePer, color = "purple", label = "Dove fraction")
plt.plot(nphawkPer, color = "coral", label = "Hawk fraction")
plt.plot(nppopulation, label = "Scaled Population")
MSNE = game().findMSNE()
plt.axhline(y=MSNE[0][0],color = 'red', linestyle='--', label = "Hawk in MSNE")
plt.axhline(y=MSNE[0][1],color = 'purple', linestyle='--', label = "Dove in MSNE")
plt.legend()
plt.xlabel("Rounds")
plt.ylabel("Population Ratio")


plt.show()

# %%
print(MSNE)
# Out:
# [array([0.33333333, 0.66666667]), array([0.33333333, 0.66666667])]

# %%
## case 1 in ppt
STARTING_DOVES = 1000
STARTING_HAWKS = 1000
STARTING_POPULATION = STARTING_HAWKS + STARTING_DOVES

ROUNDS = 200
STARTING_ENERGY = 100

MIN_FOOD_PER_ROUND = 40
MAX_FOOD_PER_ROUND = 40
MAX_FOOD_APPEARANCE = 1000 # this tells how much max food can be found
ENERGY_REQUIRED_FOR_REPRODUCTION = 250
ENERGY_LOSS_PER_ROUND = 4
ENERGY_LOSS_FROM_FIGHTING = 10
ENERGY_REQUIRED_FOR_LIVING = 10


# case 3 in ppt
STARTING_DOVES = 1000
STARTING_HAWKS = 1000
STARTING_POPULATION = STARTING_HAWKS + STARTING_DOVES

ROUNDS = 200
STARTING_ENERGY = 100

MIN_FOOD_PER_ROUND = 40
MAX_FOOD_PER_ROUND = 40
MAX_FOOD_APPEARANCE = 1000 # this tells how much max food can be found
ENERGY_REQUIRED_FOR_REPRODUCTION = 250
ENERGY_LOSS_PER_ROUND = 4
ENERGY_LOSS_FROM_FIGHTING = 25
ENERGY_REQUIRED_FOR_LIVING = 10

# case 2 in ppt
STARTING_DOVES = 1000
STARTING_HAWKS = 1000
STARTING_POPULATION = STARTING_HAWKS + STARTING_DOVES

ROUNDS = 200
STARTING_ENERGY = 100

MIN_FOOD_PER_ROUND = 40
MAX_FOOD_PER_ROUND = 40
MAX_FOOD_APPEARANCE = 1000 # this tells how much max food can be found
ENERGY_REQUIRED_FOR_REPRODUCTION = 250
ENERGY_LOSS_PER_ROUND = 4
ENERGY_LOSS_FROM_FIGHTING = 20
ENERGY_REQUIRED_FOR_LIVING = 10

# case 4
STARTING_DOVES = 1000
STARTING_HAWKS = 1000
STARTING_POPULATION = STARTING_HAWKS + STARTING_DOVES

ROUNDS = 200
STARTING_ENERGY = 100

MIN_FOOD_PER_ROUND = 40
MAX_FOOD_PER_ROUND = 40
MAX_FOOD_APPEARANCE = 1000 # this tells how much max food can be found
ENERGY_REQUIRED_FOR_REPRODUCTION = 250
ENERGY_LOSS_PER_ROUND = 4
ENERGY_LOSS_FROM_FIGHTING = 60
ENERGY_REQUIRED_FOR_LIVING = 10
