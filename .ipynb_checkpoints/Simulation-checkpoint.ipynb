# %% [markdown]
# # Imports for Simulation and Visualiation

# %%
from random import randint, shuffle
import time
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Class Game
# - Attributes
#     - PayoffMatrix
#         : Payoff Matrix of two player Game
# - Methods
#     - findSDSE
#         : Computes Strong Dominant Strategy Equilibrium if it exists.
#     - findMSNE
#         : Computes MSNE using indifference priciple.

# %%
class game:
    def __init__(self):
        food = (MAX_FOOD_PER_ROUND + MIN_FOOD_PER_ROUND)//2
        self.payoffMatrix = [ 
                            [[(food//2) - ENERGY_LOSS_FROM_FIGHTING, (food//2) - ENERGY_LOSS_FROM_FIGHTING],[food,0]],
                            [[0, food],[(food//2), (food//2)]]
                            ]
#     Arguments : None, Return: list of SDSE strategy
    def findSDSE(self):
        P1 = []
        P2 = []
        if self.payoffMatrix[0][0][0] > self.payoffMatrix[1][0][0] and self.payoffMatrix[0][1][0] > self.payoffMatrix[1][1][0]:
            P1.append(0)
        if self.payoffMatrix[0][0][0] < self.payoffMatrix[1][0][0] and self.payoffMatrix[0][1][0] < self.payoffMatrix[1][1][0]:
            P1.appendp(1)
        if self.payoffMatrix[0][0][1] > self.payoffMatrix[0][1][1] and self.payoffMatrix[1][0][1] > self.payoffMatrix[1][1][1]:
            P2.append(0)
        if self.payoffMatrix[0][0][1] < self.payoffMatrix[0][1][1] and self.payoffMatrix[1][0][1] < self.payoffMatrix[1][1][1]:
            P2.append(1)
        ret = [(x, y) for x in P1 for y in P2]
        return ret

#   Arguments: None, Return list of probability distribution over strategy for player 1 and player 2
    def findMSNE(self):

        SDSE = self.findSDSE()
        p = np.zeros(2)
        q = np.zeros(2)
        if(len(SDSE) > 0):
            p[SDSE[0][0]] = 1
            q[SDSE[0][1]] = 1
            return [p,q]
        
#         row player Indifference Condition
        a = np.array([[1, 1], [self.payoffMatrix[0][0][0] - self.payoffMatrix[1][0][0], self.payoffMatrix[0][1][0] - self.payoffMatrix[1][1][0]] ])
        b = np.array([1, 0])
        q = np.linalg.solve(a, b)
        
#         col player Indifference Condition
        a = np.array([[1, 1], [self.payoffMatrix[0][0][1] - self.payoffMatrix[0][1][1], self.payoffMatrix[1][0][1] - self.payoffMatrix[1][1][1]] ])
        b = np.array([1, 0])
        p = np.linalg.solve(a, b) 
        return [p,q]

# %% [markdown]
# #### Global intitial Condtion
# 1. STARTING_DOVES
#     : The number of players who are Doves in the beginning
# 2. STARTING_HAWKS
#     : The number of players who are Doves in the beginning
# 3. ROUNDS
#     : Number of Rounds in the simulation
# 4. STARTING_ENERGY
#     : The amount of energy with which each player starts the game.
# 5. MIN_FOOD_PER_ROUND
#     : Min energy available per food.
# 6. MAX_FOOD_PER_ROUND
#     : Max energy available per food.
# 7. MAX_FOOD_APPEARANCE
#     : Max number of food appearance per round
# 8. ENERGY_REQUIRED_FOR_REPRODUCTION
#     : Minimum energy required to reproduce
# 9. ENERGY_LOSS_PER_ROUND
#     : Energy spent for surviving a round
# 10. ENERGY_LOSS_FROM_FIGHTING
#     : Energy spent over fighting
# 11. ENERGY_REQUIRED_FOR_LIVING
#     : Minimum energy required to remain alive
#
# #### Model Formulation
#
# 1. Game Starts with gameInit(), a function which initialize all the agents. These agents are the players in this game and they can be either HAWK or DOVE.
# 2. Then rounds start, while rounds <= ROUNDS **and** Agents Remaining >=2:
#     1. Call AwakenAgents(), set the state of agent to **Awake State**.
#     2. Generate the random food for the current round.
#     3. Shuffle the agents for random pairing.
#     4. Then pair the agents and let them compete over the food, However the max number of food appearance is limited by MAX_FOOD_APPEARANCE.
#     5. Then the agents pay the cost of living a round.
#     6. Cull() is called and every agent with energy less than ENERGY_REQUIRED_FOR_LIVING is deleted from the simulation.
#     7. The remaing of the agents then reproduce if they have energy greater than ENERGY_REQUIRED_FOR_REPRODUCTION.
#     8. Data is collected stored for further analysis.
# 3. After the simulation ends we analyze and compare the data collected with the  theoretically calculated MSNE.

# %%
STARTING_DOVES = 1000*10
STARTING_HAWKS = 1000
STARTING_POPULATION = STARTING_HAWKS + STARTING_DOVES

ROUNDS = 200
STARTING_ENERGY = 100

MIN_FOOD_PER_ROUND = 60
MAX_FOOD_PER_ROUND = 70
MAX_FOOD_APPEARANCE = 1000 # this tells how much max food can be found
ENERGY_REQUIRED_FOR_REPRODUCTION = 250
ENERGY_LOSS_PER_ROUND = 4
ENERGY_LOSS_FROM_FIGHTING = 50+30
ENERGY_REQUIRED_FOR_LIVING = 10

STATUS_ACTIVE = "active"
STATUS_ASLEEP = "asleep"

TYPE_HAWK = "hawk"
TYPE_DOVE = "dove"

agents = []

# Graph stuff
graph_hawk_points = []
graph_dove_points = []

AGENT_ID = 1
class Agent:
    
    def __init__(self, agent_type, status, energy):
        global AGENT_ID
        self.id = AGENT_ID
        AGENT_ID += 1
        self.agent_type = agent_type
        self.status = status
        self.energy = energy
    def wake(self):
        self.status = STATUS_ACTIVE
    def sleep(self):
        self.status = STATUS_ASLEEP

def gameInit():
    global agents
    agents = []
    for x in range(0,STARTING_DOVES):
        a = Agent(TYPE_DOVE, STATUS_ASLEEP, STARTING_ENERGY)
        agents.append(a)
    for x in range(0,STARTING_HAWKS):
        a = Agent(TYPE_HAWK, STATUS_ASLEEP, STARTING_ENERGY)
        agents.append(a)

def compete(agent, nemesis, food):
# add a food fuction inside agent
    if agent.agent_type == TYPE_HAWK and nemesis.agent_type == TYPE_HAWK:
        # food distributed as food // 2 and loss from fighting subtracted
        agent.energy += (food//2)
        agent.energy -= ENERGY_LOSS_FROM_FIGHTING
        nemesis.energy += (food//2)
        nemesis.energy -= ENERGY_LOSS_FROM_FIGHTING
        
    if agent.agent_type == TYPE_HAWK and nemesis.agent_type == TYPE_DOVE:
        agent.energy += food

    if agent.agent_type == TYPE_DOVE and nemesis.agent_type == TYPE_HAWK:
        nemesis.energy += food

    if agent.agent_type == TYPE_DOVE and nemesis.agent_type == TYPE_DOVE:
        agent.energy += (food//2)
        nemesis.energy += (food//2)

    nemesis.sleep()
    agent.sleep()
def cull():

    dead_hawks = 0
    dead_doves = 0
    n = len(agents)
    for index, agent in enumerate(reversed(agents)):
        if agent.energy < ENERGY_REQUIRED_FOR_LIVING:
            if agent.agent_type == TYPE_DOVE: dead_doves += 1
            if agent.agent_type == TYPE_HAWK: dead_hawks += 1
            del agents[n - index - 1]


    return dead_hawks, dead_doves
def breed():
    """
    If agent can breed, it halves its energy and produces 
    one baby with starting energy (parent energy // 2) and
    keep parent energy // 2 for itself
    """
    hawk_babies = 0
    dove_babies = 0
    for agent in agents:
        if agent.energy > ENERGY_REQUIRED_FOR_REPRODUCTION:
            baby_agent_a = Agent(agent.agent_type, STATUS_ASLEEP, (agent.energy//2))
            agents.append(baby_agent_a)

            agent.energy //= 2

            if agent.agent_type == TYPE_DOVE: dove_babies += 1
            if agent.agent_type == TYPE_HAWK: hawk_babies += 1


    return hawk_babies, dove_babies
def getCountOfType(agents):
    local_hawk_count = 0
    local_dove_count = 0
    for agent in agents:
        if agent.agent_type == TYPE_HAWK:
            local_hawk_count += 1
        else:
            local_dove_count += 1
    return local_hawk_count, local_dove_count
def getFood():
    return randint(MIN_FOOD_PER_ROUND, MAX_FOOD_PER_ROUND)
def awakenAgents():
    for agent in agents:
        agent.wake()
def main():
    gameInit()

    current_round = 1
    death_count = 0
    dead_hawks  = 0
    dead_doves  = 0
    breed_count = 0
    main_tic = time.time()
    
    while current_round <= ROUNDS and len(agents) > 2:
        print(f"Round {current_round}")
        tic = time.time()
        awakenAgents()
        food = getFood()
# shuffling agents so that the matchmaking while be random
        shuffle(agents)
        for idx in range (0, len(agents), 2):
            if idx//2 > MAX_FOOD_APPEARANCE:
                break
            if idx + 1 >= len(agents):
                break
            agent, nemesis = agents[idx], agents[idx + 1]
            compete(agent, nemesis, food)

        # Energy cost of 'living'
        for agent in agents:
            agent.energy -= ENERGY_LOSS_PER_ROUND
        
        round_dead_hawks, round_dead_doves = cull()
        round_hawk_babies, round_dove_babies = breed()
        death_count += (round_dead_hawks + round_dead_doves)
        breed_count += (round_hawk_babies + round_dove_babies)


        toc = time.time()
        # Plot
        hawk_count, dove_count = getCountOfType(agents)
        hawk_percent = (hawk_count / (hawk_count + dove_count))*100
        dove_percent = (dove_count / (hawk_count + dove_count))*100
        graph_hawk_points.append(hawk_count)
        graph_dove_points.append(dove_count)
        print("ROUND %d" % current_round)
        print("Food produced          : %d" % food)
        print(f"Population             : Hawks-> {hawk_count}, Doves-> {dove_count}")
        print("Dead hawks             : %d" % round_dead_hawks)
        print("Dead doves             : %d" % round_dead_doves)
        print("Hawk babies            : %s" % round_hawk_babies)
        print("Dove babies            : %s" % round_dove_babies)
        print("Hawks                  : %s" % hawk_percent)
        print("Doves                  : %s" % dove_percent)
        print("----")
        print("Round Processing time  : %s" % (toc - tic))
        print("Elapsed time           : %s\n" % (time.time() - main_tic))

        

        current_round += 1


    main_toc = time.time()
    hawk_count, dove_count = getCountOfType(agents)
    hawk_percent = (hawk_count / (hawk_count + dove_count))*100
    dove_percent = (dove_count / (hawk_count + dove_count))*100
    print("=============================================================")
    print("Total dead agents      : %d" % death_count)
    print("Total breeding agents  : %d" % breed_count)
    print("Total rounds completed : %d" % (current_round - 1))
    print("Total population size  : %s" % len(agents))
    print("Hawks                  : %s" % hawk_percent)
    print("Doves                  : %s" % dove_percent)
    print("Processing time        : %s" % (main_toc - main_tic))
    print("=============================================================")
main()
# Out:
# Round 1
# ROUND 1
# Food produced          : 62
# Population             : Hawks-> 1000, Doves-> 10000
# Dead hawks             : 0
# Dead doves             : 0
# Hawk babies            : 0
# Dove babies            : 0
# Hawks                  : 9.090909090909092
# Doves                  : 90.9090909090909
# ----
# Round Processing time  : 0.018943071365356445
# Elapsed time           : 0.0229341983795166
#
# Round 2
# ROUND 2
# Food produced          : 64
# Population             : Hawks-> 999, Doves-> 10000
# Dead hawks             : 1
# Dead doves             : 0
# Hawk babies            : 0
# Dove babies            : 0
# Hawks                  : 9.082643876716064
# Doves                  : 90.91735612328394
# ----
# Round Processing time  : 0.01995086669921875
# Elapsed time           : 0.04587078094482422
#
# Round 3
# ROUND 3
# Food produced          : 60
# Population             : Hawks-> 1000, Doves-> 10000
# Dead hawks             : 1
# Dead doves             : 0
# Hawk babies            : 2
# Dove babies            : 0
# Hawks                  : 9.090909090909092
# Doves                  : 90.9090909090909
# ----
# Round Processing time  : 0.017962217330932617
# Elapsed time           : 0.06682085990905762
#
# Round 4
# ROUND 4
# Food produced          : 67
# Population             : Hawks-> 1014, Doves-> 10000
# Dead hawks             : 0
# Dead doves             : 0
# Hawk babies            : 14
# Dove babies            : 0
# Hawks                  : 9.20646449972762
# Doves                  : 90.79353550027238
# ----
# Round Processing time  : 0.01894998550415039
# Elapsed time           : 0.08876228332519531
#
# Round 5
# ROUND 5
# Food produced          : 70
# Population             : Hawks-> 1037, Doves-> 10000
# Dead hawks             : 0
# Dead doves             : 0
# Hawk babies            : 23
# Dove babies            : 0
# Hawks                  : 9.395669112983601
# Doves                  : 90.6043308870164
# ----
# Round Processing time  : 0.01994180679321289
# Elapsed time           : 0.11070370674133301
#
# Round 6
# ROUND 6
# Food produced          : 67
# Population             : Hawks-> 1056, Doves-> 10000
# Dead hawks             : 2
# Dead doves             : 0
# Hawk babies            : 21
# Dove babies            : 0
# Hawks                  : 9.55137481910275
# Doves                  : 90.44862518089725
# ----
# Round Processing time  : 0.018949508666992188
# Elapsed time           : 0.1316511631011963
#
# Round 7
# ROUND 7
# Food produced          : 63
# Population             : Hawks-> 1082, Doves-> 10000
# Dead hawks             : 0
# Dead doves             : 0
# Hawk babies            : 26
# Dove babies            : 0
# Hawks                  : 9.763580581122541
# Doves                  : 90.23641941887746
# ----
# Round Processing time  : 0.02389240264892578
# Elapsed time           : 0.15757179260253906
#
# Round 8
# ROUND 8
# Food produced          : 60
# Population             : Hawks-> 1117, Doves-> 10002
# Dead hawks             : 1
# Dead doves             : 0
# Hawk babies            : 36
# Dove babies            : 2
# Hawks                  : 10.045867434121773
# Doves                  : 89.95413256587823
# ----
# Round Processing time  : 0.018964767456054688
# Elapsed time           : 0.17852234840393066
#
# Round 9
# ROUND 9
# Food produced          : 66
# Population             : Hawks-> 1155, Doves-> 10010
# Dead hawks             : 1
# Dead doves             : 0
# Hawk babies            : 39
# Dove babies            : 8
# Hawks                  : 10.344827586206897
# Doves                  : 89.65517241379311
# ----
# Round Processing time  : 0.019947528839111328
# Elapsed time           : 0.20046377182006836
#
# Round 10
# ROUND 10
# Food produced          : 68
# Population             : Hawks-> 1202, Doves-> 10023
# Dead hawks             : 0
# Dead doves             : 0
# Hawk babies            : 47
# Dove babies            : 13
# Hawks                  : 10.708240534521158
# Doves                  : 89.29175946547883
# ----
# Round Processing time  : 0.018949270248413086
# Elapsed time           : 0.22141098976135254
#
# Round 11
# ROUND 11
# Food produced          : 64
# Population             : Hawks-> 1205, Doves-> 10029
# Dead hawks             : 21
# Dead doves             : 0
# Hawk babies            : 24
# Dove babies            : 6
# Hawks                  : 10.726366387751469
# Doves                  : 89.27363361224853
# ----
# Round Processing time  : 0.01894998550415039
# Elapsed time           : 0.24235200881958008
#
# Round 12
# ROUND 12
# Food produced          : 69
# Population             : Hawks-> 1227, Doves-> 10036
# Dead hawks             : 6
# Dead doves             : 0
# Hawk babies            : 28
# Dove babies            : 7
# Hawks                  : 10.894077954363848
# Doves                  : 89.10592204563615
# ----
# Round Processing time  : 0.019942045211791992
# Elapsed time           : 0.26524925231933594
#
# Round 13
# ROUND 13
# Food produced          : 61
# Population             : Hawks-> 1244, Doves-> 10042
# Dead hawks             : 4
# Dead doves             : 0
# Hawk babies            : 21
# Dove babies            : 6
# Hawks                  : 11.022505759347863
# Doves                  : 88.97749424065213
# ----
# Round Processing time  : 0.021982192993164062
# Elapsed time           : 0.2892265319824219
#
# Round 14
# ROUND 14
# Food produced          : 66
# Population             : Hawks-> 1269, Doves-> 10057
# Dead hawks             : 4
# Dead doves             : 0
# Hawk babies            : 29
# Dove babies            : 15
# Hawks                  : 11.204308670316086
# Doves                  : 88.79569132968392
# ----
# Round Processing time  : 0.020944833755493164
# Elapsed time           : 0.31316399574279785
#
# Round 15
# ROUND 15
# Food produced          : 69
# Population             : Hawks-> 1299, Doves-> 10074
# Dead hawks             : 3
# Dead doves             : 0
# Hawk babies            : 33
# Dove babies            : 17
# Hawks                  : 11.421788446320232
# Doves                  : 88.57821155367976
# ----
# Round Processing time  : 0.018949031829833984
# Elapsed time           : 0.3351168632507324
#
# Round 16
# ROUND 16
# Food produced          : 67
# Population             : Hawks-> 1327, Doves-> 10098
# Dead hawks             : 5
# Dead doves             : 0
# Hawk babies            : 33
# Dove babies            : 24
# Hawks                  : 11.61487964989059
# Doves                  : 88.38512035010942
# ----
# Round Processing time  : 0.019893646240234375
# Elapsed time           : 0.3650176525115967
#
# Round 17
# ROUND 17
# Food produced          : 60
# Population             : Hawks-> 1366, Doves-> 10133
# Dead hawks             : 3
# Dead doves             : 0
# Hawk babies            : 42
# Dove babies            : 35
# Hawks                  : 11.879293851639273
# Doves                  : 88.12070614836072
# ----
# Round Processing time  : 0.026934146881103516
# Elapsed time           : 0.393939733505249
#
# Round 18
# ROUND 18
# Food produced          : 69
# Population             : Hawks-> 1404, Doves-> 10186
# Dead hawks             : 4
# Dead doves             : 0
# Hawk babies            : 42
# Dove babies            : 53
# Hawks                  : 12.113891285591025
# Doves                  : 87.88610871440898
# ----
# Round Processing time  : 0.021941184997558594
# Elapsed time           : 0.4188401699066162
#
# Round 19
# ROUND 19
# Food produced          : 60
# Population             : Hawks-> 1457, Doves-> 10205
# Dead hawks             : 2
# Dead doves             : 0
# Hawk babies            : 55
# Dove babies            : 19
# Hawks                  : 12.493568856113873
# Doves                  : 87.50643114388612
# ----
# Round Processing time  : 0.02593088150024414
# Elapsed time           : 0.4468057155609131
#
# Round 20
# ROUND 20
# Food produced          : 63
# Population             : Hawks-> 1509, Doves-> 10213
# Dead hawks             : 4
# Dead doves             : 0
# Hawk babies            : 56
# Dove babies            : 8
# Hawks                  : 12.873229824262072
# Doves                  : 87.12677017573793
# ----
# Round Processing time  : 0.020943164825439453
# Elapsed time           : 0.4707345962524414
#
# Round 21
# ROUND 21
# Food produced          : 60
# Population             : Hawks-> 1565, Doves-> 10227
# Dead hawks             : 2
# Dead doves             : 0
# Hawk babies            : 58
# Dove babies            : 14
# Hawks                  : 13.271709633649934
# Doves                  : 86.72829036635007
# ----
# Round Processing time  : 0.018955230712890625
# Elapsed time           : 0.4926784038543701
#
# Round 22
# ROUND 22
# Food produced          : 63
# Population             : Hawks-> 1609, Doves-> 10252
# Dead hawks             : 0
# Dead doves             : 0
# Hawk babies            : 44
# Dove babies            : 25
# Hawks                  : 13.565466655425343
# Doves                  : 86.43453334457466
# ----
# Round Processing time  : 0.020947933197021484
# Elapsed time           : 0.5156223773956299
#
# Round 23
# ROUND 23
# Food produced          : 68
# Population             : Hawks-> 1655, Doves-> 10100
# Dead hawks             : 10
# Dead doves             : 193
# Hawk babies            : 56
# Dove babies            : 41
# Hawks                  : 14.07911527009783
# Doves                  : 85.92088472990217
# ----
# Round Processing time  : 0.02094435691833496
# Elapsed time           : 0.5385603904724121
#
# Round 24
# ROUND 24
# Food produced          : 63
# Population             : Hawks-> 1701, Doves-> 10155
# Dead hawks             : 0
# Dead doves             : 0
# Hawk babies            : 46
# Dove babies            : 55
# Hawks                  : 14.347165991902832
# Doves                  : 85.65283400809717
# ----
# Round Processing time  : 0.019906997680664062
# Elapsed time           : 0.5614924430847168
#
# Round 25
# ROUND 25
# Food produced          : 61
# Population             : Hawks-> 1742, Doves-> 10192
# Dead hawks             : 4
# Dead doves             : 0
# Hawk babies            : 45
# Dove babies            : 37
# Hawks                  : 14.596949891067537
# Doves                  : 85.40305010893246
# ----
# Round Processing time  : 0.01995396614074707
# Elapsed time           : 0.5834393501281738
#
# Round 26
# ROUND 26
# Food produced          : 69
# Population             : Hawks-> 1790, Doves-> 10249
# Dead hawks             : 6
# Dead doves             : 0
# Hawk babies            : 54
# Dove babies            : 57
# Hawks                  : 14.868344546889276
# Doves                  : 85.13165545311072
# ----
# Round Processing time  : 0.021944284439086914
# Elapsed time           : 0.6073753833770752
#
# Round 27
# ROUND 27
# Food produced          : 61
# Population             : Hawks-> 1824, Doves-> 10259
# Dead hawks             : 5
# Dead doves             : 0
# Hawk babies            : 39
# Dove babies            : 10
# Hawks                  : 15.095588843830173
# Doves                  : 84.90441115616983
# ----
# Round Processing time  : 0.020943880081176758
# Elapsed time           : 0.6313061714172363
#
# Round 28
# ROUND 28
# Food produced          : 66
# Population             : Hawks-> 1877, Doves-> 10281
# Dead hawks             : 6
# Dead doves             : 0
# Hawk babies            : 59
# Dove babies            : 22
# Hawks                  : 15.438394472775126
# Doves                  : 84.56160552722487
# ----
# Round Processing time  : 0.019953250885009766
# Elapsed time           : 0.654249906539917
#
# Round 29
# ROUND 29
# Food produced          : 67
# Population             : Hawks-> 1928, Doves-> 10302
# Dead hawks             : 3
# Dead doves             : 0
# Hawk babies            : 54
# Dove babies            : 21
# Hawks                  : 15.764513491414556
# Doves                  : 84.23548650858544
# ----
# Round Processing time  : 0.01995062828063965
# Elapsed time           : 0.686124324798584
#
# Round 30
# ROUND 30
# Food produced          : 60
# Population             : Hawks-> 1982, Doves-> 10338
# Dead hawks             : 5
# Dead doves             : 0
# Hawk babies            : 59
# Dove babies            : 36
# Hawks                  : 16.087662337662337
# Doves                  : 83.91233766233766
# ----
# Round Processing time  : 0.025966405868530273
# Elapsed time           : 0.7140843868255615
#
# Round 31
# ROUND 31
# Food produced          : 67
# Population             : Hawks-> 2034, Doves-> 10223
# Dead hawks             : 4
# Dead doves             : 155
# Hawk babies            : 56
# Dove babies            : 40
# Hawks                  : 16.594599004650405
# Doves                  : 83.4054009953496
# ----
# Round Processing time  : 0.020949363708496094
# Elapsed time           : 0.7380294799804688
#
# Round 32
# ROUND 32
# Food produced          : 65
# Population             : Hawks-> 2088, Doves-> 10217
# Dead hawks             : 3
# Dead doves             : 56
# Hawk babies            : 57
# Dove babies            : 50
# Hawks                  : 16.96871190572938
# Doves                  : 83.03128809427062
# ----
# Round Processing time  : 0.02094101905822754
# Elapsed time           : 0.7619223594665527
#
# Round 33
# ROUND 33
# Food produced          : 68
# Population             : Hawks-> 2146, Doves-> 10290
# Dead hawks             : 7
# Dead doves             : 0
# Hawk babies            : 65
# Dove babies            : 73
# Hawks                  : 17.256352524927628
# Doves                  : 82.74364747507236
# ----
# Round Processing time  : 0.02098703384399414
# Elapsed time           : 0.7849009037017822
#
# Round 34
# ROUND 34
# Food produced          : 63
# Population             : Hawks-> 2190, Doves-> 10337
# Dead hawks             : 1
# Dead doves             : 0
# Hawk babies            : 45
# Dove babies            : 47
# Hawks                  : 17.482238365131316
# Doves                  : 82.51776163486868
# ----
# Round Processing time  : 0.021940946578979492
# Elapsed time           : 0.809837818145752
#
# Round 35
# ROUND 35
# Food produced          : 65
# Population             : Hawks-> 2246, Doves-> 10356
# Dead hawks             : 3
# Dead doves             : 0
# Hawk babies            : 59
# Dove babies            : 19
# Hawks                  : 17.82256784637359
# Doves                  : 82.17743215362641
# ----
# Round Processing time  : 0.020940780639648438
# Elapsed time           : 0.8337738513946533
#
# Round 36
# ROUND 36
# Food produced          : 67
# Population             : Hawks-> 2323, Doves-> 10369
# Dead hawks             : 7
# Dead doves             : 0
# Hawk babies            : 84
# Dove babies            : 13
# Hawks                  : 18.302867948313896
# Doves                  : 81.69713205168611
# ----
# Round Processing time  : 0.021939516067504883
# Elapsed time           : 0.8586990833282471
#
# Round 37
# ROUND 37
# Food produced          : 68
# Population             : Hawks-> 2395, Doves-> 10394
# Dead hawks             : 2
# Dead doves             : 0
# Hawk babies            : 74
# Dove babies            : 25
# Hawks                  : 18.727031042301977
# Doves                  : 81.27296895769803
# ----
# Round Processing time  : 0.020949840545654297
# Elapsed time           : 0.8826329708099365
#
# Round 38
# ROUND 38
# Food produced          : 60
# Population             : Hawks-> 2445, Doves-> 10375
# Dead hawks             : 7
# Dead doves             : 59
# Hawk babies            : 57
# Dove babies            : 40
# Hawks                  : 19.07176287051482
# Doves                  : 80.92823712948518
# ----
# Round Processing time  : 0.020952224731445312
# Elapsed time           : 0.9065766334533691
#
# Round 39
# ROUND 39
# Food produced          : 63
# Population             : Hawks-> 2495, Doves-> 10231
# Dead hawks             : 13
# Dead doves             : 181
# Hawk babies            : 63
# Dove babies            : 37
# Hawks                  : 19.605531981769605
# Doves                  : 80.3944680182304
# ----
# Round Processing time  : 0.026927471160888672
# Elapsed time           : 0.936490535736084
#
# Round 40
# ROUND 40
# Food produced          : 68
# Population             : Hawks-> 2548, Doves-> 10211
# Dead hawks             : 5
# Dead doves             : 64
# Hawk babies            : 58
# Dove babies            : 44
# Hawks                  : 19.970217101653734
# Doves                  : 80.02978289834627
# ----
# Round Processing time  : 0.027930736541748047
# Elapsed time           : 0.967411994934082
#
# Round 41
# ROUND 41
# Food produced          : 70
# Population             : Hawks-> 2607, Doves-> 10268
# Dead hawks             : 11
# Dead doves             : 0
# Hawk babies            : 70
# Dove babies            : 57
# Hawks                  : 20.24854368932039
# Doves                  : 79.75145631067961
# ----
# Round Processing time  : 0.02194666862487793
# Elapsed time           : 0.9913489818572998
#
# Round 42
# ROUND 42
# Food produced          : 62
# Population             : Hawks-> 2645, Doves-> 10309
# Dead hawks             : 11
# Dead doves             : 0
# Hawk babies            : 49
# Dove babies            : 41
# Hawks                  : 20.418403581905203
# Doves                  : 79.5815964180948
# ----
# Round Processing time  : 0.022943496704101562
# Elapsed time           : 1.0182781219482422
#
# Round 43
# ROUND 43
# Food produced          : 65
# Population             : Hawks-> 2703, Doves-> 10354
# Dead hawks             : 11
# Dead doves             : 0
# Hawk babies            : 69
# Dove babies            : 45
# Hawks                  : 20.70153940415103
# Doves                  : 79.29846059584898
# ----
# Round Processing time  : 0.022940874099731445
# Elapsed time           : 1.044203758239746
#
# Round 44
# ROUND 44
# Food produced          : 70
# Population             : Hawks-> 2760, Doves-> 10387
# Dead hawks             : 5
# Dead doves             : 0
# Hawk babies            : 62
# Dove babies            : 33
# Hawks                  : 20.99338252072716
# Doves                  : 79.00661747927283
# ----
# Round Processing time  : 0.021947145462036133
# Elapsed time           : 1.0691406726837158
#
# Round 45
# ROUND 45
# Food produced          : 62
# Population             : Hawks-> 2807, Doves-> 10400
# Dead hawks             : 11
# Dead doves             : 0
# Hawk babies            : 58
# Dove babies            : 13
# Hawks                  : 21.25388051790717
# Doves                  : 78.74611948209282
# ----
# Round Processing time  : 0.0219419002532959
# Elapsed time           : 1.0940742492675781
#
# Round 46
# ROUND 46
# Food produced          : 61
# Population             : Hawks-> 2847, Doves-> 10358
# Dead hawks             : 10
# Dead doves             : 57
# Hawk babies            : 50
# Dove babies            : 15
# Hawks                  : 21.560015145778113
# Doves                  : 78.43998485422189
# ----
# Round Processing time  : 0.02293848991394043
# Elapsed time           : 1.120004653930664
#
# Round 47
# ROUND 47
# Food produced          : 68
# Population             : Hawks-> 2907, Doves-> 10259
# Dead hawks             : 9
# Dead doves             : 139
# Hawk babies            : 69
# Dove babies            : 40
# Hawks                  : 22.079598967036308
# Doves                  : 77.9204010329637
# ----
# Round Processing time  : 0.022937774658203125
# Elapsed time           : 1.1449382305145264
#
# Round 48
# ROUND 48
# Food produced          : 67
# Population             : Hawks-> 2970, Doves-> 10217
# Dead hawks             : 7
# Dead doves             : 81
# Hawk babies            : 70
# Dove babies            : 39
# Hawks                  : 22.522180935770074
# Doves                  : 77.47781906422992
# ----
# Round Processing time  : 0.02692866325378418
# Elapsed time           : 1.1748595237731934
#
# Round 49
# ROUND 49
# Food produced          : 67
# Population             : Hawks-> 3024, Doves-> 10265
# Dead hawks             : 12
# Dead doves             : 3
# Hawk babies            : 66
# Dove babies            : 51
# Hawks                  : 22.75566257807209
# Doves                  : 77.24433742192791
# ----
# Round Processing time  : 0.024931669235229492
# Elapsed time           : 1.2017858028411865
#
# Round 50
# ROUND 50
# Food produced          : 70
# Population             : Hawks-> 3084, Doves-> 10313
# Dead hawks             : 12
# Dead doves             : 0
# Hawk babies            : 72
# Dove babies            : 48
# Hawks                  : 23.020079122191536
# Doves                  : 76.97992087780847
# ----
# Round Processing time  : 0.023937225341796875
# Elapsed time           : 1.228708267211914
#
# Round 51
# ROUND 51
# Food produced          : 69
# Population             : Hawks-> 3146, Doves-> 10353
# Dead hawks             : 13
# Dead doves             : 0
# Hawk babies            : 75
# Dove babies            : 40
# Hawks                  : 23.30543003185421
# Doves                  : 76.69456996814579
# ----
# Round Processing time  : 0.029925823211669922
# Elapsed time           : 1.2616257667541504
#
# Round 52
# ROUND 52
# Food produced          : 68
# Population             : Hawks-> 3196, Doves-> 10376
# Dead hawks             : 17
# Dead doves             : 1
# Hawk babies            : 67
# Dove babies            : 24
# Hawks                  : 23.548482169171827
# Doves                  : 76.45151783082818
# ----
# Round Processing time  : 0.022938966751098633
# Elapsed time           : 1.28755521774292
#
# Round 53
# ROUND 53
# Food produced          : 60
# Population             : Hawks-> 3219, Doves-> 10378
# Dead hawks             : 23
# Dead doves             : 5
# Hawk babies            : 46
# Dove babies            : 7
# Hawks                  : 23.674339927925278
# Doves                  : 76.32566007207473
# ----
# Round Processing time  : 0.022940397262573242
# Elapsed time           : 1.3134887218475342
#
# Round 54
# ROUND 54
# Food produced          : 69
# Population             : Hawks-> 3277, Doves-> 10332
# Dead hawks             : 17
# Dead doves             : 71
# Hawk babies            : 75
# Dove babies            : 25
# Hawks                  : 24.079653170695863
# Doves                  : 75.92034682930414
# ----
# Round Processing time  : 0.022940635681152344
# Elapsed time           : 1.3394184112548828
#
# Round 55
# ROUND 55
# Food produced          : 60
# Population             : Hawks-> 3328, Doves-> 10229
# Dead hawks             : 16
# Dead doves             : 132
# Hawk babies            : 67
# Dove babies            : 29
# Hawks                  : 24.548203879914436
# Doves                  : 75.45179612008556
# ----
# Round Processing time  : 0.024932861328125
# Elapsed time           : 1.3663475513458252
#
# Round 56
# ROUND 56
# Food produced          : 61
# Population             : Hawks-> 3363, Doves-> 10182
# Dead hawks             : 22
# Dead doves             : 87
# Hawk babies            : 57
# Dove babies            : 40
# Hawks                  : 24.828349944629014
# Doves                  : 75.17165005537099
# ----
# Round Processing time  : 0.030916213989257812
# Elapsed time           : 1.4002492427825928
#
# Round 57
# ROUND 57
# Food produced          : 70
# Population             : Hawks-> 3417, Doves-> 10201
# Dead hawks             : 19
# Dead doves             : 16
# Hawk babies            : 73
# Dove babies            : 35
# Hawks                  : 25.0917902775738
# Doves                  : 74.9082097224262
# ----
# Round Processing time  : 0.022944927215576172
# Elapsed time           : 1.4261868000030518
#
# Round 58
# ROUND 58
# Food produced          : 63
# Population             : Hawks-> 3457, Doves-> 10246
# Dead hawks             : 22
# Dead doves             : 0
# Hawk babies            : 62
# Dove babies            : 45
# Hawks                  : 25.228052251331825
# Doves                  : 74.77194774866818
# ----
# Round Processing time  : 0.022938966751098633
# Elapsed time           : 1.4521169662475586
#
# Round 59
# ROUND 59
# Food produced          : 64
# Population             : Hawks-> 3501, Doves-> 10272
# Dead hawks             : 18
# Dead doves             : 0
# Hawk babies            : 62
# Dove babies            : 26
# Hawks                  : 25.41929862774995
# Doves                  : 74.58070137225006
# ----
# Round Processing time  : 0.023935317993164062
# Elapsed time           : 1.4800357818603516
#
# Round 60
# ROUND 60
# Food produced          : 61
# Population             : Hawks-> 3525, Doves-> 10279
# Dead hawks             : 24
# Dead doves             : 1
# Hawk babies            : 48
# Dove babies            : 8
# Hawks                  : 25.53607649956534
# Doves                  : 74.46392350043466
# ----
# Round Processing time  : 0.02294445037841797
# Elapsed time           : 1.5059814453125
#
# Round 61
# ROUND 61
# Food produced          : 69
# Population             : Hawks-> 3572, Doves-> 10296
# Dead hawks             : 24
# Dead doves             : 5
# Hawk babies            : 71
# Dove babies            : 22
# Hawks                  : 25.757138736659936
# Doves                  : 74.24286126334006
# ----
# Round Processing time  : 0.02392721176147461
# Elapsed time           : 1.5329010486602783
#
# Round 62
# ROUND 62
# Food produced          : 67
# Population             : Hawks-> 3597, Doves-> 10271
# Dead hawks             : 31
# Dead doves             : 58
# Hawk babies            : 56
# Dove babies            : 33
# Hawks                  : 25.937409864436113
# Doves                  : 74.0625901355639
# ----
# Round Processing time  : 0.023935317993164062
# Elapsed time           : 1.558830976486206
#
# Round 63
# ROUND 63
# Food produced          : 67
# Population             : Hawks-> 3637, Doves-> 10170
# Dead hawks             : 17
# Dead doves             : 125
# Hawk babies            : 57
# Dove babies            : 24
# Hawks                  : 26.341710726443107
# Doves                  : 73.65828927355689
# ----
# Round Processing time  : 0.02688884735107422
# Elapsed time           : 1.5877132415771484
#
# Round 64
# ROUND 64
# Food produced          : 64
# Population             : Hawks-> 3675, Doves-> 10108
# Dead hawks             : 21
# Dead doves             : 99
# Hawk babies            : 59
# Dove babies            : 37
# Hawks                  : 26.663280853224986
# Doves                  : 73.33671914677501
# ----
# Round Processing time  : 0.02496790885925293
# Elapsed time           : 1.615680456161499
#
# Round 65
# ROUND 65
# Food produced          : 65
# Population             : Hawks-> 3703, Doves-> 10119
# Dead hawks             : 33
# Dead doves             : 35
# Hawk babies            : 61
# Dove babies            : 46
# Hawks                  : 26.790623643466937
# Doves                  : 73.20937635653306
# ----
# Round Processing time  : 0.03090953826904297
# Elapsed time           : 1.6495819091796875
#
# Round 66
# ROUND 66
# Food produced          : 60
# Population             : Hawks-> 3726, Doves-> 10138
# Dead hawks             : 22
# Dead doves             : 3
# Hawk babies            : 45
# Dove babies            : 22
# Hawks                  : 26.87536064627813
# Doves                  : 73.12463935372186
# ----
# Round Processing time  : 0.0249330997467041
# Elapsed time           : 1.67750883102417
#
# Round 67
# ROUND 67
# Food produced          : 70
# Population             : Hawks-> 3760, Doves-> 10174
# Dead hawks             : 29
# Dead doves             : 0
# Hawk babies            : 63
# Dove babies            : 36
# Hawks                  : 26.984354815559065
# Doves                  : 73.01564518444094
# ----
# Round Processing time  : 0.02293705940246582
# Elapsed time           : 1.7034385204315186
#
# Round 68
# ROUND 68
# Food produced          : 64
# Population             : Hawks-> 3789, Doves-> 10189
# Dead hawks             : 31
# Dead doves             : 0
# Hawk babies            : 60
# Dove babies            : 15
# Hawks                  : 27.106882243525536
# Doves                  : 72.89311775647445
# ----
# Round Processing time  : 0.02393507957458496
# Elapsed time           : 1.7303318977355957
#
# Round 69
# ROUND 69
# Food produced          : 65
# Population             : Hawks-> 3812, Doves-> 10194
# Dead hawks             : 26
# Dead doves             : 14
# Hawk babies            : 49
# Dove babies            : 19
# Hawks                  : 27.216907039840066
# Doves                  : 72.78309296015993
# ----
# Round Processing time  : 0.023972272872924805
# Elapsed time           : 1.7573003768920898
#
# Round 70
# ROUND 70
# Food produced          : 63
# Population             : Hawks-> 3855, Doves-> 10141
# Dead hawks             : 32
# Dead doves             : 76
# Hawk babies            : 75
# Dove babies            : 23
# Hawks                  : 27.54358388110889
# Doves                  : 72.45641611889111
# ----
# Round Processing time  : 0.023931264877319336
# Elapsed time           : 1.7842283248901367
#
# Round 71
# ROUND 71
# Food produced          : 70
# Population             : Hawks-> 3911, Doves-> 10014
# Dead hawks             : 25
# Dead doves             : 143
# Hawk babies            : 81
# Dove babies            : 16
# Hawks                  : 28.086175942549374
# Doves                  : 71.91382405745063
# ----
# Round Processing time  : 0.023932456970214844
# Elapsed time           : 1.8141076564788818
#
# Round 72
# ROUND 72
# Food produced          : 70
# Population             : Hawks-> 3963, Doves-> 9915
# Dead hawks             : 38
# Dead doves             : 126
# Hawk babies            : 90
# Dove babies            : 27
# Hawks                  : 28.555987894509293
# Doves                  : 71.4440121054907
# ----
# Round Processing time  : 0.030948400497436523
# Elapsed time           : 1.8470563888549805
#
# Round 73
# ROUND 73
# Food produced          : 66
# Population             : Hawks-> 4001, Doves-> 9892
# Dead hawks             : 34
# Dead doves             : 46
# Hawk babies            : 72
# Dove babies            : 23
# Hawks                  : 28.798675592024757
# Doves                  : 71.20132440797524
# ----
# Round Processing time  : 0.024930477142333984
# Elapsed time           : 1.8739840984344482
#
# Round 74
# ROUND 74
# Food produced          : 67
# Population             : Hawks-> 4031, Doves-> 9920
# Dead hawks             : 31
# Dead doves             : 7
# Hawk babies            : 61
# Dove babies            : 35
# Hawks                  : 28.893986094186797
# Doves                  : 71.1060139058132
# ----
# Round Processing time  : 0.024930953979492188
# Elapsed time           : 1.9019279479980469
#
# Round 75
# ROUND 75
# Food produced          : 64
# Population             : Hawks-> 4058, Doves-> 9934
# Dead hawks             : 32
# Dead doves             : 2
# Hawk babies            : 59
# Dove babies            : 16
# Hawks                  : 29.00228702115494
# Doves                  : 70.99771297884504
# ----
# Round Processing time  : 0.025911331176757812
# Elapsed time           : 1.9308297634124756
#
# Round 76
# ROUND 76
# Food produced          : 69
# Population             : Hawks-> 4102, Doves-> 9957
# Dead hawks             : 27
# Dead doves             : 5
# Hawk babies            : 71
# Dove babies            : 28
# Hawks                  : 29.177039618749557
# Doves                  : 70.82296038125044
# ----
# Round Processing time  : 0.023936033248901367
# Elapsed time           : 1.9577243328094482
#
# Round 77
# ROUND 77
# Food produced          : 62
# Population             : Hawks-> 4118, Doves-> 9939
# Dead hawks             : 39
# Dead doves             : 27
# Hawk babies            : 55
# Dove babies            : 9
# Hawks                  : 29.295013160702855
# Doves                  : 70.70498683929715
# ----
# Round Processing time  : 0.024967432022094727
# Elapsed time           : 1.9856858253479004
#
# Round 78
# ROUND 78
# Food produced          : 68
# Population             : Hawks-> 4143, Doves-> 9871
# Dead hawks             : 47
# Dead doves             : 77
# Hawk babies            : 72
# Dove babies            : 9
# Hawks                  : 29.563293849008133
# Doves                  : 70.43670615099187
# ----
# Round Processing time  : 0.023935317993164062
# Elapsed time           : 2.0116145610809326
#
# Round 79
# ROUND 79
# Food produced          : 66
# Population             : Hawks-> 4180, Doves-> 9739
# Dead hawks             : 45
# Dead doves             : 149
# Hawk babies            : 82
# Dove babies            : 17
# Hawks                  : 30.030893023924133
# Doves                  : 69.96910697607586
# ----
# Round Processing time  : 0.027925968170166016
# Elapsed time           : 2.041536331176758
#
# Round 80
# ROUND 80
# Food produced          : 67
# Population             : Hawks-> 4182, Doves-> 9643
# Dead hawks             : 56
# Dead doves             : 118
# Hawk babies            : 58
# Dove babies            : 22
# Hawks                  : 30.249547920433994
# Doves                  : 69.750452079566
# ----
# Round Processing time  : 0.028922319412231445
# Elapsed time           : 2.074445962905884
#
# Round 81
# ROUND 81
# Food produced          : 68
# Population             : Hawks-> 4214, Doves-> 9602
# Dead hawks             : 39
# Dead doves             : 70
# Hawk babies            : 71
# Dove babies            : 29
# Hawks                  : 30.5008685581934
# Doves                  : 69.49913144180661
# ----
# Round Processing time  : 0.024933576583862305
# Elapsed time           : 2.101374626159668
#
# Round 82
# ROUND 82
# Food produced          : 69
# Population             : Hawks-> 4246, Doves-> 9614
# Dead hawks             : 42
# Dead doves             : 16
# Hawk babies            : 74
# Dove babies            : 28
# Hawks                  : 30.634920634920636
# Doves                  : 69.36507936507937
# ----
# Round Processing time  : 0.02393507957458496
# Elapsed time           : 2.128302574157715
#
# Round 83
# ROUND 83
# Food produced          : 63
# Population             : Hawks-> 4273, Doves-> 9634
# Dead hawks             : 36
# Dead doves             : 1
# Hawk babies            : 63
# Dove babies            : 21
# Hawks                  : 30.725533903789458
# Doves                  : 69.27446609621055
# ----
# Round Processing time  : 0.023938894271850586
# Elapsed time           : 2.1552295684814453
#
# Round 84
# ROUND 84
# Food produced          : 60
# Population             : Hawks-> 4279, Doves-> 9643
# Dead hawks             : 44
# Dead doves             : 3
# Hawk babies            : 50
# Dove babies            : 12
# Hawks                  : 30.735526504812526
# Doves                  : 69.26447349518747
# ----
# Round Processing time  : 0.023936033248901367
# Elapsed time           : 2.1821625232696533
#
# Round 85
# ROUND 85
# Food produced          : 63
# Population             : Hawks-> 4290, Doves-> 9629
# Dead hawks             : 48
# Dead doves             : 24
# Hawk babies            : 59
# Dove babies            : 10
# Hawks                  : 30.821179682448452
# Doves                  : 69.17882031755155
# ----
# Round Processing time  : 0.02489471435546875
# Elapsed time           : 2.2100830078125
#
# Round 86
# ROUND 86
# Food produced          : 64
# Population             : Hawks-> 4308, Doves-> 9560
# Dead hawks             : 32
# Dead doves             : 74
# Hawk babies            : 50
# Dove babies            : 5
# Hawks                  : 31.06432073839054
# Doves                  : 68.93567926160947
# ----
# Round Processing time  : 0.029927730560302734
# Elapsed time           : 2.2449960708618164
#
# Round 87
# ROUND 87
# Food produced          : 68
# Population             : Hawks-> 4341, Doves-> 9417
# Dead hawks             : 42
# Dead doves             : 151
# Hawk babies            : 75
# Dove babies            : 8
# Hawks                  : 31.552551242913214
# Doves                  : 68.44744875708678
# ----
# Round Processing time  : 0.024936914443969727
# Elapsed time           : 2.2719273567199707
#
# Round 88
# ROUND 88
# Food produced          : 70
# Population             : Hawks-> 4364, Doves-> 9303
# Dead hawks             : 50
# Dead doves             : 131
# Hawk babies            : 73
# Dove babies            : 17
# Hawks                  : 31.93092851393868
# Doves                  : 68.06907148606132
# ----
# Round Processing time  : 0.024930953979492188
# Elapsed time           : 2.2988524436950684
#
# Round 89
# ROUND 89
# Food produced          : 65
# Population             : Hawks-> 4377, Doves-> 9237
# Dead hawks             : 40
# Dead doves             : 83
# Hawk babies            : 53
# Dove babies            : 17
# Hawks                  : 32.15072719259586
# Doves                  : 67.84927280740413
# ----
# Round Processing time  : 0.024923324584960938
# Elapsed time           : 2.325774669647217
#
# Round 90
# ROUND 90
# Food produced          : 62
# Population             : Hawks-> 4400, Doves-> 9239
# Dead hawks             : 44
# Dead doves             : 17
# Hawk babies            : 67
# Dove babies            : 19
# Hawks                  : 32.26042965026761
# Doves                  : 67.73957034973238
# ----
# Round Processing time  : 0.023935317993164062
# Elapsed time           : 2.352705240249634
#
# Round 91
# ROUND 91
# Food produced          : 68
# Population             : Hawks-> 4422, Doves-> 9264
# Dead hawks             : 48
# Dead doves             : 7
# Hawk babies            : 70
# Dove babies            : 32
# Hawks                  : 32.310390179745724
# Doves                  : 67.68960982025428
# ----
# Round Processing time  : 0.030914306640625
# Elapsed time           : 2.3866117000579834
#
# Round 92
# ROUND 92
# Food produced          : 61
# Population             : Hawks-> 4449, Doves-> 9268
# Dead hawks             : 45
# Dead doves             : 6
# Hawk babies            : 72
# Dove babies            : 10
# Hawks                  : 32.43420573011592
# Doves                  : 67.56579426988408
# ----
# Round Processing time  : 0.0329129695892334
# Elapsed time           : 2.4234776496887207
#
# Round 93
# ROUND 93
# Food produced          : 66
# Population             : Hawks-> 4451, Doves-> 9256
# Dead hawks             : 57
# Dead doves             : 23
# Hawk babies            : 59
# Dove babies            : 11
# Hawks                  : 32.47245932735099
# Doves                  : 67.52754067264901
# ----
# Round Processing time  : 0.025965452194213867
# Elapsed time           : 2.451434373855591
#
# Round 94
# ROUND 94
# Food produced          : 67
# Population             : Hawks-> 4457, Doves-> 9191
# Dead hawks             : 50
# Dead doves             : 77
# Hawk babies            : 56
# Dove babies            : 12
# Hawks                  : 32.656799531066824
# Doves                  : 67.34320046893318
# ----
# Round Processing time  : 0.024936676025390625
# Elapsed time           : 2.478365421295166
#
# Round 95
# ROUND 95
# Food produced          : 68
# Population             : Hawks-> 4471, Doves-> 9080
# Dead hawks             : 49
# Dead doves             : 125
# Hawk babies            : 63
# Dove babies            : 14
# Hawks                  : 32.99387499077559
# Doves                  : 67.00612500922442
# ----
# Round Processing time  : 0.023937225341796875
# Elapsed time           : 2.505293607711792
#
# Round 96
# ROUND 96
# Food produced          : 62
# Population             : Hawks-> 4492, Doves-> 8937
# Dead hawks             : 37
# Dead doves             : 158
# Hawk babies            : 58
# Dove babies            : 15
# Hawks                  : 33.44999627671457
# Doves                  : 66.55000372328543
# ----
# Round Processing time  : 0.023935794830322266
# Elapsed time           : 2.532222032546997
#
# Round 97
# ROUND 97
# Food produced          : 61
# Population             : Hawks-> 4483, Doves-> 8865
# Dead hawks             : 64
# Dead doves             : 89
# Hawk babies            : 55
# Dove babies            : 17
# Hawks                  : 33.58555588852262
# Doves                  : 66.41444411147738
# ----
# Round Processing time  : 0.022940397262573242
# Elapsed time           : 2.5581533908843994
#
# Round 98
# ROUND 98
# Food produced          : 61
# Population             : Hawks-> 4489, Doves-> 8853
# Dead hawks             : 46
# Dead doves             : 31
# Hawk babies            : 52
# Dove babies            : 19
# Hawks                  : 33.64563034027882
# Doves                  : 66.35436965972119
# ----
# Round Processing time  : 0.022937297821044922
# Elapsed time           : 2.584085702896118
#
# Round 99
# ROUND 99
# Food produced          : 65
# Population             : Hawks-> 4507, Doves-> 8860
# Dead hawks             : 52
# Dead doves             : 6
# Hawk babies            : 70
# Dove babies            : 13
# Hawks                  : 33.717363656766665
# Doves                  : 66.28263634323334
# ----
# Round Processing time  : 0.023935794830322266
# Elapsed time           : 2.610013484954834
#
# Round 100
# ROUND 100
# Food produced          : 68
# Population             : Hawks-> 4524, Doves-> 8872
# Dead hawks             : 49
# Dead doves             : 9
# Hawk babies            : 66
# Dove babies            : 21
# Hawks                  : 33.771275007464915
# Doves                  : 66.22872499253508
# ----
# Round Processing time  : 0.02293848991394043
# Elapsed time           : 2.637938976287842
#
# Round 101
# ROUND 101
# Food produced          : 60
# Population             : Hawks-> 4533, Doves-> 8853
# Dead hawks             : 53
# Dead doves             : 22
# Hawk babies            : 62
# Dove babies            : 3
# Hawks                  : 33.863738233975795
# Doves                  : 66.1362617660242
# ----
# Round Processing time  : 0.02692866325378418
# Elapsed time           : 2.6678590774536133
#
# Round 102
# ROUND 102
# Food produced          : 62
# Population             : Hawks-> 4512, Doves-> 8796
# Dead hawks             : 76
# Dead doves             : 62
# Hawk babies            : 55
# Dove babies            : 5
# Hawks                  : 33.90441839495041
# Doves                  : 66.09558160504959
# ----
# Round Processing time  : 0.02892279624938965
# Elapsed time           : 2.6997733116149902
#
# Round 103
# ROUND 103
# Food produced          : 68
# Population             : Hawks-> 4513, Doves-> 8697
# Dead hawks             : 59
# Dead doves             : 110
# Hawk babies            : 60
# Dove babies            : 11
# Hawks                  : 34.16351249053747
# Doves                  : 65.83648750946253
# ----
# Round Processing time  : 0.02393627166748047
# Elapsed time           : 2.72570538520813
#
# Round 104
# ROUND 104
# Food produced          : 65
# Population             : Hawks-> 4516, Doves-> 8562
# Dead hawks             : 62
# Dead doves             : 147
# Hawk babies            : 65
# Dove babies            : 12
# Hawks                  : 34.53127389509099
# Doves                  : 65.46872610490901
# ----
# Round Processing time  : 0.02294468879699707
# Elapsed time           : 2.7516372203826904
#
# Round 105
# ROUND 105
# Food produced          : 67
# Population             : Hawks-> 4502, Doves-> 8465
# Dead hawks             : 74
# Dead doves             : 116
# Hawk babies            : 60
# Dove babies            : 19
# Hawks                  : 34.71890182771651
# Doves                  : 65.28109817228349
# ----
# Round Processing time  : 0.022936344146728516
# Elapsed time           : 2.7775652408599854
#
# Round 106
# ROUND 106
# Food produced          : 67
# Population             : Hawks-> 4519, Doves-> 8450
# Dead hawks             : 58
# Dead doves             : 34
# Hawk babies            : 75
# Dove babies            : 19
# Hawks                  : 34.84462950111805
# Doves                  : 65.15537049888195
# ----
# Round Processing time  : 0.022938251495361328
# Elapsed time           : 2.8024954795837402
#
# Round 107
# ROUND 107
# Food produced          : 61
# Population             : Hawks-> 4546, Doves-> 8457
# Dead hawks             : 43
# Dead doves             : 9
# Hawk babies            : 70
# Dove babies            : 16
# Hawks                  : 34.961162808582635
# Doves                  : 65.03883719141737
# ----
# Round Processing time  : 0.022909164428710938
# Elapsed time           : 2.8284294605255127
#
# Round 108
# ROUND 108
# Food produced          : 66
# Population             : Hawks-> 4554, Doves-> 8453
# Dead hawks             : 56
# Dead doves             : 13
# Hawk babies            : 64
# Dove babies            : 9
# Hawks                  : 35.011916660259864
# Doves                  : 64.98808333974014
# ----
# Round Processing time  : 0.021938085556030273
# Elapsed time           : 2.8533642292022705
#
# Round 109
# ROUND 109
# Food produced          : 64
# Population             : Hawks-> 4554, Doves-> 8427
# Dead hawks             : 67
# Dead doves             : 28
# Hawk babies            : 67
# Dove babies            : 2
# Hawks                  : 35.082042985902476
# Doves                  : 64.91795701409752
# ----
# Round Processing time  : 0.0249330997467041
# Elapsed time           : 2.8812882900238037
#
# Round 110
# ROUND 110
# Food produced          : 60
# Population             : Hawks-> 4536, Doves-> 8360
# Dead hawks             : 65
# Dead doves             : 72
# Hawk babies            : 47
# Dove babies            : 5
# Hawks                  : 35.173697270471465
# Doves                  : 64.82630272952854
# ----
# Round Processing time  : 0.022938251495361328
# Elapsed time           : 2.9072329998016357
#
# Round 111
# ROUND 111
# Food produced          : 60
# Population             : Hawks-> 4515, Doves-> 8266
# Dead hawks             : 69
# Dead doves             : 102
# Hawk babies            : 48
# Dove babies            : 8
# Hawks                  : 35.32587434473046
# Doves                  : 64.67412565526955
# ----
# Round Processing time  : 0.02492499351501465
# Elapsed time           : 2.9351532459259033
#
# Round 112
# ROUND 112
# Food produced          : 67
# Population             : Hawks-> 4519, Doves-> 8148
# Dead hawks             : 56
# Dead doves             : 135
# Hawk babies            : 60
# Dove babies            : 17
# Hawks                  : 35.67537696376411
# Doves                  : 64.32462303623588
# ----
# Round Processing time  : 0.026924610137939453
# Elapsed time           : 2.964073896408081
#
# Round 113
# ROUND 113
# Food produced          : 63
# Population             : Hawks-> 4506, Doves-> 8068
# Dead hawks             : 67
# Dead doves             : 99
# Hawk babies            : 54
# Dove babies            : 19
# Hawks                  : 35.83585175759504
# Doves                  : 64.16414824240496
# ----
# Round Processing time  : 0.023940324783325195
# Elapsed time           : 2.9929897785186768
#
# Round 114
# ROUND 114
# Food produced          : 67
# Population             : Hawks-> 4501, Doves-> 8039
# Dead hawks             : 67
# Dead doves             : 43
# Hawk babies            : 62
# Dove babies            : 14
# Hawks                  : 35.89314194577353
# Doves                  : 64.10685805422648
# ----
# Round Processing time  : 0.021947860717773438
# Elapsed time           : 3.0169320106506348
#
# Round 115
# ROUND 115
# Food produced          : 68
# Population             : Hawks-> 4506, Doves-> 8041
# Dead hawks             : 64
# Dead doves             : 13
# Hawk babies            : 69
# Dove babies            : 15
# Hawks                  : 35.912967243165696
# Doves                  : 64.0870327568343
# ----
# Round Processing time  : 0.020938396453857422
# Elapsed time           : 3.0408613681793213
#
# Round 116
# ROUND 116
# Food produced          : 69
# Population             : Hawks-> 4504, Doves-> 8046
# Dead hawks             : 75
# Dead doves             : 13
# Hawk babies            : 73
# Dove babies            : 18
# Hawks                  : 35.88844621513944
# Doves                  : 64.11155378486055
# ----
# Round Processing time  : 0.022939443588256836
# Elapsed time           : 3.0657947063446045
#
# Round 117
# ROUND 117
# Food produced          : 60
# Population             : Hawks-> 4493, Doves-> 8012
# Dead hawks             : 78
# Dead doves             : 39
# Hawk babies            : 67
# Dove babies            : 5
# Hawks                  : 35.929628148740505
# Doves                  : 64.0703718512595
# ----
# Round Processing time  : 0.022939443588256836
# Elapsed time           : 3.0907278060913086
#
# Round 118
# ROUND 118
# Food produced          : 67
# Population             : Hawks-> 4510, Doves-> 7963
# Dead hawks             : 62
# Dead doves             : 60
# Hawk babies            : 79
# Dove babies            : 11
# Hawks                  : 36.158101499238356
# Doves                  : 63.84189850076164
# ----
# Round Processing time  : 0.023936748504638672
# Elapsed time           : 3.117666006088257
#
# Round 119
# ROUND 119
# Food produced          : 65
# Population             : Hawks-> 4525, Doves-> 7873
# Dead hawks             : 62
# Dead doves             : 96
# Hawk babies            : 77
# Dove babies            : 6
# Hawks                  : 36.497822229391836
# Doves                  : 63.50217777060816
# ----
# Round Processing time  : 0.021932363510131836
# Elapsed time           : 3.142590284347534
#
# Round 120
# ROUND 120
# Food produced          : 69
# Population             : Hawks-> 4527, Doves-> 7746
# Dead hawks             : 62
# Dead doves             : 140
# Hawk babies            : 64
# Dove babies            : 13
# Hawks                  : 36.8858469811782
# Doves                  : 63.1141530188218
# ----
# Round Processing time  : 0.02892160415649414
# Elapsed time           : 3.173506498336792
#
# Round 121
# ROUND 121
# Food produced          : 66
# Population             : Hawks-> 4528, Doves-> 7663
# Dead hawks             : 57
# Dead doves             : 99
# Hawk babies            : 58
# Dove babies            : 16
# Hawks                  : 37.14215404806825
# Doves                  : 62.85784595193176
# ----
# Round Processing time  : 0.02294635772705078
# Elapsed time           : 3.1994376182556152
#
# Round 122
# ROUND 122
# Food produced          : 68
# Population             : Hawks-> 4532, Doves-> 7621
# Dead hawks             : 71
# Dead doves             : 54
# Hawk babies            : 75
# Dove babies            : 12
# Hawks                  : 37.29120381798733
# Doves                  : 62.70879618201267
# ----
# Round Processing time  : 0.020951509475708008
# Elapsed time           : 3.2223830223083496
#
# Round 123
# ROUND 123
# Food produced          : 66
# Population             : Hawks-> 4543, Doves-> 7618
# Dead hawks             : 70
# Dead doves             : 16
# Hawk babies            : 81
# ...
# Dead hawks             : 89
# Dead doves             : 71
# Hawk babies            : 67
# Dove babies            : 14
# Hawks                  : 41.49268292682927
# Doves                  : 58.507317073170725
# ----
# Round Processing time  : 0.023936033248901367
# Elapsed time           : 4.137927770614624
#
# Round 162
# ROUND 162
# Food produced          : 61
# Population             : Hawks-> 4225, Doves-> 5939
# Dead hawks             : 88
# Dead doves             : 65
# Hawk babies            : 60
# Dove babies            : 7
# Hawks                  : 41.56828020464384
# Doves                  : 58.431719795356166
# ----
# Round Processing time  : 0.021907806396484375
# Elapsed time           : 4.1608664989471436
#
# Round 163
# ROUND 163
# Food produced          : 60
# Population             : Hawks-> 4192, Doves-> 5925
# Dead hawks             : 79
# Dead doves             : 29
# Hawk babies            : 46
# Dove babies            : 15
# Hawks                  : 41.435208065632104
# Doves                  : 58.564791934367896
# ----
# Round Processing time  : 0.02094435691833496
# Elapsed time           : 4.184802293777466
#
# Round 164
# ROUND 164
# Food produced          : 60
# Population             : Hawks-> 4151, Doves-> 5928
# Dead hawks             : 91
# Dead doves             : 8
# Hawk babies            : 50
# Dove babies            : 11
# Hawks                  : 41.18464133346562
# Doves                  : 58.81535866653438
# ----
# Round Processing time  : 0.017951488494873047
# Elapsed time           : 4.204748868942261
#
# Round 165
# ROUND 165
# Food produced          : 66
# Population             : Hawks-> 4125, Doves-> 5929
# Dead hawks             : 86
# Dead doves             : 13
# Hawk babies            : 60
# Dove babies            : 14
# Hawks                  : 41.02844638949672
# Doves                  : 58.97155361050328
# ----
# Round Processing time  : 0.017958641052246094
# Elapsed time           : 4.224703311920166
#
# Round 166
# ROUND 166
# Food produced          : 67
# Population             : Hawks-> 4109, Doves-> 5914
# Dead hawks             : 74
# Dead doves             : 25
# Hawk babies            : 58
# Dove babies            : 10
# Hawks                  : 40.995709867305195
# Doves                  : 59.004290132694805
# ----
# Round Processing time  : 0.018070220947265625
# Elapsed time           : 4.2448155879974365
#
# Round 167
# ROUND 167
# Food produced          : 65
# Population             : Hawks-> 4107, Doves-> 5883
# Dead hawks             : 75
# Dead doves             : 38
# Hawk babies            : 73
# Dove babies            : 7
# Hawks                  : 41.11111111111111
# Doves                  : 58.88888888888889
# ----
# Round Processing time  : 0.016963481903076172
# Elapsed time           : 4.264759302139282
#
# Round 168
# ROUND 168
# Food produced          : 63
# Population             : Hawks-> 4079, Doves-> 5810
# Dead hawks             : 80
# Dead doves             : 84
# Hawk babies            : 52
# Dove babies            : 11
# Hawks                  : 41.24785114773991
# Doves                  : 58.75214885226009
# ----
# Round Processing time  : 0.01894998550415039
# Elapsed time           : 4.284705877304077
#
# Round 169
# ROUND 169
# Food produced          : 60
# Population             : Hawks-> 4045, Doves-> 5743
# Dead hawks             : 81
# Dead doves             : 76
# Hawk babies            : 47
# Dove babies            : 9
# Hawks                  : 41.3261136085002
# Doves                  : 58.6738863914998
# ----
# Round Processing time  : 0.019958019256591797
# Elapsed time           : 4.307651519775391
#
# Round 170
# ROUND 170
# Food produced          : 65
# Population             : Hawks-> 4023, Doves-> 5695
# Dead hawks             : 87
# Dead doves             : 65
# Hawk babies            : 65
# Dove babies            : 17
# Hawks                  : 41.39740687384235
# Doves                  : 58.60259312615764
# ----
# Round Processing time  : 0.022931814193725586
# Elapsed time           : 4.332581043243408
#
# Round 171
# ROUND 171
# Food produced          : 68
# Population             : Hawks-> 4039, Doves-> 5690
# Dead hawks             : 72
# Dead doves             : 27
# Hawk babies            : 88
# Dove babies            : 22
# Hawks                  : 41.515058073799985
# Doves                  : 58.484941926200015
# ----
# Round Processing time  : 0.0199432373046875
# Elapsed time           : 4.3545191287994385
#
# Round 172
# ROUND 172
# Food produced          : 67
# Population             : Hawks-> 4019, Doves-> 5687
# Dead hawks             : 97
# Dead doves             : 17
# Hawk babies            : 77
# Dove babies            : 14
# Hawks                  : 41.40737688028024
# Doves                  : 58.592623119719754
# ----
# Round Processing time  : 0.017955303192138672
# Elapsed time           : 4.374460220336914
#
# Round 173
# ROUND 173
# Food produced          : 67
# Population             : Hawks-> 4009, Doves-> 5689
# Dead hawks             : 73
# Dead doves             : 9
# Hawk babies            : 63
# Dove babies            : 11
# Hawks                  : 41.338420292843885
# Doves                  : 58.66157970715612
# ----
# Round Processing time  : 0.016960620880126953
# Elapsed time           : 4.393415212631226
#
# Round 174
# ROUND 174
# Food produced          : 63
# Population             : Hawks-> 4003, Doves-> 5673
# Dead hawks             : 79
# Dead doves             : 25
# Hawk babies            : 73
# Dove babies            : 9
# Hawks                  : 41.37040099214552
# Doves                  : 58.62959900785448
# ----
# Round Processing time  : 0.017952442169189453
# Elapsed time           : 4.413355827331543
#
# Round 175
# ROUND 175
# Food produced          : 63
# Population             : Hawks-> 3995, Doves-> 5643
# Dead hawks             : 76
# Dead doves             : 37
# Hawk babies            : 68
# Dove babies            : 7
# Hawks                  : 41.45050840423325
# Doves                  : 58.54949159576675
# ----
# Round Processing time  : 0.016962289810180664
# Elapsed time           : 4.433300256729126
#
# Round 176
# ROUND 176
# Food produced          : 65
# Population             : Hawks-> 3997, Doves-> 5595
# Dead hawks             : 64
# Dead doves             : 54
# Hawk babies            : 66
# Dove babies            : 6
# Hawks                  : 41.670141784820686
# Doves                  : 58.32985821517932
# ----
# Round Processing time  : 0.01696324348449707
# Elapsed time           : 4.452260971069336
#
# Round 177
# ROUND 177
# Food produced          : 69
# Population             : Hawks-> 4007, Doves-> 5568
# Dead hawks             : 61
# Dead doves             : 52
# Hawk babies            : 71
# Dove babies            : 25
# Hawks                  : 41.84856396866841
# Doves                  : 58.15143603133159
# ----
# Round Processing time  : 0.01795053482055664
# Elapsed time           : 4.472200393676758
#
# Round 178
# ROUND 178
# Food produced          : 63
# Population             : Hawks-> 3990, Doves-> 5552
# Dead hawks             : 81
# Dead doves             : 37
# Hawk babies            : 64
# Dove babies            : 21
# Hawks                  : 41.81513309578705
# Doves                  : 58.18486690421295
# ----
# Round Processing time  : 0.018953800201416016
# Elapsed time           : 4.493150472640991
#
# Round 179
# ROUND 179
# Food produced          : 67
# Population             : Hawks-> 3995, Doves-> 5539
# Dead hawks             : 63
# Dead doves             : 38
# Hawk babies            : 68
# Dove babies            : 25
# Hawks                  : 41.902664149360184
# Doves                  : 58.09733585063982
# ----
# Round Processing time  : 0.024932146072387695
# Elapsed time           : 4.520076513290405
#
# Round 180
# ROUND 180
# Food produced          : 61
# Population             : Hawks-> 3976, Doves-> 5539
# Dead hawks             : 83
# Dead doves             : 11
# Hawk babies            : 64
# Dove babies            : 11
# Hawks                  : 41.78665265370468
# Doves                  : 58.21334734629532
# ----
# Round Processing time  : 0.01795172691345215
# Elapsed time           : 4.5400230884552
#
# Round 181
# ROUND 181
# Food produced          : 60
# Population             : Hawks-> 3943, Doves-> 5540
# Dead hawks             : 83
# Dead doves             : 8
# Hawk babies            : 50
# Dove babies            : 9
# Hawks                  : 41.579668881155754
# Doves                  : 58.420331118844246
# ----
# Round Processing time  : 0.016954660415649414
# Elapsed time           : 4.558972597122192
#
# Round 182
# ROUND 182
# Food produced          : 65
# Population             : Hawks-> 3917, Doves-> 5536
# Dead hawks             : 77
# Dead doves             : 15
# Hawk babies            : 51
# Dove babies            : 11
# Hawks                  : 41.4365809795832
# Doves                  : 58.563419020416795
# ----
# Round Processing time  : 0.016954421997070312
# Elapsed time           : 4.577921628952026
#
# Round 183
# ROUND 183
# Food produced          : 62
# Population             : Hawks-> 3900, Doves-> 5512
# Dead hawks             : 80
# Dead doves             : 38
# Hawk babies            : 63
# Dove babies            : 14
# Hawks                  : 41.43646408839779
# Doves                  : 58.5635359116022
# ----
# Round Processing time  : 0.017955303192138672
# Elapsed time           : 4.597868204116821
#
# Round 184
# ROUND 184
# Food produced          : 65
# Population             : Hawks-> 3892, Doves-> 5472
# Dead hawks             : 74
# Dead doves             : 52
# Hawk babies            : 66
# Dove babies            : 12
# Hawks                  : 41.56343442973088
# Doves                  : 58.43656557026912
# ----
# Round Processing time  : 0.016954421997070312
# Elapsed time           : 4.616811513900757
#
# Round 185
# ROUND 185
# Food produced          : 64
# Population             : Hawks-> 3882, Doves-> 5437
# Dead hawks             : 82
# Dead doves             : 59
# Hawk babies            : 72
# Dove babies            : 24
# Hawks                  : 41.65683013198841
# Doves                  : 58.34316986801159
# ----
# Round Processing time  : 0.016954660415649414
# Elapsed time           : 4.635760545730591
#
# Round 186
# ROUND 186
# Food produced          : 61
# Population             : Hawks-> 3872, Doves-> 5425
# Dead hawks             : 65
# Dead doves             : 29
# Hawk babies            : 55
# Dove babies            : 17
# Hawks                  : 41.647843390340974
# Doves                  : 58.35215660965903
# ----
# Round Processing time  : 0.01596689224243164
# Elapsed time           : 4.653720378875732
#
# Round 187
# ROUND 187
# Food produced          : 62
# Population             : Hawks-> 3871, Doves-> 5411
# Dead hawks             : 64
# Dead doves             : 28
# Hawk babies            : 63
# Dove babies            : 14
# Hawks                  : 41.704374057315235
# Doves                  : 58.29562594268477
# ----
# Round Processing time  : 0.016958951950073242
# Elapsed time           : 4.672668218612671
#
# Round 188
# ROUND 188
# Food produced          : 70
# Population             : Hawks-> 3902, Doves-> 5411
# Dead hawks             : 58
# Dead doves             : 14
# Hawk babies            : 89
# Dove babies            : 14
# Hawks                  : 41.89842156125845
# Doves                  : 58.10157843874154
# ----
# Round Processing time  : 0.016954660415649414
# Elapsed time           : 4.691614389419556
#
# Round 189
# ROUND 189
# Food produced          : 67
# Population             : Hawks-> 3909, Doves-> 5403
# Dead hawks             : 75
# Dead doves             : 18
# Hawk babies            : 82
# Dove babies            : 10
# Hawks                  : 41.978092783505154
# Doves                  : 58.02190721649485
# ----
# Round Processing time  : 0.0169522762298584
# Elapsed time           : 4.7105607986450195
#
# Round 190
# ROUND 190
# Food produced          : 65
# Population             : Hawks-> 3922, Doves-> 5404
# Dead hawks             : 70
# Dead doves             : 13
# Hawk babies            : 83
# Dove babies            : 14
# Hawks                  : 42.05447137036243
# Doves                  : 57.94552862963758
# ----
# Round Processing time  : 0.017917156219482422
# Elapsed time           : 4.730514049530029
#
# Round 191
# ROUND 191
# Food produced          : 62
# Population             : Hawks-> 3900, Doves-> 5379
# Dead hawks             : 87
# Dead doves             : 36
# Hawk babies            : 65
# Dove babies            : 11
# Hawks                  : 42.030391205948916
# Doves                  : 57.969608794051084
# ----
# Round Processing time  : 0.01695728302001953
# Elapsed time           : 4.74946403503418
#
# Round 192
# ROUND 192
# Food produced          : 68
# Population             : Hawks-> 3924, Doves-> 5358
# Dead hawks             : 73
# Dead doves             : 37
# Hawk babies            : 97
# Dove babies            : 16
# Hawks                  : 42.27537168713639
# Doves                  : 57.7246283128636
# ----
# Round Processing time  : 0.02293705940246582
# Elapsed time           : 4.77439022064209
#
# Round 193
# ROUND 193
# Food produced          : 67
# Population             : Hawks-> 3908, Doves-> 5318
# Dead hawks             : 80
# Dead doves             : 52
# Hawk babies            : 64
# Dove babies            : 12
# Hawks                  : 42.35855191849122
# Doves                  : 57.641448081508784
# ----
# Round Processing time  : 0.01795792579650879
# Elapsed time           : 4.7943434715271
#
# Round 194
# ROUND 194
# Food produced          : 62
# Population             : Hawks-> 3899, Doves-> 5301
# Dead hawks             : 74
# Dead doves             : 38
# Hawk babies            : 65
# Dove babies            : 21
# Hawks                  : 42.380434782608695
# Doves                  : 57.6195652173913
# ----
# Round Processing time  : 0.025888681411743164
# Elapsed time           : 4.822269439697266
#
# Round 195
# ROUND 195
# Food produced          : 65
# Population             : Hawks-> 3922, Doves-> 5292
# Dead hawks             : 60
# Dead doves             : 21
# Hawk babies            : 83
# Dove babies            : 12
# Hawks                  : 42.56566095072715
# Doves                  : 57.43433904927284
# ----
# Round Processing time  : 0.01595616340637207
# Elapsed time           : 4.8422205448150635
#
# Round 196
# ROUND 196
# Food produced          : 61
# Population             : Hawks-> 3898, Doves-> 5293
# Dead hawks             : 83
# Dead doves             : 12
# Hawk babies            : 59
# Dove babies            : 13
# Hawks                  : 42.41105429224241
# Doves                  : 57.58894570775759
# ----
# Round Processing time  : 0.01694941520690918
# Elapsed time           : 4.8611650466918945
#
# Round 197
# ROUND 197
# Food produced          : 61
# Population             : Hawks-> 3883, Doves-> 5297
# Dead hawks             : 67
# Dead doves             : 10
# Hawk babies            : 52
# Dove babies            : 14
# Hawks                  : 42.29847494553377
# Doves                  : 57.70152505446623
# ----
# Round Processing time  : 0.01595783233642578
# Elapsed time           : 4.879117727279663
#
# Round 198
# ROUND 198
# Food produced          : 66
# Population             : Hawks-> 3884, Doves-> 5298
# Dead hawks             : 61
# Dead doves             : 19
# Hawk babies            : 62
# Dove babies            : 20
# Hawks                  : 42.30015247222828
# Doves                  : 57.69984752777173
# ----
# Round Processing time  : 0.016994714736938477
# Elapsed time           : 4.89906644821167
#
# Round 199
# ROUND 199
# Food produced          : 62
# Population             : Hawks-> 3883, Doves-> 5274
# Dead hawks             : 73
# Dead doves             : 37
# Hawk babies            : 72
# Dove babies            : 13
# Hawks                  : 42.40471770230425
# Doves                  : 57.595282297695746
# ----
# Round Processing time  : 0.015956878662109375
# Elapsed time           : 4.917015552520752
#
# Round 200
# ROUND 200
# Food produced          : 64
# Population             : Hawks-> 3854, Doves-> 5251
# Dead hawks             : 88
# Dead doves             : 33
# Hawk babies            : 59
# Dove babies            : 10
# Hawks                  : 42.32839099395937
# Doves                  : 57.67160900604063
# ----
# Round Processing time  : 0.01795172691345215
# Elapsed time           : 4.9369215965271
#
# =============================================================
# Total dead agents      : 17641
# Total breeding agents  : 15746
# Total rounds completed : 200
# Total population size  : 9105
# Hawks                  : 42.32839099395937
# Doves                  : 57.67160900604063
# Processing time        : 4.9369215965271
# =============================================================

# %%
npdove = np.array(graph_dove_points)
nphawk = np.array(graph_hawk_points)
npdovePer = npdove / (npdove + nphawk)
nphawkPer = nphawk / (npdove + nphawk)
nppopulation = nphawk + npdove
nppopulation = nppopulation/np.max(nppopulation)

# %%
plt.clf()
plt.plot(npdovePer, color = "purple", label = "Dove fraction")
plt.plot(nphawkPer, color = "coral", label = "Hawk fraction")
plt.plot(nppopulation, label = "Population")
MSNE = game().findMSNE()
plt.axhline(y=MSNE[0][0],color = 'red', linestyle='--', label = "Hawk in MSNE")
plt.axhline(y=MSNE[0][1],color = 'purple', linestyle='--', label = "Dove in MSNE")
plt.legend()



plt.show()

# %%
print(MSNE)
# Out:
# [array([0.40740741, 0.59259259]), array([0.40740741, 0.59259259])]

# %%
STARTING_DOVES = 1000
STARTING_HAWKS = 1000
STARTING_POPULATION = STARTING_HAWKS + STARTING_DOVES

ROUNDS = 500
STARTING_ENERGY = 100

MIN_FOOD_PER_ROUND = 10
MAX_FOOD_PER_ROUND = 70
MAX_FOOD_APPEARANCE = 2000 # this tells how much max food can be found
ENERGY_REQUIRED_FOR_REPRODUCTION = 250
ENERGY_LOSS_PER_ROUND = 4
ENERGY_LOSS_FROM_FIGHTING = 35
ENERGY_REQUIRED_FOR_LIVING = 10
